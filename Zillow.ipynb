# %% [markdown]
# # Kaggle Project - Zillow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import neighbors
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
from sklearn.cluster import KMeans
from collections import Counter
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import time
import xgboost as xgb
from catboost import CatBoostRegressor

# %% [markdown]
# # Overview

# %% [markdown]
# # Read Data

# %%
properties_16 = pd.read_csv('C:/Users/70785/Downloads/zillow-prize-1/properties_2016.csv', header = 0)
properties_17 = pd.read_csv('C:/Users/70785/Downloads/zillow-prize-1/properties_2017.csv', header = 0)

# %%
properties_16.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties_16.shape
# Out:
# (2985217, 58)

# %%
properties_17.shape
# Out:
# (2985217, 58)

# %%
train_16 = pd.read_csv('C:/Users/70785/Downloads/zillow-prize-1/train_2016_v2.csv', header = 0)
train_17 = pd.read_csv('C:/Users/70785/Downloads/zillow-prize-1/train_2017.csv', header = 0)

# %%
train_16.tail()
# Out:
#        parcelid  logerror transactiondate
# 90270  10774160   -0.0356      2016-12-30
# 90271  12046695    0.0070      2016-12-30
# 90272  12995401   -0.2679      2016-12-30
# 90273  11402105    0.0602      2016-12-30
# 90274  12566293    0.4207      2016-12-30

# %%
train_16.shape
# Out:
# (90275, 3)

# %%
train_17.shape
# Out:
# (77613, 3)

# %% [markdown]
# # Correlations for Preperties_16

# %%
#Identify numerical columns to produce a heatmap
catcols = ['parcelid','airconditioningtypeid','architecturalstyletypeid','buildingqualitytypeid',
           'buildingclasstypeid','decktypeid','fips','hashottuborspa','heatingorsystemtypeid','pooltypeid10',
           'pooltypeid2','pooltypeid7','propertycountylandusecode','propertylandusetypeid','propertyzoningdesc',
           'rawcensustractandblock','regionidcity','regionidcounty','regionidneighborhood','regionidzip',
           'storytypeid','typeconstructiontypeid','yearbuilt','taxdelinquencyflag']
numcols = [x for x in properties_16.columns if x not in catcols]

plt.figure(figsize = (12,8))
sns.heatmap(data=properties_16[numcols].corr())
plt.show()
plt.gcf().clear()

# %%
numcols = [x for x in properties_17.columns if x not in catcols]

plt.figure(figsize = (12,8))
sns.heatmap(data=properties_16[numcols].corr())
plt.show()
plt.gcf().clear()

# %% [markdown]
# 'calculatedfinishedsquarefeet' 'finishedsquarefeet12' 'finishedsquarefeet13' 'finishedsquarefeet15' 'finishedsquarefeet6'are all very strongly correlated, according to the heatmap.
#
# 'structuretaxvaluedollarcnt' 'taxvaluedollarcnt' 'landtaxvaluedollarcnt' and 'taxamount'are also very strongly correlated, according to the heatmap.

# %% [markdown]
# # Missing values

# %%
#Check missing value in column dimension
col_missing_16 = properties_16.isnull().sum(axis=0)/properties_16.shape[0]
col_missing_17 = properties_17.isnull().sum(axis=0)/properties_17.shape[0]

# %%
plt.figure(figsize=(20,10))
y_pos = np.arange(len(col_missing_16.index)) 
plt.bar(y_pos, col_missing_16)
plt.xticks(y_pos, col_missing_16.index, ha='right', rotation=55, fontsize=13, fontname='monospace')
plt.title('Features vs Missing Value Percentage')
plt.show()

# %%
plt.figure(figsize=(20,10))
y_pos = np.arange(len(col_missing_17.index))
plt.bar(y_pos, col_missing_17)
plt.xticks(y_pos, col_missing_17.index, ha='right', rotation=55, fontsize=13, fontname='monospace')
plt.title('Features vs Missing Value Percentage')
plt.show()

# %%
# row_missing = z_16.isnull().sum(axis=1)/z_16.shape[1]
# row_missing[row_missing>0.8]

# %% [markdown]
# ## Removing redundant features

# %%
#'calculatedfinishedsquarefeet' 'finishedsquarefeet12' 'finishedsquarefeet13' 'finishedsquarefeet15' 'finishedsquarefeet6' 
# They have really similar information based on the dictionary description
#'calculatedfinishedsquarefeet' has the fewest missing values
#Plus, 'finishedsquarefeet13' 'finishedsquarefeet15' 'finishedsquarefeet6' all have more than 96% missing values.
print(col_missing_16['finishedsquarefeet13'], col_missing_16['finishedsquarefeet15'], col_missing_16['finishedsquarefeet6'])
dropcols = ['finishedsquarefeet13', 'finishedsquarefeet15','finishedsquarefeet6']

#'finishedsquarefeet50' and 'finishedfloor1squarefeet' have exactly the same information according to the dictionary descriptions
#Plus, 'finishedsquarefeet50' and 'finishedfloor1squarefeet' have exactly the same amount of missing values.
print(col_missing_16['finishedsquarefeet50'], col_missing_16['finishedfloor1squarefeet'])
dropcols.append('finishedsquarefeet50')

#'bathroomcnt' and 'calculatedbathnbr' and 'fullbathcnt' have exactly the same information according to the dictionary descriptions
# Plus, only 'bathroomcnt' has least missing values.
print(col_missing_16['bathroomcnt'], col_missing_16['calculatedbathnbr'], col_missing_16['fullbathcnt'])
dropcols.append('calculatedbathnbr')
dropcols.append('fullbathcnt')
# Out:
# 0.9974300025760271 0.9360857183916613 0.9926300165113625
# 0.9320930438222749 0.9320930438222749
# 0.0038395868709041924 0.0431834603648579 0.0431834603648579

# %% [markdown]
# ## Pool Features

# %%
#'pooltypeid10' seems to be inconcistent with the 'hashottuborspa' 
#which should have the same information according to the dictionary descriptions
# print(properties_16.pooltypeid10.value_counts())
#check if 'pooltypeid10' contains any new information
index = properties_16.hashottuborspa.isnull()
index2 = properties_16.pooltypeid10.isnull()
properties_16.loc[index & ~index2,'hashottuborspa'] = 1
# print(properties_16['hashottuborspa'].value_counts())
#'pooltypeid10' does not contain any new information
index = properties_17.hashottuborspa.isnull()
index2 = properties_17.pooltypeid10.isnull()
properties_17.loc[index & ~index2,'hashottuborspa'] = 1
dropcols.append('pooltypeid10')

#NAs in 'hashottuborspa' means the there is no SPA or Hottub
index = properties_16.hashottuborspa.isnull()
properties_16.loc[index,'hashottuborspa'] = False
index = properties_17.hashottuborspa.isnull()
properties_17.loc[index,'hashottuborspa'] = False

#If 'pooltypeid's are null then pool/hottub doesnt exist
# print(properties_16.pooltypeid2.value_counts())
index = properties_16.pooltypeid2.isnull()
properties_16.loc[index,'pooltypeid2'] = 0
index = properties_17.pooltypeid2.isnull()
properties_17.loc[index,'pooltypeid2'] = 0

# print(properties_16.pooltypeid7.value_counts())
index = properties_16.pooltypeid7.isnull()
properties_16.loc[index,'pooltypeid7'] = 0
index = properties_17.pooltypeid7.isnull()
properties_17.loc[index,'pooltypeid7'] = 0

# print(properties_16.poolcnt.value_counts())
index = properties_16.poolcnt.isnull()
properties_16.loc[index,'poolcnt'] = 0
index = properties_17.poolcnt.isnull()
properties_17.loc[index,'poolcnt'] = 0

#Fill in median values for 'poolsizesum' missing values where 'poolcnt' is >0.
poolsizesum_median_16 = properties_16.loc[properties_16['poolcnt'] > 0, 'poolsizesum'].median()
properties_16.loc[(properties_16['poolcnt'] > 0) & (properties_16['poolsizesum'].isnull()), 'poolsizesum'] = poolsizesum_median_16
poolsizesum_median_17 = properties_17.loc[properties_17['poolcnt'] > 0, 'poolsizesum'].median()
properties_17.loc[(properties_17['poolcnt'] > 0) & (properties_17['poolsizesum'].isnull()), 'poolsizesum'] = poolsizesum_median_17

#If 'poolcnt' is 0, then 'poolsizesum' is 0
properties_16.loc[(properties_16['poolcnt'] == 0), 'poolsizesum'] = 0
properties_17.loc[(properties_17['poolcnt'] == 0), 'poolsizesum'] = 0

# %% [markdown]
# ## Fireplace features

# %%
#'fireplaceflag' seems to be inconcistent with the 'fireplacecnt' 
#which should have the same information according to the dictionary descriptions
# print(properties_16.fireplaceflag.value_counts())
# print(properties_16.fireplacecnt.value_counts())

#Fix 'fireplaceflag' according to 'fireplaceflag'
properties_16['fireplaceflag']= "No"
properties_16.loc[properties_16['fireplacecnt']>0,'fireplaceflag']= "Yes"
properties_17['fireplaceflag']= "No"
properties_17.loc[properties_17['fireplacecnt']>0,'fireplaceflag']= "Yes"

#If 'fireplacecnt' is null then fireplace doesnt exist
index = properties_16.fireplacecnt.isnull()
properties_16.loc[index,'fireplacecnt'] = 0
index = properties_17.fireplacecnt.isnull()
properties_17.loc[index,'fireplacecnt'] = 0

# %% [markdown]
# ## Garage features

# %%
#If 'garagecarcnt' is null then garbage doesnt exist
index = properties_16.garagecarcnt.isnull()
properties_16.loc[index,'garagecarcnt'] = 0
index = properties_17.garagecarcnt.isnull()
properties_17.loc[index,'garagecarcnt'] = 0

#If 'garagetotalsqft' is null then garbage doesnt exist
index = properties_16.garagetotalsqft.isnull()
properties_16.loc[index,'garagetotalsqft'] = 0
index = properties_17.garagetotalsqft.isnull()
properties_17.loc[index,'garagetotalsqft'] = 0

# %% [markdown]
# ## Tax Features

# %%
#If 'taxdelinquencyflag' is null then tax delinquency doesn't exist
# print(properties_16.taxdelinquencyflag.value_counts())
index = properties_16.taxdelinquencyflag.isnull()
properties_16.loc[index,'taxdelinquencyflag'] = 'N'
index = properties_17.taxdelinquencyflag.isnull()
properties_17.loc[index,'taxdelinquencyflag'] = 'N'

#If 'structuretaxvaluedollarcnt' is null then structure tax doesnt exist
properties_16.loc[properties_16['structuretaxvaluedollarcnt'].isnull(), 'structuretaxvaluedollarcnt'] = 0
properties_17.loc[properties_17['structuretaxvaluedollarcnt'].isnull(), 'structuretaxvaluedollarcnt'] = 0

#Fill in mean values for 'landtaxvaluedollarcnt' missing values where 'landtaxvaluedollarcnt' is >0.
landtaxvalue_mean_16 = properties_16.loc[~properties_16['landtaxvaluedollarcnt'].isnull(), 'landtaxvaluedollarcnt'].mean()
properties_16.loc[properties_16['landtaxvaluedollarcnt'].isnull(), 'landtaxvaluedollarcnt'] = landtaxvalue_mean_16
landtaxvalue_mean_17 = properties_17.loc[~properties_17['landtaxvaluedollarcnt'].isnull(), 'landtaxvaluedollarcnt'].mean()
properties_17.loc[properties_17['landtaxvaluedollarcnt'].isnull(), 'landtaxvaluedollarcnt'] = landtaxvalue_mean_17

#Fill in mean values for 'taxamount' missing values where 'taxamount' is >0.
tax_mean_16 = properties_16.loc[~properties_16['taxamount'].isnull(), 'taxamount'].mean()
properties_16.loc[properties_16['taxamount'].isnull(), 'taxamount'] = tax_mean_16
tax_mean_17 = properties_17.loc[~properties_17['taxamount'].isnull(), 'taxamount'].mean()
properties_17.loc[properties_17['taxamount'].isnull(), 'taxamount'] = tax_mean_17

#'structuretaxvaluedollarcnt' + 'landtaxvaluedollarcnt' = 'taxvaluedollarcnt' 
#Remove 'taxvaluedollarcnt'
dropcols.append('taxvaluedollarcnt')

# %% [markdown]
# ## Other features

# %% [markdown]
# 'threequarterbathnbr'

# %%
# print(properties_16['threequarterbathnbr'].value_counts())

#Fill in the NAs with majority which is 1 in 'threequarterbathnbr'
index = properties_16.threequarterbathnbr.isnull()
properties_16.loc[index,'threequarterbathnbr'] = 1

index = properties_17.threequarterbathnbr.isnull()
properties_17.loc[index,'threequarterbathnbr'] = 1

# %% [markdown]
# 'heatingorsystemtypeid'

# %%
# print(properties_16['heatingorsystemtypeid'].value_counts())

#Fill in the NAs with majority which is 2 in 'heatingorsystemtypeid'
index = properties_16.heatingorsystemtypeid.isnull()
properties_16.loc[index,'heatingorsystemtypeid'] = 2
index = properties_17.heatingorsystemtypeid.isnull()
properties_17.loc[index,'heatingorsystemtypeid'] = 2

# %% [markdown]
# 'airconditioningtypeid'

# %%
# print(properties_16['airconditioningtypeid'].value_counts())

#Fill in the NAs with majority which is 1 in 'airconditioningtypeid'
index = properties_16.airconditioningtypeid.isnull()
properties_16.loc[index,'airconditioningtypeid'] = 1
index = properties_17.airconditioningtypeid.isnull()
properties_17.loc[index,'airconditioningtypeid'] = 1

# %% [markdown]
# ## Geo features

# %% [markdown]
# ### Use KNN to fill in NAs

# %%
# # geocolumns = ['parcelid','latitude', 'longitude','propertycountylandusecode', 'propertylandusetypeid',
# #               'propertyzoningdesc','regionidcity','regionidcounty', 'regionidneighborhood', 
# #               'regionidzip','censustractandblock', 'rawcensustractandblock']
# # geo = z_16[geocolumns]
# # geo.dropna(axis = 0, subset = ['latitude', 'longitude'], inplace = True)
# def fillna_knn(df, base, target, fraction = 1, threshold = 10, n_neighbors = 5):
#     assert isinstance(base, list) or isinstance(base, np.ndarray) and isinstance(target, str) 
#     whole = [target] + base
    
#     miss = df[target].isnull()
#     notmiss = ~miss 
#     nummiss = miss.sum()
    
#     enc = OneHotEncoder()
#     X_target = df.loc[notmiss, whole].sample(frac = fraction)
    
#     enc.fit(X_target[target].unique().reshape((-1,1)))
    
#     Y = enc.transform(X_target[ target ].values.reshape((-1,1))).toarray()
#     X = X_target[base]
    
#     print('fitting')
#     n_neighbors = n_neighbors
#     clf = neighbors.KNeighborsClassifier(n_neighbors, weights = 'uniform')
#     clf.fit( X, Y )
    
#     print('the shape of active features: ',enc.active_features_.shape)
    
#     print('predicting')
#     Z = clf.predict(df.loc[miss, base])
    
#     numunperdicted = Z[:,0].sum()
#     if numunperdicted / nummiss *100 < threshold :
#         print('writing result to df')    
#         df.loc[miss, target]  = np.dot(Z , enc.active_features_)
#         print('num of unperdictable data: ', numunperdicted)
#         return enc
#     else:
#         print('out of threshold: {}% > {}%'.format( numunperdicted / nummiss *100 , threshold ))

# #function to deal with variables that are actually string/categories
# def zoningcode2int( df, target ):
#     storenull = df[target].isnull()
#     enc = LabelEncoder( )
#     df[target] = df[ target ].astype( str )

#     print('fit and transform')
#     df[target]= enc.fit_transform(df[target].values)
#     print('num of categories: ', enc.classes_.shape)
#     df.loc[storenull, target] = np.nan
#     print('recover the nan value')
#     return enc

# %%
# properties_16_knn = properties_16.copy()
# a = properties_16_knn.dropna(axis = 0, subset = ['latitude', 'longitude'])

# %%
# #Fill 'regionidzip'
# fillna_knn(df = a, base = ['latitude', 'longitude'] ,
#            target = 'regionidzip', fraction = 1, n_neighbors = 1)

# #Fill 'propertycountylandusecode'
# zoningcode2int(df = a, target = 'propertycountylandusecode')

# fillna_knn(df = a, base = ['latitude', 'longitude'],
#            target = 'propertycountylandusecode', fraction = 1, n_neighbors = 1)

# %% [markdown]
# ### Use Clustering to fill in NAs

# %%
def fillna_clustering( df, base, target, threshold = 10, n_clusters = 5 ):
    assert isinstance( base , list ) or isinstance( base , np.ndarray ) and isinstance( target, str ) 
    whole = [target] + base
    
    miss = df[target].isnull()
    notmiss = ~miss 
    nummiss = miss.sum()
    missing_idx = df.loc[miss,target].index
    
    X = df.loc[notmiss, base]
    
    print('fitting')
    kmc = KMeans(n_clusters=n_clusters, random_state=0).fit(X)
    
    print( 'predicting' )
    Z = kmc.predict(df.loc[miss, base])
    
    numunperdicted = Z.shape[0]
    print( 'writing result to df' )
    id_label=kmc.labels_
    pred = pd.DataFrame(data={'cluster': Z}) 
    pred[target] = 0
    uniq_label=np.unique(Z)
    for i in uniq_label:
        a = np.where(id_label==i)
        c = Counter(df[target][a[0]])
        if(isinstance(c.most_common(1)[0][0], str)):
            pred.loc[pred['cluster'] == i,target] = c.most_common(1)[0][0]
        elif(math.isnan(c.most_common(1)[0][0])):
            pred.loc[pred['cluster'] == i,target] = c.most_common(2)[1][0]
        else:
            pred.loc[pred['cluster'] == i,target] = c.most_common(1)[0][0]
    df[target][missing_idx] = pred[target]
    #print(df[target].isnull().sum())
    print( 'num of unperdictable data: ', numunperdicted )

# %%
# z_16_clustering = z_16.copy()

# df = z_16_clustering
# base = ['latitude', 'longitude']
# target = 'propertyzoningdesc'
# n_clusters = 20


# miss = df[target].isnull()
# notmiss = ~miss 
# nummiss = miss.sum()
# missing_idx = df.loc[miss,target].index

# X = df.loc[notmiss, base]
    
# # print('fitting')
# kmc = KMeans(n_clusters=n_clusters, random_state=0).fit(X)
# id_label=kmc.labels_

# # print( 'predicting' )
# Z = kmc.predict(df.loc[miss, base])
# pred = pd.DataFrame(data={'cluster': Z}) 
# pred[target] = 0

# uniq_label=np.unique(Z)
# #i = uniq_label[1]
# for i in uniq_label:
#     a = np.where(id_label==i)
#     c = Counter(df[target][a[0]])
#     if(isinstance(c.most_common(1)[0][0], str)):
#         pred.loc[pred['cluster'] == i,target] = c.most_common(1)[0][0]
#     elif(math.isnan(c.most_common(1)[0][0])):
#         pred.loc[pred['cluster'] == i,target] = c.most_common(2)[1][0]
#     else:
#         pred.loc[pred['cluster'] == i,target] = c.most_common(1)[0][0]

# df[target][missing_idx] = pred[target]
# df[target].isnull().sum()

# %%
properties_16_clustering = properties_16.copy()
b_16 = properties_16_clustering.dropna(axis = 0, subset = ['latitude', 'longitude'])
properties_17_clustering = properties_17.copy()
b_17 = properties_17_clustering.dropna(axis = 0, subset = ['latitude', 'longitude'])

# %%
#Fill 'regionidzip'
fillna_clustering(df = b_16, base = ['latitude', 'longitude'] ,
                  target = 'regionidzip', n_clusters = 8)
fillna_clustering(df = b_17, base = ['latitude', 'longitude'] ,
                  target = 'regionidzip', n_clusters = 8)

#Fill 'propertycountylandusecode'
fillna_clustering(df = b_16, base = ['latitude', 'longitude'] ,
                  target = 'propertycountylandusecode', n_clusters = 8)
fillna_clustering(df = b_17, base = ['latitude', 'longitude'] ,
                  target = 'propertycountylandusecode', n_clusters = 8)
# Out:
# fitting
# predicting
# writing result to df
# num of unperdictable data:  2543
# fitting
# predicting
# writing result to df
# num of unperdictable data:  9782
# fitting
# predicting
# writing result to df
# num of unperdictable data:  840
# fitting
# predicting
# writing result to df
# num of unperdictable data:  67

# %%
latitude_flag = ~properties_16_clustering['latitude'].isnull()
longitude_flag = ~properties_16_clustering['longitude'].isnull()
properties_16_clustering.loc[latitude_flag & longitude_flag, 'regionidzip'] = b_16['regionidzip']
properties_16_clustering.loc[latitude_flag & longitude_flag, 'propertycountylandusecode'] = b_16['propertycountylandusecode']

latitude_flag = ~properties_17_clustering['latitude'].isnull()
longitude_flag = ~properties_17_clustering['longitude'].isnull()
properties_17_clustering.loc[latitude_flag & longitude_flag, 'regionidzip'] = b_17['regionidzip']
properties_17_clustering.loc[latitude_flag & longitude_flag, 'propertycountylandusecode'] = b_17['propertycountylandusecode']

# %% [markdown]
# ## Getting rid of features with missing value > 97%?

# %%
#a = properties_16_knn.drop(dropcols, axis=1)
b_16 = properties_16_clustering.drop(dropcols, axis=1)
col_missing_16 = b_16.isnull().sum(axis=0)/b_16.shape[0]
b_17 = properties_17_clustering.drop(dropcols, axis=1)
col_missing_17 = b_17.isnull().sum(axis=0)/b_17.shape[0]
# print(col_missing[col_missing>0.5])
missing_more_than_97 = ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 
                        'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft17','yardbuildingsqft26',
                        'taxdelinquencyyear']
#properties_16_knn = a.drop(missing_more_than_97, axis=1)
properties_16_clustering = b_16.drop(missing_more_than_97, axis=1)
properties_17_clustering = b_17.drop(missing_more_than_97, axis=1)

# %% [markdown]
# # Categorical with Multiple Levels¶

# %%
#All the categorical features
cat_col = ['propertycountylandusecode', 'propertyzoningdesc', 'airconditioningtypeid', 'buildingqualitytypeid',
          'heatingorsystemtypeid', 'pooltypeid2', 'pooltypeid7', 'propertylandusetypeid', 'regionidcity',
          'regionidcounty', 'regionidneighborhood', 'regionidzip', 'hashottuborspa', 'fireplaceflag',
           'taxdelinquencyflag']
#Check their levels
for i in cat_col:
    print (i, len(properties_16_clustering[i].value_counts()))
    print (i, len(properties_17_clustering[i].value_counts()))
# Out:
# propertycountylandusecode 240
# propertycountylandusecode 234
# propertyzoningdesc 5638
# propertyzoningdesc 5651
# airconditioningtypeid 7
# airconditioningtypeid 7
# buildingqualitytypeid 12
# buildingqualitytypeid 12
# heatingorsystemtypeid 14
# heatingorsystemtypeid 14
# pooltypeid2 2
# pooltypeid2 2
# pooltypeid7 2
# pooltypeid7 2
# propertylandusetypeid 15
# propertylandusetypeid 16
# regionidcity 186
# regionidcity 186
# regionidcounty 3
# regionidcounty 3
# regionidneighborhood 528
# regionidneighborhood 529
# regionidzip 405
# regionidzip 403
# hashottuborspa 2
# hashottuborspa 2
# fireplaceflag 2
# fireplaceflag 2
# taxdelinquencyflag 2
# taxdelinquencyflag 2

# %% [markdown]
# ## 'propertycountylandusecode'

# %%
#According to http://www.titleadvantage.com/mdocs/LA%20Use%20Codes.pdf and https://www.ocpafl.org/Searches/Lookups.aspx/Code/PropertyUse
properties_16_clustering['propertycountylandusecode'] = [str(i) for i in properties_16_clustering['propertycountylandusecode']]

uniq_code_16=np.unique(properties_16_clustering['propertycountylandusecode'])
for i in uniq_code_16:
    if i.startswith('0'):
        if i.startswith('00'):
            properties_16_clustering.loc[properties_16_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Vacant'
        elif i.startswith('01'):
            properties_16_clustering.loc[properties_16_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Single Residence'
        else:
            properties_16_clustering.loc[properties_16_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Multi-family Residence'
    else:
        properties_16_clustering.loc[properties_16_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Commercial'
          
properties_17_clustering['propertycountylandusecode'] = [str(i) for i in properties_17_clustering['propertycountylandusecode']]
uniq_code_17=np.unique(properties_17_clustering['propertycountylandusecode'])
for i in uniq_code_17:
    if i.startswith('0'):
        if i.startswith('00'):
            properties_17_clustering.loc[properties_17_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Vacant'
        elif i.startswith('01'):
            properties_17_clustering.loc[properties_17_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Single Residence'
        else:
            properties_17_clustering.loc[properties_17_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Multi-family Residence'
    else:
        properties_17_clustering.loc[properties_17_clustering['propertycountylandusecode'] == i, 'propertycountylandusecode'] = 'Commercial'

# %%
properties_16_clustering['propertycountylandusecode'].value_counts()
# Out:
# Single Residence          1791941
# Commercial                 980550
# Multi-family Residence     212726
# Name: propertycountylandusecode, dtype: int64

# %% [markdown]
# ## 'propertyzoningdesc'

# %%
#Accoding to the https://planning.lacity.org/zone_code/Appendices/sum_of_zone.pdf 
#you get almost the same information as 'propertycountylandusecode' if you reduce its levels
properties_16_clustering.drop('propertyzoningdesc', axis=1, inplace=True)
properties_17_clustering.drop('propertyzoningdesc', axis=1, inplace=True)

# %% [markdown]
# ##  'regionidcity' and 'regionidneighborhood'

# %%
#You get almost the same information as 'regionidzip' if you reduce its levels
properties_16_clustering.drop(['regionidcity', 'regionidneighborhood'], axis=1, inplace=True)
properties_17_clustering.drop(['regionidcity', 'regionidneighborhood'], axis=1, inplace=True)

# %% [markdown]
# ## 'regionidzip'

# %%
properties_16_clustering['regionidzip'] = [str(i) for i in properties_16_clustering['regionidzip']]
properties_17_clustering['regionidzip'] = [str(i) for i in properties_17_clustering['regionidzip']]

# %%
properties_16_clustering['regionidzip'] = properties_16_clustering['regionidzip'].apply(lambda x: x[1]+x[-3])
properties_17_clustering['regionidzip'] = properties_17_clustering['regionidzip'].apply(lambda x: x[1]+x[-3])

# %%
properties_16_clustering['regionidzip'].value_counts()
# Out:
# 65    264274
# 63    254969
# 60    251611
# 67    246495
# 66    235788
# 64    232093
# 61    217541
# 62    215215
# 69    213482
# 68    187601
# 78    122664
# 79     77982
# 77     67559
# 73     61191
# 76     60116
# 71     59194
# 74     56092
# 75     38428
# 70     30228
# 52     17280
# 59     12328
# 57     11585
# an     11437
# 53      9993
# 54      9944
# 55      5874
# 72      5423
# 56      4783
# 58      2999
# 51       617
# 95       431
# Name: regionidzip, dtype: int64

# %% [markdown]
# # Impute rest of the NAs

# %%
properties_16_clustering.isnull().sum()
# Out:
# parcelid                              0
# airconditioningtypeid                 0
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingqualitytypeid           1046729
# finishedfloor1squarefeet        2782500
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# fips                              11437
# fireplacecnt                          0
# garagecarcnt                          0
# garagetotalsqft                       0
# hashottuborspa                        0
# heatingorsystemtypeid                 0
# latitude                          11437
# longitude                         11437
# lotsizesquarefeet                276099
# poolcnt                               0
# poolsizesum                           0
# pooltypeid2                           0
# pooltypeid7                           0
# propertycountylandusecode             0
# propertylandusetypeid             11437
# rawcensustractandblock            11437
# regionidcounty                    11437
# regionidzip                           0
# roomcnt                           11475
# threequarterbathnbr                   0
# unitcnt                         1007727
# yearbuilt                         59928
# numberofstories                 2303148
# fireplaceflag                         0
# structuretaxvaluedollarcnt            0
# assessmentyear                    11439
# landtaxvaluedollarcnt                 0
# taxamount                             0
# taxdelinquencyflag                    0
# censustractandblock               75126
# dtype: int64

# %%
#Impute NA with -1
properties_16_clustering = properties_16_clustering.fillna(-1)
properties_17_clustering = properties_17_clustering.fillna(-1)

# %% [markdown]
# missing value final check

# %%
#final_z_16_knn.isnull().sum()

# %%
sum(properties_16_clustering.isnull().sum())
# Out:
# 0

# %%
sum(properties_17_clustering.isnull().sum())
# Out:
# 0

# %% [markdown]
# # Merge data

# %%
z_16_clustering = pd.merge(train_16, properties_16_clustering,on = 'parcelid',how = 'left')
z_17_clustering = pd.merge(train_17, properties_17_clustering,on = 'parcelid',how = 'left')

# %% [markdown]
# check missing values

# %%
sum(z_16_clustering.isnull().sum())
# Out:
# 0

# %% [markdown]
# ## 'transactiondate' make items into datetime object

# %%
z_16_clustering['transactiondate'] = z_16_clustering['transactiondate'].apply(
        lambda x: datetime.strptime(x,'%Y-%m-%d'))
z_17_clustering['transactiondate'] = z_17_clustering['transactiondate'].apply(
        lambda x: datetime.strptime(x,'%Y-%m-%d'))

# %% [markdown]
# ## Creat 'year' and 'month' features

# %%
z_16_clustering['year'] = z_16_clustering['transactiondate'].dt.year
z_16_clustering['month'] = z_16_clustering['transactiondate'].dt.month
z_17_clustering['year'] = z_17_clustering['transactiondate'].dt.year
z_17_clustering['month'] = z_17_clustering['transactiondate'].dt.month

# %%
#Remove 'transactiondate'
z_16_clustering.drop('transactiondate', axis=1, inplace=True)
z_17_clustering.drop('transactiondate', axis=1, inplace=True)

# %% [markdown]
# # Correlations for z_16_clustering

# %% [markdown]
# ## Numerical features

# %%
# get correlation of all numerical variable
correlation = z_16_clustering.select_dtypes(include = [np.number]).corr()
print(correlation['logerror'].sort_values(ascending = False))
# Out:
# logerror                        1.000000
# finishedsquarefeet12            0.039555
# calculatedfinishedsquarefeet    0.039011
# bathroomcnt                     0.027889
# bedroomcnt                      0.025467
# structuretaxvaluedollarcnt      0.023141
# censustractandblock             0.017309
# finishedfloor1squarefeet        0.012481
# threequarterbathnbr             0.011011
# garagetotalsqft                 0.008901
# rawcensustractandblock          0.008376
# fips                            0.008363
# fireplacecnt                    0.007746
# month                           0.006421
# garagecarcnt                    0.006140
# roomcnt                         0.005760
# lotsizesquarefeet               0.005357
# latitude                        0.004915
# parcelid                        0.004837
# yearbuilt                       0.004637
# numberofstories                 0.004215
# airconditioningtypeid           0.004046
# propertylandusetypeid           0.001003
# regionidcounty                  0.000341
# unitcnt                        -0.002802
# landtaxvaluedollarcnt          -0.003050
# longitude                      -0.003432
# pooltypeid2                    -0.003881
# buildingqualitytypeid          -0.005069
# taxamount                      -0.006671
# pooltypeid7                    -0.008078
# poolsizesum                    -0.008956
# poolcnt                        -0.008983
# heatingorsystemtypeid          -0.019586
# assessmentyear                       NaN
# year                                 NaN
# Name: logerror, dtype: float64

# %% [markdown]
# ## Categorical features - Boxplot

# %% [markdown]
# # Outliers

# %%
cat_col = ['propertycountylandusecode', 'airconditioningtypeid', 'buildingqualitytypeid',
          'heatingorsystemtypeid', 'pooltypeid2', 'pooltypeid7', 'propertylandusetypeid',
          'regionidcounty', 'regionidzip', 'hashottuborspa', 'fireplaceflag', 'taxdelinquencyflag']
num_col = z_16_clustering.columns.difference(cat_col)
# train_df=train_df[ train_df.logerror > -0.4 ]
# train_df=train_df[ train_df.logerror < 0.419 ]




# list of features without intervention

# count    8.871900e+04
# mean     6.033366e+13
# std      3.096115e+12
# min     -1.000000e+00
# 50%      6.037604e+13
# 99.8%    6.111008e+13
# max      6.111009e+13
# Name: censustractandblock, dtype: float64


# count    88273.000000
# mean      6048.725216
# std         20.440648
# min       6037.000000
# 50%       6037.000000
# 99.8%     6111.000000
# max       6111.000000
# Name: fips, dtype: float64


# count    88273.000000
# mean         0.122302
# std          0.382543
# min          0.000000
# 50%          0.000000
# 99.8%        3.000000
# max          4.000000
# Name: fireplacecnt, dtype: float64



# count    8.762600e+04
# mean     3.400580e+07
# std      2.647829e+05
# min      3.333930e+07
# 50%      3.401991e+07
# 99.8%    3.470700e+07
# max      3.481601e+07
# Name: latitude, dtype: float64


# count    8.718500e+04
# mean    -1.181964e+08
# std      3.577270e+05
# min     -1.194479e+08
# 0.2%    -1.192825e+08
# 50%     -1.181708e+08
# 99.8%   -1.175798e+08
# max     -1.175549e+08
# Name: longitude, dtype: float64




# count    86976.000000
# mean         5.862560
# std          2.811006
# min          1.000000
# 0.2%         1.000000
# 50%          6.000000
# 99.8%       12.000000
# max         12.000000
# Name: month, dtype: float64


# count    86976.000000
# mean        -0.443295
# std          1.056214
# min         -1.000000
# 0.2%        -1.000000
# 50%         -1.000000
# 99.8%        3.000000
# max          4.000000
# Name: numberofstories, dtype: float64


# count    8.697600e+04
# mean     1.297369e+07
# std      2.520129e+06
# min      1.071174e+07
# 0.2%     1.072128e+07
# 50%      1.254645e+07
# 99.8%    1.729324e+07
# max      1.629608e+08
# Name: parcelid, dtype: float64



# count    86976.000000
# mean         0.193065
# std          0.394706
# min          0.000000
# 0.2%         0.000000
# 50%          0.000000
# 99.8%        1.000000
# max          1.000000
# Name: poolcnt, dtype: float64



# count    8.675800e+04
# mean     6.048829e+07
# std      2.004896e+05
# min      6.037101e+07
# 0.2%     6.037102e+07
# 50%      6.037603e+07
# 99.8%    6.111008e+07
# max      6.111009e+07
# Name: rawcensustractandblock, dtype: float64



# count    86471.0
# mean      2016.0
# std          0.0
# min       2016.0
# 0.2%      2016.0
# 50%       2016.0
# 99.8%     2016.0
# max       2016.0
# Name: year, dtype: float6


# count    86471.000000
# mean      1966.047253
# std         70.018119
# min         -1.000000
# 0.2%      1901.000000
# 50%       1969.000000
# 99.8%     2013.000000
# max       2015.000000
# Name: yearbuilt, dtype: float64



import matplotlib.pyplot as plt
# %matplotlib inline



# z_16_clustering.head
num_col




# count    90275.000000
# mean         2.279474
# std          1.004271
# min          0.000000
# 50%          2.000000
# 99.8%        7.000000
# max         20.000000
# Name: bathroomcnt, dtype: float64

# upper_bnd = z_16_clustering[num_col[idx]].quantile(0.9975)


idx = 1
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 7.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]

# z_16_clustering[num_col[idx]].hist(bins=30)


# bedroomcnt - remove outliers that have > 8 bedrooms
idx = 2
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 8.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)





# calculatedfinishedsquarefeet removed outliers > 6131 and < 0

# count    89605.000000
# mean      1734.612979
# std        867.362040
# min         -1.000000
# 50%       1528.000000
# 99.8%     6130.960000
# max      22741.000000
# Name: calculatedfinishedsquarefeet, dtype: float64


idx = 3
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 6131
lower_bnd = 0
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] >  lower_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)


# finishedfloor1squarefeet - removed outliers > 2738
# count    88719.000000
# mean       101.755216
# std        394.466879
# min         -1.000000
# 50%         -1.000000
# 99.8%     2738.410000
# max       5701.000000
# Name: finishedfloor1squarefeet, dtype: float64



idx = 5
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 2738
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)

# z_16_clustering[num_col[idx]].value_counts()


# finishedsquarefeet12 - removed outliers > 5383
# count    88495.000000
# mean      1640.680016
# std        849.893801
# min         -1.000000
# 50%       1479.000000
# 99.8%     5382.530000
# max       6127.000000
# Name: finishedsquarefeet12, dtype: float64


idx = 6
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 5383
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)




# garagecarcnt - removed outliers > 4

# count    88273.000000
# mean         0.597782
# std          0.899559
# min          0.000000
# 50%          0.000000
# 99.8%        3.000000
# max         13.000000
# Name: garagecarcnt, dtype: float64

idx = 9
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 4.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)



# garagetotalsqft - removed outliers > 768
# count    88068.000000
# mean       110.349957
# std        209.241486
# min          0.000000
# 50%          0.000000
# 99.8%      768.000000
# max        878.000000
# Name: garagetotalsqft, dtype: float64


idx = 10
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 768
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)





# landtaxvaluedollarcnt - removed outliers > 2363546
# count    8.784600e+04
# mean     2.637081e+05
# std      3.244894e+05
# min      2.200000e+01
# 50%      1.904020e+05
# 99.8%    2.363546e+06
# max      1.315000e+07
# Name: landtaxvaluedollarcnt, dtype: float64

idx = 11
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975])
upper_bnd = 2363546
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)



# logerror - removed outliers > 0.9685 and outliers < -0.7319
# count    87626.000000
# mean         0.011158
# std          0.157813
# min         -4.605000
# 0.2%        -0.731900
# 50%          0.005000
# 99.8%        0.968406
# max          4.737000
# Name: logerror, dtype: float64


idx = 13
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 0.9685
lower_bnd = -0.7319
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] >  lower_bnd]
# z_16_clustering[num_col[idx]].hist(bins=30)



# lotsizesquarefeet - removed outliers > 815788
# count    8.718500e+04
# mean     2.560400e+04
# std      1.150715e+05
# min     -1.000000e+00
# 0.2%    -1.000000e+00
# 50%      6.742000e+03
# 99.8%    8.157880e+05
# max      6.971010e+06
# Name: lotsizesquarefeet, dtype: float64


idx = 15
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 815789
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]

# z_16_clustering[num_col[idx]].hist(bins=30)



# poolsizesum - removed outliers > 545
# count    86976.000000
# mean        95.570065
# std        195.773394
# min          0.000000
# 0.2%         0.000000
# 50%          0.000000
# 99.8%      545.125000
# max        960.000000
# Name: poolsizesum, dtype: float64

idx = 20
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 546
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]


# roomcnt - removed outliers > 10
# count    86758.000000
# mean         1.451739
# std          2.775266
# min          0.000000
# 0.2%         0.000000
# 50%          0.000000
# 99.8%       10.000000
# max         13.000000
# Name: roomcnt, dtype: float64


idx = 22
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 10.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]




# structuretaxvaluedollarcnt - removed outliers > 1053985
# count    8.641400e+04
# mean     1.645139e+05
# std      1.424486e+05
# min      0.000000e+00
# 0.2%     7.115000e+03
# 50%      1.291290e+05
# 99.8%    1.053985e+06
# max      3.500000e+06
# Name: structuretaxvaluedollarcnt, dtype: float64


idx = 23
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 1053985
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]





# taxamount - removed outliers > 30864
# count     86197.000000
# mean       5450.939176
# std        4322.904711
# min          49.080000
# 0.2%        504.623000
# 50%        4467.740000
# 99.8%     30863.119500
# max      173218.070000
# Name: taxamount, dtype: float64

idx = 24
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 30864
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]



# count    85982.000000
# mean         1.000419
# std          0.021019
# min          1.000000
# 0.2%         1.000000
# 50%          1.000000
# 99.8%        1.000000
# max          3.000000
# Name: threequarterbathnbr, dtype: float64


idx = 25
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 1.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]
z_16_clustering[num_col[idx]].hist(bins=30)


# unitcnt - removed outliers > 4.1
# count    86475.000000
# mean         0.377785
# std          1.186620
# min         -1.000000
# 0.2%        -1.000000
# 50%          1.000000
# 99.8%        4.000000
# max        143.000000
# Name: unitcnt, dtype: float64

idx = 26
# print(num_col[idx])
# print(z_16_clustering.shape)
# z_16_clustering[num_col[idx]].hist(bins=30)
# z_16_clustering[num_col[idx]].describe(percentiles=[.9975, .0025])
upper_bnd = 4.1
z_16_clustering = z_16_clustering[z_16_clustering[num_col[idx]] <  upper_bnd]






# #List of features without intervention
# #finishedsquarefeet12
# # count    2.700485e+06
# # mean     1.737672e+03
# # std      8.189221e+02
# # min      1.000000e+00
# # 50%      1.537000e+03
# # 99.8%    5.929000e+03
# # max      7.147000e+03
# # Name: finishedsquarefeet12, dtype: float64



# #List of features with intervention
# # bathroomcnt 0 - 20 99.75% - 7.5 remove entries beyond 99.75%
# # bedroomcnt 0 - 20 99.75% - 7.5 remove entries beyond 99.75%

# # finishedfloor1squarefeet
# # count    202473.000000
# # mean       1377.550780
# # std         619.081217
# # min           3.000000
# # 50%        1282.000000
# # 99.8%      4776.820000
# # max       31303.000000
# # Name: finishedfloor1squarefeet, dtype: float64


# # calculatedfinishedsquarefeet - remove beyond 99.75%

# # fireplacecnt - remove > 4 from histogram
# # count    311847.000000
# # mean          1.164953
# # std           0.448701
# # min           1.000000
# # 50%           1.000000
# # 99.8%         3.000000
# # max           9.000000
# # Name: fireplacecnt, dtype: float64

# # garagecarcnt - remove beyond 99.75%
# # count    881017.000000
# # mean          1.816656
# # std           0.576970
# # min           0.000000
# # 50%           2.000000
# # 99.8%         5.000000
# # max          19.000000
# # Name: garagecarcnt, dtype: float64








# idx = 5
# print(col_num[idx])
# print(properties_16.shape)
# properties_16[col_num[idx]].hist(bins=5)
# properties_16[col_num[idx]].describe(percentiles=[.9975])
# properties_16 = properties_16[properties_16[col_num[idx]] <  properties_16[col_num[idx]].quantile(0.9975)]




# idx = 13
# print(col_num[idx])
# print(properties_16.shape)
# properties_16[col_num[idx]].hist(bins=10)
# properties_16[col_num[idx]].describe(percentiles=[.9975])
# properties_16 = properties_16[properties_16[col_num[idx]] <  properties_16[col_num[idx]].quantile(0.9975)]


# idx = 14
# print(col_num[idx])
# print(properties_16.shape)
# properties_16[col_num[idx]].hist(bins=10)
# properties_16[col_num[idx]].describe(percentiles=[.9975])
# properties_16_3 = properties_16[properties_16[col_num[idx]] < properties_16[col_num[idx]].quantile(0.9975)]
# properties_16_4 = properties_16[properties_16[col_num[idx]].isna()]

# frames = [properties_16_3, properties_16_4]
# res = pd.concat(frames)


# idx = 11
# print(col_num[idx])
# print(properties_16.shape)
# res[col_num[idx]].hist(bins=5)
# res[col_num[idx]].describe(percentiles=[.9975])
# properties_16_1 = res[res[col_num[idx]] <  4]
# properties_16_2 = res[res[col_num[idx]].isna()]

# frames = [properties_16_1, properties_16_2]
# res = pd.concat(frames)
# res.shape





# # #If 'garagecarcnt' is null then garbage doesnt exist
# # index = z_16.garagecarcnt.isnull()
# # z_16.loc[index,'garagecarcnt'] = 0

# %%
def detect_outlier(data):
    
    """
    input: numerical data, Array
    return: new data without outlier
    """
    tmp = data.copy()
    
    q1, q3 = np.percentile(tmp, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)
    
    has_outlier = np.max(tmp) > upper_bound or np.min(tmp) < lower_bound
    if not has_outlier:
        return tmp
    upper_idx = np.where(tmp > upper_bound)
    lower_idx = np.where(tmp < lower_bound)
    tmp[upper_idx] = upper_bound
    tmp[lower_idx] = lower_bound
    
    if np.max(tmp) <= upper_bound and np.min(tmp) >= lower_bound:
        print ("Done with handling outliers")
    else:
        print ("Warning!! Fail handling outliers")
    
    return tmp

# %%
for f in num_col:
    z_16_clustering[f] = detect_outlier(z_16_clustering[f].values)
# Out:
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers

# %%
for f in num_col:
    z_17_clustering[f] = detect_outlier(z_17_clustering[f].values)
# Out:
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers
# Done with handling outliers

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Get Dummy

# %%
cat_col = ['propertycountylandusecode', 'airconditioningtypeid', 'buildingqualitytypeid',
          'heatingorsystemtypeid', 'pooltypeid2', 'pooltypeid7', 'propertylandusetypeid',
          'regionidcounty', 'regionidzip', 'hashottuborspa', 'fireplaceflag', 'taxdelinquencyflag']

# %%
z_16_clustering = pd.get_dummies(z_16_clustering, columns = cat_col)
z_17_clustering = pd.get_dummies(z_17_clustering, columns = cat_col)

# %%
z_16_clustering.shape
# Out:
# (86471, 113)

# %%
z_17_clustering.shape
# Out:
# (77613, 119)

# %%
z_16_clustering.to_csv('z_16_clustering.csv', index=True)
z_17_clustering.to_csv('z_16_clustering.csv', index=True)

# %%
# z_16_clustering = pd.read_csv('C:/Users/70785/z_16_clustering.csv', header = 0)
# z_17_clustering = pd.read_csv('C:/Users/70785/z_17_clustering.csv', header = 0)

# %% [markdown]
# ## Split training and test

# %%
x = z_16_clustering[z_16_clustering.columns.difference(['logerror'])].values
y = z_16_clustering['logerror'].values
x_17 = z_17_clustering[z_17_clustering.columns.difference(['logerror'])].values
y_17 = z_17_clustering['logerror'].values

# Split data into train and test (80% & 20%)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state = 0)
x_17_train, x_17_test, y_17_train, y_17_test = train_test_split(
    x_17, y_17, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Standarization

# %%
# initialize a scaler object
scaler = StandardScaler()

# transform training set
x_train_std = scaler.fit_transform(x_train)

# the same transform for test set
x_test_std = scaler.transform(x_test)

# transform whole dataset 
X = scaler.fit_transform(x)

# initialize a scaler object
scaler = StandardScaler()

# transform training set
x_17_train_std = scaler.fit_transform(x_17_train)

# the same transform for test set
x_17_test_std = scaler.transform(x_17_test)

# transform whole dataset 
X_17 = scaler.fit_transform(x_17)

# %% [markdown]
# ## Model selection

# %%
# Function to evaluate the model using AIC with sum of squared error
def model_evaluation(X, y, cv, regressor, **kwargs):
    
    start = time.time()
    kf = KFold(n_splits=cv,shuffle=True)
    y_predict = y.copy()
    clf = regressor(**kwargs)
    
    rmse = 0
    mae = 0
    for train_index, validate_index in kf.split(X):
        
        # split to training and validation set
        X_train, X_validate = X[train_index], X[validate_index]
        y_train, y_validate = y[train_index], y[validate_index]
        
        # fit current model
        clf.fit(X_train, y_train)
        
        # predict on validation set
        y_predict = clf.predict(X_validate)
        
        # rmse
        rmse += np.sqrt(np.mean((y_predict - y_validate)**2))
        
        # mae 
        mae += np.mean(abs(y_predict - y_validate))
    end = time.time()    
    # return average score among all validation sets
    return rmse / cv, mae / cv, end-start

# %%
models = [LinearRegression, Ridge, Lasso, ElasticNet, DecisionTreeRegressor, BaggingRegressor, RandomForestRegressor, ExtraTreesRegressor, 
          AdaBoostRegressor, GradientBoostingRegressor, SVR]
# results
results_dict = {}

# train models
for model in models:
    print ("Training model: ", model)
    if(model == Ridge):
        rmse, mae, runtime = model_evaluation(x_train, y_train, 5, model, alpha = 0.1)
    elif(model == Lasso):
        rmse, mae, runtime = model_evaluation(x_train, y_train, 5, model, alpha = 0.001)
    elif(model == ElasticNet):
        rmse, mae, runtime = model_evaluation(x_train, y_train, 5, model, alpha = 0.001, l1_ratio = 0.5)
    elif(model == SVR):
        rmse, mae, runtime = model_evaluation(x_train, y_train, 5, model, gamma='scale', C=1.0, epsilon=0.2)
    else:
        rmse, mae, runtime = model_evaluation(x_train, y_train, 5, model)
    results_dict[model] = [rmse, mae, runtime]

print ('Done with model selection!')
# Out:
# Training model:  <class 'sklearn.linear_model.base.LinearRegression'>
# Training model:  <class 'sklearn.linear_model.ridge.Ridge'>
# Training model:  <class 'sklearn.linear_model.coordinate_descent.Lasso'>
# Training model:  <class 'sklearn.linear_model.coordinate_descent.ElasticNet'>
# Training model:  <class 'sklearn.tree.tree.DecisionTreeRegressor'>
# Training model:  <class 'sklearn.ensemble.bagging.BaggingRegressor'>
# Training model:  <class 'sklearn.ensemble.forest.RandomForestRegressor'>
# Training model:  <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# Training model:  <class 'sklearn.ensemble.weight_boosting.AdaBoostRegressor'>
# Training model:  <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# Training model:  <class 'sklearn.svm.classes.SVR'>
# Done with model selection!

# %%
df = pd.DataFrame(results_dict).T
df.columns = [ 'rmse', 'mae', 'time']
df
# Out:
#                                                         rmse       mae  \
# <class 'sklearn.linear_model.base.LinearRegress...  0.060211  0.045117
# <class 'sklearn.linear_model.ridge.Ridge'>          0.060234  0.045140
# <class 'sklearn.linear_model.coordinate_descent...  0.060358  0.045278
# <class 'sklearn.linear_model.coordinate_descent...  0.060334  0.045253
# <class 'sklearn.tree.tree.DecisionTreeRegressor'>   0.085463  0.065572
# <class 'sklearn.ensemble.bagging.BaggingRegress...  0.062940  0.047843
# <class 'sklearn.ensemble.forest.RandomForestReg...  0.063039  0.047957
# <class 'sklearn.ensemble.forest.ExtraTreesRegre...  0.063979  0.048718
# <class 'sklearn.ensemble.weight_boosting.AdaBoo...  0.060410  0.045277
# <class 'sklearn.ensemble.gradient_boosting.Grad...  0.059891  0.044801
# <class 'sklearn.svm.classes.SVR'>                   0.060753  0.045468
#
#                                                           time
# <class 'sklearn.linear_model.base.LinearRegress...    3.075147
# <class 'sklearn.linear_model.ridge.Ridge'>            0.704118
# <class 'sklearn.linear_model.coordinate_descent...   66.991079
# <class 'sklearn.linear_model.coordinate_descent...   49.891404
# <class 'sklearn.tree.tree.DecisionTreeRegressor'>     9.841588
# <class 'sklearn.ensemble.bagging.BaggingRegress...   61.658135
# <class 'sklearn.ensemble.forest.RandomForestReg...   57.254540
# <class 'sklearn.ensemble.forest.ExtraTreesRegre...   44.926817
# <class 'sklearn.ensemble.weight_boosting.AdaBoo...   11.611704
# <class 'sklearn.ensemble.gradient_boosting.Grad...  126.552561
# <class 'sklearn.svm.classes.SVR'>                     0.575674

# %% [markdown]
# Tune Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error

candidate_alpha = []
alpha = 0.000001
for i in range(200):
    candidate_alpha.append(alpha)
    alpha += 0.000005
mae_list = []

for alpha in candidate_alpha:
    
    # initialize a Lasso model
    lasso = Lasso(alpha)

    # fit training data
    model_lasso = lasso.fit(x_train_std,y_train)

    # predict on test data
    y_pred_lasso = model_lasso.predict(x_test_std)
    
    # calculate mae
    mae = mean_absolute_error(y_test, y_pred_lasso)
    
    # append to list
    mae_list.append(mae)

# %%
plt.plot(candidate_alpha, mae_list)
plt.xlabel("alphas")
plt.ylabel("MAE")
plt.title("Hyperparameter tuning in Lasso Regression")
plt.show()

# %%
best_alpha = candidate_alpha[mae_list.index(min(mae_list))]
best_alpha
# Out:
# 0.000111

# %%
lasso = Lasso(best_alpha)
model_lasso = lasso.fit(x_train_std,y_train)
lasso_17 = Lasso(best_alpha)
model_lasso_17 = lasso_17.fit(x_17_train_std,y_17_train)

# %% [markdown]
# Feature selection

# %%
parameter_16 = model_lasso.coef_
parameter_17 = model_lasso_17.coef_
print(parameter_16)
# Out:
# [ 0.00000000e+00  3.84864044e-04 -2.16585332e-04  2.54245156e-04
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  5.94282254e-04
#  -3.64287704e-04  0.00000000e+00 -1.75571394e-04  6.35247653e-05
#  -7.53012821e-05 -3.85440514e-04  0.00000000e+00 -3.91134296e-04
#   6.99326421e-03  0.00000000e+00  0.00000000e+00  2.16748425e-03
#  -0.00000000e+00  0.00000000e+00  1.05649322e-03 -7.60092553e-17
#  -1.98713345e-03  0.00000000e+00  6.52984382e-04 -2.50753506e-17
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -1.71992692e-04  0.00000000e+00 -1.18230863e-07 -0.00000000e+00
#  -1.77244506e-04 -8.06077152e-04  2.42596720e-05  5.21996501e-04
#   6.96518430e-03 -0.00000000e+00  3.32272447e-04  1.33865899e-03
#   1.08137905e-03  0.00000000e+00  1.43889548e-03  0.00000000e+00
#   0.00000000e+00  1.71213542e-03 -3.98791802e-17  2.59873760e-03
#  -2.45925891e-16  0.00000000e+00  2.72800273e-04 -0.00000000e+00
#   0.00000000e+00 -5.44332707e-05 -5.37215493e-04  1.66973652e-04
#  -0.00000000e+00  3.09674073e-05  3.18826973e-04  4.44936534e-04
#   1.73667394e-03 -0.00000000e+00 -7.76242338e-05  5.63760485e-06
#   4.07196158e-04 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -2.21454022e-04  5.00817622e-04
#   6.96017037e-05  4.10688168e-04  3.34339725e-04 -1.89764192e-04
#  -1.44038663e-04 -7.30509120e-04 -4.75665120e-04  0.00000000e+00
#  -1.01594695e-04  0.00000000e+00  3.49418716e-04  0.00000000e+00
#  -1.88561578e-04  4.70071778e-04  1.53462448e-04  3.10132497e-04
#  -6.35732848e-04 -9.17931738e-05 -0.00000000e+00  0.00000000e+00
#  -2.73756023e-04 -1.35636153e-04  0.00000000e+00 -1.23000728e-04
#  -7.75098516e-04 -1.92527207e-04 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -1.06838000e-02 -1.40306891e-03  1.12845497e-16
#   0.00000000e+00 -1.63665638e-03  0.00000000e+00  9.76502079e-04]

# %%
negative_index =z_16_clustering[z_16_clustering.columns.difference(['logerror'])].columns[np.argwhere(parameter_16<-1e-6).reshape(1,-1)][0,]
negative_index_17 = z_17_clustering[z_17_clustering.columns.difference(['logerror'])].columns[np.argwhere(parameter_17<-1e-6).reshape(1,-1)][0,]
print(negative_index)
# Out:
# Index(['airconditioningtypeid_13.0', 'bedroomcnt', 'buildingqualitytypeid_1.0',
#        'buildingqualitytypeid_12.0', 'buildingqualitytypeid_4.0',
#        'buildingqualitytypeid_8.0', 'garagecarcnt',
#        'heatingorsystemtypeid_13.0', 'heatingorsystemtypeid_20.0',
#        'heatingorsystemtypeid_24.0', 'propertylandusetypeid_247.0',
#        'propertylandusetypeid_248.0', 'propertylandusetypeid_269.0',
#        'regionidzip_52', 'regionidzip_57', 'regionidzip_58', 'regionidzip_59',
#        'regionidzip_60', 'regionidzip_62', 'regionidzip_66', 'regionidzip_70',
#        'regionidzip_71', 'regionidzip_74', 'regionidzip_75', 'regionidzip_77',
#        'regionidzip_78', 'regionidzip_79', 'taxamount', 'taxdelinquencyflag_N',
#        'unitcnt'],
#       dtype='object')

# %%
positive_index =z_16_clustering[z_16_clustering.columns.difference(['logerror'])].columns[np.argwhere(parameter_16>1e-6).reshape(1,-1)][0,]
positive_index_17 = z_17_clustering[z_17_clustering.columns.difference(['logerror'])].columns[np.argwhere(parameter_17>1e-6).reshape(1,-1)][0,]
print(positive_index)
# Out:
# Index(['airconditioningtypeid_11.0', 'airconditioningtypeid_3.0',
#        'bathroomcnt', 'buildingqualitytypeid_10.0',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'fireplaceflag_No', 'hashottuborspa_False', 'heatingorsystemtypeid_6.0',
#        'heatingorsystemtypeid_7.0', 'landtaxvaluedollarcnt', 'longitude',
#        'lotsizesquarefeet', 'month', 'parcelid', 'pooltypeid2_0.0',
#        'pooltypeid7_0.0', 'propertycountylandusecode_Multi-family Residence',
#        'propertylandusetypeid_260.0', 'propertylandusetypeid_263.0',
#        'propertylandusetypeid_264.0', 'propertylandusetypeid_265.0',
#        'propertylandusetypeid_266.0', 'propertylandusetypeid_275.0',
#        'propertylandusetypeid_31.0', 'regionidzip_53', 'regionidzip_54',
#        'regionidzip_55', 'regionidzip_56', 'regionidzip_64', 'regionidzip_67',
#        'regionidzip_68', 'regionidzip_69', 'yearbuilt'],
#       dtype='object')

# %%
z_16_lasso = z_16_clustering[np.hstack([positive_index ,negative_index])]
z_17_lasso = z_17_clustering[np.hstack([positive_index_17 ,negative_index_17])]

# %%
x_lasso = z_16_lasso.values
y_lasso = z_16_clustering['logerror'].values
x_17_lasso = z_17_lasso.values
y_17_lasso = z_17_clustering['logerror'].values

# Split data into train and test (80% & 20%)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state = 0)
x_17_train, x_17_test, y_17_train, y_17_test = train_test_split(
    x_17, y_17, test_size = 0.2, random_state = 0)

# %%
# initialize a scaler object
scaler = StandardScaler()

# transform training set
x_train_std = scaler.fit_transform(x_train)

# the same transform for test set
x_test_std = scaler.transform(x_test)

# transform whole dataset 
X = scaler.fit_transform(x)

# initialize a scaler object
scaler = StandardScaler()

# transform training set
x_17_train_std = scaler.fit_transform(x_17_train)

# the same transform for test set
x_17_test_std = scaler.transform(x_17_test)

# transform whole dataset 
X_17 = scaler.fit_transform(x_17)

# %% [markdown]
# Catboost

# %%
cb = CatBoostRegressor(learning_rate = 0.09, depth = 9)
cb.fit(x_train_std, y_train)
cb_17 = CatBoostRegressor()
cb_17.fit(x_17_train_std, y_17_train)
# Out:
# 0:	learn: 0.0609766	total: 110ms	remaining: 1m 49s
# 1:	learn: 0.0608300	total: 199ms	remaining: 1m 39s
# 2:	learn: 0.0607066	total: 293ms	remaining: 1m 37s
# 3:	learn: 0.0605941	total: 397ms	remaining: 1m 38s
# 4:	learn: 0.0605035	total: 485ms	remaining: 1m 36s
# 5:	learn: 0.0604127	total: 572ms	remaining: 1m 34s
# 6:	learn: 0.0603348	total: 664ms	remaining: 1m 34s
# 7:	learn: 0.0602487	total: 755ms	remaining: 1m 33s
# 8:	learn: 0.0601710	total: 834ms	remaining: 1m 31s
# 9:	learn: 0.0601059	total: 922ms	remaining: 1m 31s
# 10:	learn: 0.0600367	total: 1.01s	remaining: 1m 30s
# 11:	learn: 0.0599785	total: 1.09s	remaining: 1m 29s
# 12:	learn: 0.0599158	total: 1.18s	remaining: 1m 29s
# 13:	learn: 0.0598743	total: 1.27s	remaining: 1m 29s
# 14:	learn: 0.0598375	total: 1.36s	remaining: 1m 29s
# 15:	learn: 0.0597878	total: 1.44s	remaining: 1m 28s
# 16:	learn: 0.0597422	total: 1.54s	remaining: 1m 28s
# 17:	learn: 0.0597092	total: 1.63s	remaining: 1m 28s
# 18:	learn: 0.0596684	total: 1.73s	remaining: 1m 29s
# 19:	learn: 0.0596265	total: 1.82s	remaining: 1m 29s
# 20:	learn: 0.0595964	total: 1.91s	remaining: 1m 28s
# 21:	learn: 0.0595664	total: 2s	remaining: 1m 29s
# 22:	learn: 0.0595315	total: 2.12s	remaining: 1m 30s
# 23:	learn: 0.0595020	total: 2.23s	remaining: 1m 30s
# 24:	learn: 0.0594702	total: 2.33s	remaining: 1m 31s
# 25:	learn: 0.0594367	total: 2.44s	remaining: 1m 31s
# 26:	learn: 0.0593912	total: 2.52s	remaining: 1m 30s
# 27:	learn: 0.0593709	total: 2.62s	remaining: 1m 30s
# 28:	learn: 0.0593517	total: 2.7s	remaining: 1m 30s
# 29:	learn: 0.0593240	total: 2.8s	remaining: 1m 30s
# 30:	learn: 0.0592981	total: 2.9s	remaining: 1m 30s
# 31:	learn: 0.0592518	total: 3.02s	remaining: 1m 31s
# 32:	learn: 0.0592283	total: 3.13s	remaining: 1m 31s
# 33:	learn: 0.0591992	total: 3.22s	remaining: 1m 31s
# 34:	learn: 0.0591729	total: 3.32s	remaining: 1m 31s
# 35:	learn: 0.0591423	total: 3.41s	remaining: 1m 31s
# 36:	learn: 0.0591203	total: 3.5s	remaining: 1m 31s
# 37:	learn: 0.0591089	total: 3.59s	remaining: 1m 30s
# 38:	learn: 0.0590740	total: 3.67s	remaining: 1m 30s
# 39:	learn: 0.0590536	total: 3.76s	remaining: 1m 30s
# 40:	learn: 0.0590339	total: 3.85s	remaining: 1m 30s
# 41:	learn: 0.0590016	total: 3.94s	remaining: 1m 29s
# 42:	learn: 0.0589826	total: 4.03s	remaining: 1m 29s
# 43:	learn: 0.0589644	total: 4.12s	remaining: 1m 29s
# 44:	learn: 0.0589487	total: 4.2s	remaining: 1m 29s
# 45:	learn: 0.0589322	total: 4.29s	remaining: 1m 29s
# 46:	learn: 0.0589086	total: 4.38s	remaining: 1m 28s
# 47:	learn: 0.0588698	total: 4.47s	remaining: 1m 28s
# 48:	learn: 0.0588574	total: 4.56s	remaining: 1m 28s
# 49:	learn: 0.0588350	total: 4.65s	remaining: 1m 28s
# 50:	learn: 0.0588213	total: 4.73s	remaining: 1m 27s
# 51:	learn: 0.0587963	total: 4.82s	remaining: 1m 27s
# 52:	learn: 0.0587780	total: 4.9s	remaining: 1m 27s
# 53:	learn: 0.0587597	total: 4.98s	remaining: 1m 27s
# 54:	learn: 0.0587317	total: 5.07s	remaining: 1m 27s
# 55:	learn: 0.0586992	total: 5.19s	remaining: 1m 27s
# 56:	learn: 0.0586792	total: 5.28s	remaining: 1m 27s
# 57:	learn: 0.0586526	total: 5.38s	remaining: 1m 27s
# 58:	learn: 0.0586335	total: 5.47s	remaining: 1m 27s
# 59:	learn: 0.0586140	total: 5.57s	remaining: 1m 27s
# 60:	learn: 0.0585951	total: 5.66s	remaining: 1m 27s
# 61:	learn: 0.0585786	total: 5.74s	remaining: 1m 26s
# 62:	learn: 0.0585584	total: 5.82s	remaining: 1m 26s
# 63:	learn: 0.0585437	total: 5.91s	remaining: 1m 26s
# 64:	learn: 0.0585285	total: 5.99s	remaining: 1m 26s
# 65:	learn: 0.0585229	total: 6.08s	remaining: 1m 25s
# 66:	learn: 0.0585051	total: 6.19s	remaining: 1m 26s
# 67:	learn: 0.0584788	total: 6.29s	remaining: 1m 26s
# 68:	learn: 0.0584608	total: 6.4s	remaining: 1m 26s
# 69:	learn: 0.0584477	total: 6.51s	remaining: 1m 26s
# 70:	learn: 0.0584286	total: 6.6s	remaining: 1m 26s
# 71:	learn: 0.0584123	total: 6.68s	remaining: 1m 26s
# 72:	learn: 0.0583881	total: 6.77s	remaining: 1m 25s
# 73:	learn: 0.0583695	total: 6.87s	remaining: 1m 25s
# 74:	learn: 0.0583557	total: 6.95s	remaining: 1m 25s
# 75:	learn: 0.0583414	total: 7.08s	remaining: 1m 26s
# 76:	learn: 0.0583264	total: 7.18s	remaining: 1m 26s
# 77:	learn: 0.0582983	total: 7.29s	remaining: 1m 26s
# 78:	learn: 0.0582844	total: 7.37s	remaining: 1m 25s
# 79:	learn: 0.0582717	total: 7.47s	remaining: 1m 25s
# 80:	learn: 0.0582384	total: 7.58s	remaining: 1m 26s
# 81:	learn: 0.0582237	total: 7.69s	remaining: 1m 26s
# 82:	learn: 0.0581927	total: 7.8s	remaining: 1m 26s
# 83:	learn: 0.0581790	total: 7.9s	remaining: 1m 26s
# 84:	learn: 0.0581594	total: 8.01s	remaining: 1m 26s
# 85:	learn: 0.0581373	total: 8.12s	remaining: 1m 26s
# 86:	learn: 0.0581271	total: 8.23s	remaining: 1m 26s
# 87:	learn: 0.0581115	total: 8.34s	remaining: 1m 26s
# 88:	learn: 0.0580989	total: 8.42s	remaining: 1m 26s
# 89:	learn: 0.0580827	total: 8.52s	remaining: 1m 26s
# 90:	learn: 0.0580547	total: 8.61s	remaining: 1m 25s
# 91:	learn: 0.0580231	total: 8.7s	remaining: 1m 25s
# 92:	learn: 0.0580050	total: 8.78s	remaining: 1m 25s
# 93:	learn: 0.0579840	total: 8.88s	remaining: 1m 25s
# 94:	learn: 0.0579629	total: 8.96s	remaining: 1m 25s
# 95:	learn: 0.0579369	total: 9.05s	remaining: 1m 25s
# 96:	learn: 0.0579293	total: 9.13s	remaining: 1m 24s
# 97:	learn: 0.0579120	total: 9.21s	remaining: 1m 24s
# 98:	learn: 0.0578938	total: 9.29s	remaining: 1m 24s
# 99:	learn: 0.0578847	total: 9.38s	remaining: 1m 24s
# 100:	learn: 0.0578706	total: 9.45s	remaining: 1m 24s
# 101:	learn: 0.0578575	total: 9.54s	remaining: 1m 23s
# 102:	learn: 0.0578425	total: 9.63s	remaining: 1m 23s
# 103:	learn: 0.0578213	total: 9.72s	remaining: 1m 23s
# 104:	learn: 0.0578011	total: 9.8s	remaining: 1m 23s
# 105:	learn: 0.0577870	total: 9.88s	remaining: 1m 23s
# 106:	learn: 0.0577729	total: 9.97s	remaining: 1m 23s
# 107:	learn: 0.0577508	total: 10.1s	remaining: 1m 23s
# 108:	learn: 0.0577339	total: 10.2s	remaining: 1m 23s
# 109:	learn: 0.0577130	total: 10.3s	remaining: 1m 23s
# 110:	learn: 0.0577005	total: 10.4s	remaining: 1m 23s
# 111:	learn: 0.0576857	total: 10.5s	remaining: 1m 23s
# 112:	learn: 0.0576688	total: 10.6s	remaining: 1m 23s
# 113:	learn: 0.0576441	total: 10.7s	remaining: 1m 23s
# 114:	learn: 0.0576343	total: 10.8s	remaining: 1m 22s
# 115:	learn: 0.0576237	total: 10.8s	remaining: 1m 22s
# 116:	learn: 0.0576089	total: 10.9s	remaining: 1m 22s
# 117:	learn: 0.0575853	total: 11.1s	remaining: 1m 22s
# 118:	learn: 0.0575657	total: 11.2s	remaining: 1m 22s
# 119:	learn: 0.0575594	total: 11.3s	remaining: 1m 22s
# 120:	learn: 0.0575437	total: 11.3s	remaining: 1m 22s
# 121:	learn: 0.0575252	total: 11.5s	remaining: 1m 22s
# 122:	learn: 0.0575155	total: 11.6s	remaining: 1m 22s
# 123:	learn: 0.0574988	total: 11.7s	remaining: 1m 22s
# 124:	learn: 0.0574836	total: 11.8s	remaining: 1m 22s
# 125:	learn: 0.0574665	total: 11.9s	remaining: 1m 22s
# 126:	learn: 0.0574524	total: 12s	remaining: 1m 22s
# 127:	learn: 0.0574369	total: 12.2s	remaining: 1m 22s
# 128:	learn: 0.0574155	total: 12.3s	remaining: 1m 22s
# 129:	learn: 0.0573998	total: 12.4s	remaining: 1m 22s
# 130:	learn: 0.0573874	total: 12.5s	remaining: 1m 22s
# 131:	learn: 0.0573661	total: 12.6s	remaining: 1m 22s
# 132:	learn: 0.0573481	total: 12.7s	remaining: 1m 22s
# 133:	learn: 0.0573233	total: 12.8s	remaining: 1m 22s
# 134:	learn: 0.0572994	total: 12.9s	remaining: 1m 22s
# 135:	learn: 0.0572886	total: 13s	remaining: 1m 22s
# 136:	learn: 0.0572728	total: 13.1s	remaining: 1m 22s
# 137:	learn: 0.0572602	total: 13.2s	remaining: 1m 22s
# 138:	learn: 0.0572357	total: 13.3s	remaining: 1m 22s
# 139:	learn: 0.0572163	total: 13.4s	remaining: 1m 22s
# 140:	learn: 0.0571999	total: 13.6s	remaining: 1m 22s
# 141:	learn: 0.0571834	total: 13.7s	remaining: 1m 22s
# 142:	learn: 0.0571573	total: 13.8s	remaining: 1m 22s
# 143:	learn: 0.0571430	total: 13.9s	remaining: 1m 22s
# 144:	learn: 0.0571307	total: 14s	remaining: 1m 22s
# 145:	learn: 0.0571086	total: 14.1s	remaining: 1m 22s
# 146:	learn: 0.0570920	total: 14.2s	remaining: 1m 22s
# 147:	learn: 0.0570645	total: 14.3s	remaining: 1m 22s
# 148:	learn: 0.0570432	total: 14.3s	remaining: 1m 21s
# 149:	learn: 0.0570186	total: 14.4s	remaining: 1m 21s
# 150:	learn: 0.0570040	total: 14.5s	remaining: 1m 21s
# 151:	learn: 0.0569903	total: 14.6s	remaining: 1m 21s
# 152:	learn: 0.0569724	total: 14.7s	remaining: 1m 21s
# 153:	learn: 0.0569557	total: 14.8s	remaining: 1m 21s
# 154:	learn: 0.0569417	total: 14.9s	remaining: 1m 21s
# 155:	learn: 0.0569303	total: 15s	remaining: 1m 20s
# 156:	learn: 0.0569117	total: 15.1s	remaining: 1m 20s
# 157:	learn: 0.0568935	total: 15.2s	remaining: 1m 20s
# 158:	learn: 0.0568797	total: 15.2s	remaining: 1m 20s
# 159:	learn: 0.0568621	total: 15.3s	remaining: 1m 20s
# 160:	learn: 0.0568510	total: 15.4s	remaining: 1m 20s
# 161:	learn: 0.0568311	total: 15.5s	remaining: 1m 20s
# 162:	learn: 0.0568175	total: 15.6s	remaining: 1m 20s
# 163:	learn: 0.0568041	total: 15.7s	remaining: 1m 19s
# 164:	learn: 0.0567801	total: 15.8s	remaining: 1m 19s
# 165:	learn: 0.0567632	total: 15.8s	remaining: 1m 19s
# 166:	learn: 0.0567400	total: 15.9s	remaining: 1m 19s
# 167:	learn: 0.0567252	total: 16s	remaining: 1m 19s
# 168:	learn: 0.0567118	total: 16.1s	remaining: 1m 19s
# 169:	learn: 0.0566926	total: 16.2s	remaining: 1m 18s
# 170:	learn: 0.0566751	total: 16.3s	remaining: 1m 18s
# 171:	learn: 0.0566573	total: 16.4s	remaining: 1m 18s
# 172:	learn: 0.0566407	total: 16.4s	remaining: 1m 18s
# 173:	learn: 0.0566255	total: 16.5s	remaining: 1m 18s
# 174:	learn: 0.0566135	total: 16.6s	remaining: 1m 18s
# 175:	learn: 0.0565969	total: 16.7s	remaining: 1m 18s
# 176:	learn: 0.0565848	total: 16.8s	remaining: 1m 18s
# 177:	learn: 0.0565751	total: 16.9s	remaining: 1m 18s
# 178:	learn: 0.0565617	total: 17.1s	remaining: 1m 18s
# 179:	learn: 0.0565439	total: 17.2s	remaining: 1m 18s
# 180:	learn: 0.0565205	total: 17.2s	remaining: 1m 18s
# 181:	learn: 0.0565062	total: 17.3s	remaining: 1m 17s
# 182:	learn: 0.0564964	total: 17.4s	remaining: 1m 17s
# 183:	learn: 0.0564844	total: 17.5s	remaining: 1m 17s
# 184:	learn: 0.0564705	total: 17.6s	remaining: 1m 17s
# 185:	learn: 0.0564575	total: 17.7s	remaining: 1m 17s
# 186:	learn: 0.0564397	total: 17.8s	remaining: 1m 17s
# 187:	learn: 0.0564220	total: 17.9s	remaining: 1m 17s
# 188:	learn: 0.0564102	total: 18s	remaining: 1m 17s
# 189:	learn: 0.0563888	total: 18.1s	remaining: 1m 16s
# 190:	learn: 0.0563684	total: 18.1s	remaining: 1m 16s
# 191:	learn: 0.0563522	total: 18.2s	remaining: 1m 16s
# 192:	learn: 0.0563301	total: 18.3s	remaining: 1m 16s
# 193:	learn: 0.0563199	total: 18.4s	remaining: 1m 16s
# 194:	learn: 0.0563014	total: 18.5s	remaining: 1m 16s
# 195:	learn: 0.0562939	total: 18.6s	remaining: 1m 16s
# 196:	learn: 0.0562770	total: 18.7s	remaining: 1m 16s
# 197:	learn: 0.0562588	total: 18.8s	remaining: 1m 16s
# 198:	learn: 0.0562420	total: 18.9s	remaining: 1m 16s
# 199:	learn: 0.0562234	total: 19s	remaining: 1m 16s
# 200:	learn: 0.0562040	total: 19.1s	remaining: 1m 15s
# 201:	learn: 0.0561898	total: 19.2s	remaining: 1m 15s
# 202:	learn: 0.0561750	total: 19.3s	remaining: 1m 15s
# 203:	learn: 0.0561640	total: 19.4s	remaining: 1m 15s
# 204:	learn: 0.0561443	total: 19.4s	remaining: 1m 15s
# 205:	learn: 0.0561316	total: 19.5s	remaining: 1m 15s
# 206:	learn: 0.0561108	total: 19.6s	remaining: 1m 15s
# 207:	learn: 0.0560896	total: 19.7s	remaining: 1m 15s
# 208:	learn: 0.0560712	total: 19.8s	remaining: 1m 15s
# 209:	learn: 0.0560444	total: 19.9s	remaining: 1m 14s
# 210:	learn: 0.0560265	total: 20s	remaining: 1m 14s
# 211:	learn: 0.0560096	total: 20.1s	remaining: 1m 14s
# 212:	learn: 0.0559947	total: 20.2s	remaining: 1m 14s
# 213:	learn: 0.0559845	total: 20.3s	remaining: 1m 14s
# 214:	learn: 0.0559630	total: 20.4s	remaining: 1m 14s
# 215:	learn: 0.0559396	total: 20.5s	remaining: 1m 14s
# 216:	learn: 0.0559150	total: 20.6s	remaining: 1m 14s
# 217:	learn: 0.0558979	total: 20.7s	remaining: 1m 14s
# 218:	learn: 0.0558835	total: 20.7s	remaining: 1m 13s
# 219:	learn: 0.0558746	total: 20.8s	remaining: 1m 13s
# 220:	learn: 0.0558580	total: 20.9s	remaining: 1m 13s
# 221:	learn: 0.0558365	total: 21s	remaining: 1m 13s
# 222:	learn: 0.0558257	total: 21.1s	remaining: 1m 13s
# 223:	learn: 0.0558000	total: 21.2s	remaining: 1m 13s
# 224:	learn: 0.0557835	total: 21.3s	remaining: 1m 13s
# 225:	learn: 0.0557668	total: 21.3s	remaining: 1m 13s
# 226:	learn: 0.0557574	total: 21.4s	remaining: 1m 12s
# 227:	learn: 0.0557433	total: 21.5s	remaining: 1m 12s
# 228:	learn: 0.0557225	total: 21.6s	remaining: 1m 12s
# 229:	learn: 0.0557115	total: 21.7s	remaining: 1m 12s
# 230:	learn: 0.0557038	total: 21.8s	remaining: 1m 12s
# 231:	learn: 0.0556899	total: 21.9s	remaining: 1m 12s
# 232:	learn: 0.0556770	total: 22s	remaining: 1m 12s
# 233:	learn: 0.0556607	total: 22.1s	remaining: 1m 12s
# 234:	learn: 0.0556511	total: 22.2s	remaining: 1m 12s
# 235:	learn: 0.0556335	total: 22.3s	remaining: 1m 12s
# 236:	learn: 0.0556174	total: 22.4s	remaining: 1m 12s
# 237:	learn: 0.0555896	total: 22.5s	remaining: 1m 12s
# 238:	learn: 0.0555759	total: 22.6s	remaining: 1m 11s
# 239:	learn: 0.0555545	total: 22.7s	remaining: 1m 11s
# 240:	learn: 0.0555432	total: 22.7s	remaining: 1m 11s
# 241:	learn: 0.0555250	total: 22.8s	remaining: 1m 11s
# 242:	learn: 0.0555092	total: 22.9s	remaining: 1m 11s
# 243:	learn: 0.0554946	total: 23s	remaining: 1m 11s
# 244:	learn: 0.0554818	total: 23.1s	remaining: 1m 11s
# 245:	learn: 0.0554681	total: 23.2s	remaining: 1m 11s
# 246:	learn: 0.0554542	total: 23.3s	remaining: 1m 10s
# 247:	learn: 0.0554366	total: 23.4s	remaining: 1m 10s
# 248:	learn: 0.0554169	total: 23.5s	remaining: 1m 10s
# 249:	learn: 0.0554040	total: 23.5s	remaining: 1m 10s
# 250:	learn: 0.0553903	total: 23.6s	remaining: 1m 10s
# 251:	learn: 0.0553743	total: 23.7s	remaining: 1m 10s
# 252:	learn: 0.0553624	total: 23.8s	remaining: 1m 10s
# 253:	learn: 0.0553499	total: 23.9s	remaining: 1m 10s
# 254:	learn: 0.0553366	total: 24s	remaining: 1m 9s
# 255:	learn: 0.0553235	total: 24s	remaining: 1m 9s
# 256:	learn: 0.0553099	total: 24.1s	remaining: 1m 9s
# 257:	learn: 0.0553009	total: 24.2s	remaining: 1m 9s
# 258:	learn: 0.0552865	total: 24.3s	remaining: 1m 9s
# 259:	learn: 0.0552683	total: 24.4s	remaining: 1m 9s
# 260:	learn: 0.0552571	total: 24.5s	remaining: 1m 9s
# 261:	learn: 0.0552458	total: 24.6s	remaining: 1m 9s
# 262:	learn: 0.0552345	total: 24.6s	remaining: 1m 9s
# 263:	learn: 0.0552250	total: 24.7s	remaining: 1m 8s
# 264:	learn: 0.0552037	total: 24.8s	remaining: 1m 8s
# 265:	learn: 0.0551873	total: 24.9s	remaining: 1m 8s
# 266:	learn: 0.0551682	total: 25s	remaining: 1m 8s
# 267:	learn: 0.0551519	total: 25.1s	remaining: 1m 8s
# 268:	learn: 0.0551354	total: 25.1s	remaining: 1m 8s
# 269:	learn: 0.0551210	total: 25.2s	remaining: 1m 8s
# 270:	learn: 0.0551087	total: 25.3s	remaining: 1m 8s
# 271:	learn: 0.0550966	total: 25.4s	remaining: 1m 7s
# 272:	learn: 0.0550845	total: 25.5s	remaining: 1m 7s
# 273:	learn: 0.0550675	total: 25.5s	remaining: 1m 7s
# 274:	learn: 0.0550596	total: 25.6s	remaining: 1m 7s
# 275:	learn: 0.0550491	total: 25.7s	remaining: 1m 7s
# 276:	learn: 0.0550375	total: 25.8s	remaining: 1m 7s
# 277:	learn: 0.0550249	total: 25.9s	remaining: 1m 7s
# 278:	learn: 0.0550136	total: 25.9s	remaining: 1m 7s
# 279:	learn: 0.0549998	total: 26s	remaining: 1m 6s
# 280:	learn: 0.0549845	total: 26.1s	remaining: 1m 6s
# 281:	learn: 0.0549726	total: 26.2s	remaining: 1m 6s
# 282:	learn: 0.0549607	total: 26.3s	remaining: 1m 6s
# 283:	learn: 0.0549441	total: 26.4s	remaining: 1m 6s
# 284:	learn: 0.0549361	total: 26.4s	remaining: 1m 6s
# 285:	learn: 0.0549190	total: 26.5s	remaining: 1m 6s
# 286:	learn: 0.0548926	total: 26.6s	remaining: 1m 6s
# 287:	learn: 0.0548690	total: 26.7s	remaining: 1m 5s
# 288:	learn: 0.0548418	total: 26.8s	remaining: 1m 5s
# 289:	learn: 0.0548339	total: 26.8s	remaining: 1m 5s
# 290:	learn: 0.0548201	total: 26.9s	remaining: 1m 5s
# 291:	learn: 0.0548020	total: 27s	remaining: 1m 5s
# 292:	learn: 0.0547824	total: 27.1s	remaining: 1m 5s
# 293:	learn: 0.0547659	total: 27.2s	remaining: 1m 5s
# 294:	learn: 0.0547459	total: 27.3s	remaining: 1m 5s
# 295:	learn: 0.0547310	total: 27.3s	remaining: 1m 5s
# 296:	learn: 0.0547218	total: 27.4s	remaining: 1m 4s
# 297:	learn: 0.0547103	total: 27.5s	remaining: 1m 4s
# 298:	learn: 0.0546980	total: 27.6s	remaining: 1m 4s
# 299:	learn: 0.0546843	total: 27.7s	remaining: 1m 4s
# 300:	learn: 0.0546744	total: 27.8s	remaining: 1m 4s
# 301:	learn: 0.0546582	total: 27.8s	remaining: 1m 4s
# 302:	learn: 0.0546470	total: 27.9s	remaining: 1m 4s
# 303:	learn: 0.0546297	total: 28s	remaining: 1m 4s
# 304:	learn: 0.0546136	total: 28.1s	remaining: 1m 3s
# 305:	learn: 0.0546018	total: 28.2s	remaining: 1m 3s
# 306:	learn: 0.0545884	total: 28.2s	remaining: 1m 3s
# 307:	learn: 0.0545754	total: 28.3s	remaining: 1m 3s
# 308:	learn: 0.0545621	total: 28.4s	remaining: 1m 3s
# 309:	learn: 0.0545492	total: 28.5s	remaining: 1m 3s
# 310:	learn: 0.0545295	total: 28.6s	remaining: 1m 3s
# 311:	learn: 0.0545169	total: 28.6s	remaining: 1m 3s
# 312:	learn: 0.0545084	total: 28.7s	remaining: 1m 3s
# 313:	learn: 0.0544985	total: 28.8s	remaining: 1m 2s
# 314:	learn: 0.0544860	total: 28.9s	remaining: 1m 2s
# 315:	learn: 0.0544731	total: 29s	remaining: 1m 2s
# 316:	learn: 0.0544487	total: 29.1s	remaining: 1m 2s
# 317:	learn: 0.0544303	total: 29.1s	remaining: 1m 2s
# 318:	learn: 0.0544134	total: 29.2s	remaining: 1m 2s
# 319:	learn: 0.0544000	total: 29.3s	remaining: 1m 2s
# 320:	learn: 0.0543874	total: 29.4s	remaining: 1m 2s
# 321:	learn: 0.0543749	total: 29.5s	remaining: 1m 2s
# 322:	learn: 0.0543589	total: 29.5s	remaining: 1m 1s
# 323:	learn: 0.0543447	total: 29.6s	remaining: 1m 1s
# 324:	learn: 0.0543345	total: 29.7s	remaining: 1m 1s
# 325:	learn: 0.0543255	total: 29.8s	remaining: 1m 1s
# 326:	learn: 0.0542988	total: 29.9s	remaining: 1m 1s
# 327:	learn: 0.0542826	total: 29.9s	remaining: 1m 1s
# 328:	learn: 0.0542675	total: 30s	remaining: 1m 1s
# 329:	learn: 0.0542533	total: 30.1s	remaining: 1m 1s
# 330:	learn: 0.0542387	total: 30.2s	remaining: 1m 1s
# 331:	learn: 0.0542199	total: 30.3s	remaining: 1m
# 332:	learn: 0.0542038	total: 30.3s	remaining: 1m
# 333:	learn: 0.0541871	total: 30.4s	remaining: 1m
# 334:	learn: 0.0541781	total: 30.5s	remaining: 1m
# 335:	learn: 0.0541642	total: 30.6s	remaining: 1m
# 336:	learn: 0.0541561	total: 30.7s	remaining: 1m
# 337:	learn: 0.0541471	total: 30.8s	remaining: 1m
# 338:	learn: 0.0541302	total: 30.8s	remaining: 1m
# 339:	learn: 0.0541165	total: 30.9s	remaining: 1m
# 340:	learn: 0.0541047	total: 31s	remaining: 59.9s
# 341:	learn: 0.0540918	total: 31.1s	remaining: 59.8s
# 342:	learn: 0.0540760	total: 31.2s	remaining: 59.7s
# 343:	learn: 0.0540630	total: 31.2s	remaining: 59.6s
# 344:	learn: 0.0540451	total: 31.3s	remaining: 59.5s
# 345:	learn: 0.0540397	total: 31.4s	remaining: 59.4s
# 346:	learn: 0.0540302	total: 31.5s	remaining: 59.3s
# 347:	learn: 0.0540180	total: 31.6s	remaining: 59.1s
# 348:	learn: 0.0540014	total: 31.6s	remaining: 59s
# 349:	learn: 0.0539833	total: 31.7s	remaining: 58.9s
# 350:	learn: 0.0539717	total: 31.8s	remaining: 58.8s
# 351:	learn: 0.0539592	total: 31.9s	remaining: 58.7s
# 352:	learn: 0.0539419	total: 32s	remaining: 58.6s
# 353:	learn: 0.0539178	total: 32s	remaining: 58.5s
# 354:	learn: 0.0539043	total: 32.1s	remaining: 58.4s
# 355:	learn: 0.0538872	total: 32.2s	remaining: 58.3s
# 356:	learn: 0.0538730	total: 32.3s	remaining: 58.2s
# 357:	learn: 0.0538592	total: 32.4s	remaining: 58.1s
# 358:	learn: 0.0538517	total: 32.5s	remaining: 58s
# 359:	learn: 0.0538388	total: 32.5s	remaining: 57.8s
# 360:	learn: 0.0538244	total: 32.6s	remaining: 57.7s
# 361:	learn: 0.0538101	total: 32.7s	remaining: 57.6s
# 362:	learn: 0.0537945	total: 32.8s	remaining: 57.5s
# 363:	learn: 0.0537848	total: 32.9s	remaining: 57.4s
# 364:	learn: 0.0537764	total: 32.9s	remaining: 57.3s
# 365:	learn: 0.0537571	total: 33s	remaining: 57.2s
# 366:	learn: 0.0537391	total: 33.1s	remaining: 57.1s
# 367:	learn: 0.0537245	total: 33.2s	remaining: 57s
# 368:	learn: 0.0537123	total: 33.3s	remaining: 56.9s
# 369:	learn: 0.0537050	total: 33.4s	remaining: 56.8s
# 370:	learn: 0.0536944	total: 33.4s	remaining: 56.7s
# 371:	learn: 0.0536835	total: 33.5s	remaining: 56.6s
# 372:	learn: 0.0536769	total: 33.6s	remaining: 56.5s
# 373:	learn: 0.0536680	total: 33.7s	remaining: 56.4s
# 374:	learn: 0.0536567	total: 33.8s	remaining: 56.3s
# 375:	learn: 0.0536478	total: 33.8s	remaining: 56.2s
# 376:	learn: 0.0536366	total: 33.9s	remaining: 56.1s
# 377:	learn: 0.0536262	total: 34s	remaining: 56s
# 378:	learn: 0.0536110	total: 34.1s	remaining: 55.9s
# 379:	learn: 0.0535990	total: 34.2s	remaining: 55.8s
# 380:	learn: 0.0535822	total: 34.3s	remaining: 55.6s
# 381:	learn: 0.0535637	total: 34.3s	remaining: 55.5s
# 382:	learn: 0.0535493	total: 34.4s	remaining: 55.4s
# 383:	learn: 0.0535328	total: 34.5s	remaining: 55.3s
# 384:	learn: 0.0535200	total: 34.6s	remaining: 55.2s
# 385:	learn: 0.0535028	total: 34.7s	remaining: 55.2s
# 386:	learn: 0.0534931	total: 34.8s	remaining: 55.1s
# 387:	learn: 0.0534840	total: 34.9s	remaining: 55s
# 388:	learn: 0.0534724	total: 35s	remaining: 54.9s
# 389:	learn: 0.0534675	total: 35.1s	remaining: 54.8s
# 390:	learn: 0.0534539	total: 35.1s	remaining: 54.7s
# 391:	learn: 0.0534447	total: 35.3s	remaining: 54.7s
# 392:	learn: 0.0534331	total: 35.4s	remaining: 54.6s
# 393:	learn: 0.0534195	total: 35.5s	remaining: 54.6s
# 394:	learn: 0.0534148	total: 35.6s	remaining: 54.5s
# 395:	learn: 0.0534025	total: 35.7s	remaining: 54.5s
# 396:	learn: 0.0533870	total: 35.8s	remaining: 54.4s
# 397:	learn: 0.0533678	total: 35.9s	remaining: 54.3s
# 398:	learn: 0.0533528	total: 36s	remaining: 54.3s
# 399:	learn: 0.0533371	total: 36.1s	remaining: 54.2s
# 400:	learn: 0.0533247	total: 36.2s	remaining: 54.1s
# 401:	learn: 0.0533151	total: 36.3s	remaining: 54.1s
# 402:	learn: 0.0533056	total: 36.4s	remaining: 54s
# 403:	learn: 0.0532931	total: 36.5s	remaining: 53.9s
# 404:	learn: 0.0532838	total: 36.6s	remaining: 53.8s
# 405:	learn: 0.0532680	total: 36.7s	remaining: 53.7s
# 406:	learn: 0.0532561	total: 36.8s	remaining: 53.7s
# 407:	learn: 0.0532455	total: 36.9s	remaining: 53.6s
# 408:	learn: 0.0532316	total: 37s	remaining: 53.5s
# 409:	learn: 0.0532256	total: 37.1s	remaining: 53.4s
# 410:	learn: 0.0532068	total: 37.2s	remaining: 53.3s
# 411:	learn: 0.0531920	total: 37.3s	remaining: 53.3s
# 412:	learn: 0.0531814	total: 37.4s	remaining: 53.2s
# 413:	learn: 0.0531710	total: 37.5s	remaining: 53.1s
# 414:	learn: 0.0531600	total: 37.6s	remaining: 53s
# 415:	learn: 0.0531483	total: 37.7s	remaining: 52.9s
# 416:	learn: 0.0531360	total: 37.8s	remaining: 52.9s
# 417:	learn: 0.0531229	total: 37.9s	remaining: 52.8s
# 418:	learn: 0.0531072	total: 38s	remaining: 52.7s
# 419:	learn: 0.0530907	total: 38.1s	remaining: 52.6s
# 420:	learn: 0.0530836	total: 38.2s	remaining: 52.5s
# 421:	learn: 0.0530668	total: 38.3s	remaining: 52.5s
# 422:	learn: 0.0530566	total: 38.4s	remaining: 52.4s
# 423:	learn: 0.0530481	total: 38.5s	remaining: 52.3s
# 424:	learn: 0.0530390	total: 38.6s	remaining: 52.2s
# 425:	learn: 0.0530275	total: 38.7s	remaining: 52.1s
# 426:	learn: 0.0530201	total: 38.8s	remaining: 52s
# 427:	learn: 0.0530044	total: 38.9s	remaining: 51.9s
# 428:	learn: 0.0529944	total: 39s	remaining: 51.8s
# 429:	learn: 0.0529826	total: 39s	remaining: 51.8s
# 430:	learn: 0.0529733	total: 39.1s	remaining: 51.7s
# 431:	learn: 0.0529636	total: 39.2s	remaining: 51.6s
# 432:	learn: 0.0529472	total: 39.3s	remaining: 51.5s
# 433:	learn: 0.0529381	total: 39.4s	remaining: 51.4s
# 434:	learn: 0.0529283	total: 39.5s	remaining: 51.3s
# 435:	learn: 0.0529179	total: 39.6s	remaining: 51.2s
# 436:	learn: 0.0529050	total: 39.7s	remaining: 51.1s
# 437:	learn: 0.0528955	total: 39.8s	remaining: 51.1s
# 438:	learn: 0.0528803	total: 39.9s	remaining: 51s
# 439:	learn: 0.0528664	total: 40s	remaining: 50.9s
# 440:	learn: 0.0528614	total: 40.1s	remaining: 50.8s
# 441:	learn: 0.0528469	total: 40.1s	remaining: 50.7s
# 442:	learn: 0.0528376	total: 40.2s	remaining: 50.6s
# 443:	learn: 0.0528255	total: 40.3s	remaining: 50.5s
# 444:	learn: 0.0528145	total: 40.4s	remaining: 50.4s
# 445:	learn: 0.0528023	total: 40.5s	remaining: 50.3s
# 446:	learn: 0.0527920	total: 40.6s	remaining: 50.3s
# 447:	learn: 0.0527709	total: 40.7s	remaining: 50.2s
# 448:	learn: 0.0527525	total: 40.8s	remaining: 50.1s
# 449:	learn: 0.0527438	total: 40.9s	remaining: 50s
# 450:	learn: 0.0527262	total: 41s	remaining: 49.9s
# 451:	learn: 0.0527177	total: 41.1s	remaining: 49.8s
# 452:	learn: 0.0527045	total: 41.2s	remaining: 49.7s
# 453:	learn: 0.0526848	total: 41.3s	remaining: 49.6s
# 454:	learn: 0.0526726	total: 41.3s	remaining: 49.5s
# 455:	learn: 0.0526561	total: 41.4s	remaining: 49.4s
# 456:	learn: 0.0526437	total: 41.5s	remaining: 49.3s
# 457:	learn: 0.0526312	total: 41.6s	remaining: 49.2s
# 458:	learn: 0.0526140	total: 41.7s	remaining: 49.1s
# 459:	learn: 0.0526000	total: 41.7s	remaining: 49s
# 460:	learn: 0.0525873	total: 41.8s	remaining: 48.9s
# 461:	learn: 0.0525730	total: 41.9s	remaining: 48.8s
# 462:	learn: 0.0525609	total: 42s	remaining: 48.7s
# 463:	learn: 0.0525492	total: 42.1s	remaining: 48.6s
# 464:	learn: 0.0525335	total: 42.1s	remaining: 48.5s
# 465:	learn: 0.0525254	total: 42.2s	remaining: 48.4s
# 466:	learn: 0.0525123	total: 42.3s	remaining: 48.3s
# 467:	learn: 0.0525035	total: 42.4s	remaining: 48.2s
# 468:	learn: 0.0524903	total: 42.5s	remaining: 48.1s
# 469:	learn: 0.0524790	total: 42.5s	remaining: 48s
# 470:	learn: 0.0524692	total: 42.6s	remaining: 47.9s
# 471:	learn: 0.0524589	total: 42.7s	remaining: 47.8s
# 472:	learn: 0.0524502	total: 42.8s	remaining: 47.7s
# 473:	learn: 0.0524296	total: 42.9s	remaining: 47.6s
# 474:	learn: 0.0524175	total: 42.9s	remaining: 47.5s
# 475:	learn: 0.0524074	total: 43s	remaining: 47.4s
# 476:	learn: 0.0523997	total: 43.1s	remaining: 47.3s
# 477:	learn: 0.0523833	total: 43.2s	remaining: 47.2s
# 478:	learn: 0.0523717	total: 43.3s	remaining: 47.1s
# 479:	learn: 0.0523604	total: 43.3s	remaining: 47s
# 480:	learn: 0.0523484	total: 43.4s	remaining: 46.9s
# 481:	learn: 0.0523361	total: 43.5s	remaining: 46.8s
# 482:	learn: 0.0523278	total: 43.6s	remaining: 46.7s
# 483:	learn: 0.0523129	total: 43.7s	remaining: 46.6s
# 484:	learn: 0.0522978	total: 43.8s	remaining: 46.5s
# 485:	learn: 0.0522809	total: 43.8s	remaining: 46.4s
# 486:	learn: 0.0522662	total: 43.9s	remaining: 46.3s
# 487:	learn: 0.0522546	total: 44s	remaining: 46.2s
# 488:	learn: 0.0522437	total: 44.1s	remaining: 46.1s
# 489:	learn: 0.0522330	total: 44.2s	remaining: 46s
# 490:	learn: 0.0522248	total: 44.2s	remaining: 45.9s
# 491:	learn: 0.0522163	total: 44.3s	remaining: 45.8s
# 492:	learn: 0.0522013	total: 44.4s	remaining: 45.7s
# 493:	learn: 0.0521910	total: 44.5s	remaining: 45.6s
# 494:	learn: 0.0521770	total: 44.6s	remaining: 45.5s
# 495:	learn: 0.0521609	total: 44.6s	remaining: 45.4s
# 496:	learn: 0.0521461	total: 44.7s	remaining: 45.3s
# 497:	learn: 0.0521314	total: 44.8s	remaining: 45.2s
# 498:	learn: 0.0521208	total: 44.9s	remaining: 45.1s
# 499:	learn: 0.0521058	total: 45s	remaining: 45s
# 500:	learn: 0.0520942	total: 45s	remaining: 44.9s
# 501:	learn: 0.0520792	total: 45.1s	remaining: 44.8s
# 502:	learn: 0.0520600	total: 45.2s	remaining: 44.7s
# 503:	learn: 0.0520509	total: 45.3s	remaining: 44.6s
# 504:	learn: 0.0520458	total: 45.4s	remaining: 44.5s
# 505:	learn: 0.0520391	total: 45.5s	remaining: 44.4s
# 506:	learn: 0.0520315	total: 45.5s	remaining: 44.3s
# 507:	learn: 0.0520178	total: 45.6s	remaining: 44.2s
# 508:	learn: 0.0520077	total: 45.7s	remaining: 44.1s
# 509:	learn: 0.0519963	total: 45.8s	remaining: 44s
# 510:	learn: 0.0519839	total: 45.9s	remaining: 43.9s
# 511:	learn: 0.0519739	total: 45.9s	remaining: 43.8s
# 512:	learn: 0.0519600	total: 46s	remaining: 43.7s
# 513:	learn: 0.0519514	total: 46.1s	remaining: 43.6s
# 514:	learn: 0.0519319	total: 46.2s	remaining: 43.5s
# 515:	learn: 0.0519147	total: 46.3s	remaining: 43.4s
# 516:	learn: 0.0519023	total: 46.3s	remaining: 43.3s
# 517:	learn: 0.0518877	total: 46.4s	remaining: 43.2s
# 518:	learn: 0.0518779	total: 46.5s	remaining: 43.1s
# 519:	learn: 0.0518654	total: 46.6s	remaining: 43s
# 520:	learn: 0.0518539	total: 46.7s	remaining: 42.9s
# 521:	learn: 0.0518490	total: 46.7s	remaining: 42.8s
# 522:	learn: 0.0518377	total: 46.8s	remaining: 42.7s
# 523:	learn: 0.0518242	total: 46.9s	remaining: 42.6s
# 524:	learn: 0.0518148	total: 47s	remaining: 42.5s
# 525:	learn: 0.0517978	total: 47.1s	remaining: 42.4s
# 526:	learn: 0.0517881	total: 47.2s	remaining: 42.3s
# 527:	learn: 0.0517792	total: 47.2s	remaining: 42.2s
# 528:	learn: 0.0517711	total: 47.3s	remaining: 42.1s
# 529:	learn: 0.0517598	total: 47.4s	remaining: 42s
# 530:	learn: 0.0517451	total: 47.5s	remaining: 41.9s
# 531:	learn: 0.0517337	total: 47.6s	remaining: 41.8s
# 532:	learn: 0.0517217	total: 47.7s	remaining: 41.8s
# 533:	learn: 0.0517092	total: 47.7s	remaining: 41.7s
# 534:	learn: 0.0516972	total: 47.8s	remaining: 41.6s
# 535:	learn: 0.0516814	total: 47.9s	remaining: 41.5s
# 536:	learn: 0.0516643	total: 48s	remaining: 41.4s
# 537:	learn: 0.0516504	total: 48.1s	remaining: 41.3s
# 538:	learn: 0.0516429	total: 48.2s	remaining: 41.2s
# 539:	learn: 0.0516315	total: 48.2s	remaining: 41.1s
# 540:	learn: 0.0516209	total: 48.3s	remaining: 41s
# 541:	learn: 0.0516053	total: 48.4s	remaining: 40.9s
# 542:	learn: 0.0515940	total: 48.5s	remaining: 40.8s
# 543:	learn: 0.0515851	total: 48.6s	remaining: 40.7s
# 544:	learn: 0.0515783	total: 48.7s	remaining: 40.6s
# 545:	learn: 0.0515676	total: 48.7s	remaining: 40.5s
# 546:	learn: 0.0515543	total: 48.8s	remaining: 40.4s
# 547:	learn: 0.0515439	total: 48.9s	remaining: 40.3s
# 548:	learn: 0.0515295	total: 49s	remaining: 40.2s
# 549:	learn: 0.0515217	total: 49.1s	remaining: 40.1s
# 550:	learn: 0.0515099	total: 49.1s	remaining: 40s
# 551:	learn: 0.0515006	total: 49.2s	remaining: 39.9s
# 552:	learn: 0.0514856	total: 49.3s	remaining: 39.8s
# 553:	learn: 0.0514714	total: 49.4s	remaining: 39.8s
# 554:	learn: 0.0514598	total: 49.5s	remaining: 39.7s
# 555:	learn: 0.0514477	total: 49.5s	remaining: 39.6s
# 556:	learn: 0.0514338	total: 49.6s	remaining: 39.5s
# 557:	learn: 0.0514198	total: 49.7s	remaining: 39.4s
# 558:	learn: 0.0514062	total: 49.8s	remaining: 39.3s
# 559:	learn: 0.0513910	total: 49.9s	remaining: 39.2s
# 560:	learn: 0.0513731	total: 49.9s	remaining: 39.1s
# 561:	learn: 0.0513633	total: 50s	remaining: 39s
# 562:	learn: 0.0513516	total: 50.1s	remaining: 38.9s
# 563:	learn: 0.0513395	total: 50.2s	remaining: 38.8s
# 564:	learn: 0.0513316	total: 50.3s	remaining: 38.7s
# 565:	learn: 0.0513116	total: 50.4s	remaining: 38.6s
# 566:	learn: 0.0512963	total: 50.4s	remaining: 38.5s
# 567:	learn: 0.0512912	total: 50.5s	remaining: 38.4s
# 568:	learn: 0.0512783	total: 50.6s	remaining: 38.3s
# 569:	learn: 0.0512698	total: 50.7s	remaining: 38.2s
# 570:	learn: 0.0512587	total: 50.8s	remaining: 38.1s
# 571:	learn: 0.0512468	total: 50.9s	remaining: 38s
# 572:	learn: 0.0512345	total: 50.9s	remaining: 38s
# 573:	learn: 0.0512225	total: 51s	remaining: 37.9s
# 574:	learn: 0.0512114	total: 51.1s	remaining: 37.8s
# 575:	learn: 0.0511990	total: 51.2s	remaining: 37.7s
# 576:	learn: 0.0511925	total: 51.2s	remaining: 37.6s
# 577:	learn: 0.0511864	total: 51.3s	remaining: 37.5s
# 578:	learn: 0.0511759	total: 51.4s	remaining: 37.4s
# 579:	learn: 0.0511581	total: 51.5s	remaining: 37.3s
# 580:	learn: 0.0511452	total: 51.6s	remaining: 37.2s
# 581:	learn: 0.0511303	total: 51.7s	remaining: 37.1s
# 582:	learn: 0.0511146	total: 51.8s	remaining: 37s
# 583:	learn: 0.0510963	total: 51.8s	remaining: 36.9s
# 584:	learn: 0.0510861	total: 51.9s	remaining: 36.8s
# 585:	learn: 0.0510738	total: 52s	remaining: 36.7s
# 586:	learn: 0.0510601	total: 52.1s	remaining: 36.7s
# 587:	learn: 0.0510524	total: 52.2s	remaining: 36.6s
# 588:	learn: 0.0510374	total: 52.3s	remaining: 36.5s
# 589:	learn: 0.0510270	total: 52.3s	remaining: 36.4s
# 590:	learn: 0.0510183	total: 52.4s	remaining: 36.3s
# 591:	learn: 0.0510111	total: 52.5s	remaining: 36.2s
# 592:	learn: 0.0509914	total: 52.6s	remaining: 36.1s
# 593:	learn: 0.0509798	total: 52.7s	remaining: 36s
# 594:	learn: 0.0509700	total: 52.8s	remaining: 35.9s
# 595:	learn: 0.0509648	total: 52.8s	remaining: 35.8s
# 596:	learn: 0.0509558	total: 52.9s	remaining: 35.7s
# 597:	learn: 0.0509405	total: 53s	remaining: 35.6s
# 598:	learn: 0.0509318	total: 53.1s	remaining: 35.5s
# 599:	learn: 0.0509215	total: 53.2s	remaining: 35.5s
# 600:	learn: 0.0509131	total: 53.3s	remaining: 35.4s
# 601:	learn: 0.0509022	total: 53.3s	remaining: 35.3s
# 602:	learn: 0.0508948	total: 53.4s	remaining: 35.2s
# 603:	learn: 0.0508752	total: 53.5s	remaining: 35.1s
# 604:	learn: 0.0508640	total: 53.6s	remaining: 35s
# 605:	learn: 0.0508511	total: 53.7s	remaining: 34.9s
# 606:	learn: 0.0508349	total: 53.7s	remaining: 34.8s
# 607:	learn: 0.0508280	total: 53.8s	remaining: 34.7s
# 608:	learn: 0.0508185	total: 53.9s	remaining: 34.6s
# 609:	learn: 0.0508087	total: 54s	remaining: 34.5s
# 610:	learn: 0.0507956	total: 54.1s	remaining: 34.4s
# 611:	learn: 0.0507836	total: 54.1s	remaining: 34.3s
# 612:	learn: 0.0507739	total: 54.2s	remaining: 34.2s
# 613:	learn: 0.0507631	total: 54.3s	remaining: 34.1s
# 614:	learn: 0.0507498	total: 54.4s	remaining: 34.1s
# 615:	learn: 0.0507337	total: 54.5s	remaining: 34s
# 616:	learn: 0.0507213	total: 54.6s	remaining: 33.9s
# 617:	learn: 0.0507146	total: 54.6s	remaining: 33.8s
# 618:	learn: 0.0506974	total: 54.7s	remaining: 33.7s
# 619:	learn: 0.0506869	total: 54.8s	remaining: 33.6s
# 620:	learn: 0.0506733	total: 54.9s	remaining: 33.5s
# 621:	learn: 0.0506599	total: 55s	remaining: 33.4s
# 622:	learn: 0.0506477	total: 55.1s	remaining: 33.3s
# 623:	learn: 0.0506390	total: 55.1s	remaining: 33.2s
# 624:	learn: 0.0506252	total: 55.2s	remaining: 33.1s
# 625:	learn: 0.0506162	total: 55.3s	remaining: 33s
# 626:	learn: 0.0506080	total: 55.4s	remaining: 32.9s
# 627:	learn: 0.0505992	total: 55.5s	remaining: 32.9s
# 628:	learn: 0.0505848	total: 55.6s	remaining: 32.8s
# 629:	learn: 0.0505750	total: 55.6s	remaining: 32.7s
# 630:	learn: 0.0505646	total: 55.7s	remaining: 32.6s
# 631:	learn: 0.0505507	total: 55.8s	remaining: 32.5s
# 632:	learn: 0.0505349	total: 55.9s	remaining: 32.4s
# 633:	learn: 0.0505248	total: 56s	remaining: 32.3s
# 634:	learn: 0.0505159	total: 56s	remaining: 32.2s
# 635:	learn: 0.0505097	total: 56.1s	remaining: 32.1s
# 636:	learn: 0.0504971	total: 56.2s	remaining: 32s
# 637:	learn: 0.0504887	total: 56.3s	remaining: 31.9s
# 638:	learn: 0.0504753	total: 56.4s	remaining: 31.8s
# 639:	learn: 0.0504569	total: 56.4s	remaining: 31.8s
# 640:	learn: 0.0504467	total: 56.5s	remaining: 31.7s
# 641:	learn: 0.0504362	total: 56.6s	remaining: 31.6s
# 642:	learn: 0.0504242	total: 56.7s	remaining: 31.5s
# 643:	learn: 0.0504140	total: 56.8s	remaining: 31.4s
# 644:	learn: 0.0503989	total: 56.8s	remaining: 31.3s
# 645:	learn: 0.0503841	total: 56.9s	remaining: 31.2s
# 646:	learn: 0.0503750	total: 57s	remaining: 31.1s
# 647:	learn: 0.0503656	total: 57.1s	remaining: 31s
# 648:	learn: 0.0503518	total: 57.2s	remaining: 30.9s
# 649:	learn: 0.0503447	total: 57.3s	remaining: 30.8s
# 650:	learn: 0.0503382	total: 57.4s	remaining: 30.8s
# 651:	learn: 0.0503258	total: 57.4s	remaining: 30.7s
# 652:	learn: 0.0503096	total: 57.5s	remaining: 30.6s
# 653:	learn: 0.0502980	total: 57.6s	remaining: 30.5s
# 654:	learn: 0.0502863	total: 57.7s	remaining: 30.4s
# 655:	learn: 0.0502669	total: 57.8s	remaining: 30.3s
# 656:	learn: 0.0502584	total: 57.9s	remaining: 30.2s
# 657:	learn: 0.0502440	total: 57.9s	remaining: 30.1s
# 658:	learn: 0.0502327	total: 58s	remaining: 30s
# 659:	learn: 0.0502268	total: 58.1s	remaining: 29.9s
# 660:	learn: 0.0502211	total: 58.2s	remaining: 29.8s
# 661:	learn: 0.0502142	total: 58.3s	remaining: 29.7s
# 662:	learn: 0.0502068	total: 58.3s	remaining: 29.7s
# 663:	learn: 0.0501966	total: 58.4s	remaining: 29.6s
# 664:	learn: 0.0501814	total: 58.5s	remaining: 29.5s
# 665:	learn: 0.0501698	total: 58.6s	remaining: 29.4s
# 666:	learn: 0.0501617	total: 58.7s	remaining: 29.3s
# 667:	learn: 0.0501533	total: 58.7s	remaining: 29.2s
# 668:	learn: 0.0501461	total: 58.8s	remaining: 29.1s
# 669:	learn: 0.0501341	total: 58.9s	remaining: 29s
# 670:	learn: 0.0501261	total: 59s	remaining: 28.9s
# 671:	learn: 0.0501144	total: 59.1s	remaining: 28.8s
# 672:	learn: 0.0501061	total: 59.2s	remaining: 28.7s
# 673:	learn: 0.0500894	total: 59.2s	remaining: 28.7s
# 674:	learn: 0.0500764	total: 59.3s	remaining: 28.6s
# 675:	learn: 0.0500669	total: 59.4s	remaining: 28.5s
# 676:	learn: 0.0500560	total: 59.5s	remaining: 28.4s
# 677:	learn: 0.0500373	total: 59.6s	remaining: 28.3s
# 678:	learn: 0.0500253	total: 59.6s	remaining: 28.2s
# 679:	learn: 0.0500137	total: 59.7s	remaining: 28.1s
# 680:	learn: 0.0500070	total: 59.8s	remaining: 28s
# 681:	learn: 0.0499899	total: 59.9s	remaining: 27.9s
# 682:	learn: 0.0499776	total: 60s	remaining: 27.8s
# 683:	learn: 0.0499657	total: 1m	remaining: 27.7s
# 684:	learn: 0.0499532	total: 1m	remaining: 27.7s
# 685:	learn: 0.0499442	total: 1m	remaining: 27.6s
# 686:	learn: 0.0499326	total: 1m	remaining: 27.5s
# 687:	learn: 0.0499213	total: 1m	remaining: 27.4s
# 688:	learn: 0.0499090	total: 1m	remaining: 27.3s
# 689:	learn: 0.0498970	total: 1m	remaining: 27.2s
# 690:	learn: 0.0498868	total: 1m	remaining: 27.1s
# 691:	learn: 0.0498729	total: 1m	remaining: 27s
# 692:	learn: 0.0498678	total: 1m	remaining: 26.9s
# 693:	learn: 0.0498548	total: 1m	remaining: 26.8s
# 694:	learn: 0.0498431	total: 1m	remaining: 26.7s
# 695:	learn: 0.0498365	total: 1m 1s	remaining: 26.7s
# 696:	learn: 0.0498182	total: 1m 1s	remaining: 26.6s
# 697:	learn: 0.0498134	total: 1m 1s	remaining: 26.5s
# 698:	learn: 0.0498023	total: 1m 1s	remaining: 26.4s
# 699:	learn: 0.0497968	total: 1m 1s	remaining: 26.3s
# 700:	learn: 0.0497829	total: 1m 1s	remaining: 26.2s
# 701:	learn: 0.0497631	total: 1m 1s	remaining: 26.1s
# 702:	learn: 0.0497506	total: 1m 1s	remaining: 26s
# 703:	learn: 0.0497343	total: 1m 1s	remaining: 25.9s
# 704:	learn: 0.0497225	total: 1m 1s	remaining: 25.8s
# 705:	learn: 0.0497068	total: 1m 1s	remaining: 25.8s
# 706:	learn: 0.0497004	total: 1m 1s	remaining: 25.7s
# 707:	learn: 0.0496862	total: 1m 2s	remaining: 25.6s
# 708:	learn: 0.0496783	total: 1m 2s	remaining: 25.5s
# 709:	learn: 0.0496684	total: 1m 2s	remaining: 25.4s
# 710:	learn: 0.0496590	total: 1m 2s	remaining: 25.3s
# 711:	learn: 0.0496517	total: 1m 2s	remaining: 25.2s
# 712:	learn: 0.0496381	total: 1m 2s	remaining: 25.1s
# 713:	learn: 0.0496221	total: 1m 2s	remaining: 25s
# 714:	learn: 0.0496130	total: 1m 2s	remaining: 24.9s
# 715:	learn: 0.0496014	total: 1m 2s	remaining: 24.9s
# 716:	learn: 0.0495958	total: 1m 2s	remaining: 24.8s
# 717:	learn: 0.0495907	total: 1m 2s	remaining: 24.7s
# 718:	learn: 0.0495810	total: 1m 2s	remaining: 24.6s
# 719:	learn: 0.0495714	total: 1m 2s	remaining: 24.5s
# 720:	learn: 0.0495591	total: 1m 3s	remaining: 24.4s
# 721:	learn: 0.0495467	total: 1m 3s	remaining: 24.3s
# 722:	learn: 0.0495367	total: 1m 3s	remaining: 24.2s
# 723:	learn: 0.0495285	total: 1m 3s	remaining: 24.1s
# 724:	learn: 0.0495078	total: 1m 3s	remaining: 24s
# 725:	learn: 0.0494991	total: 1m 3s	remaining: 24s
# 726:	learn: 0.0494807	total: 1m 3s	remaining: 23.9s
# 727:	learn: 0.0494674	total: 1m 3s	remaining: 23.8s
# 728:	learn: 0.0494538	total: 1m 3s	remaining: 23.7s
# 729:	learn: 0.0494395	total: 1m 3s	remaining: 23.6s
# 730:	learn: 0.0494316	total: 1m 3s	remaining: 23.5s
# 731:	learn: 0.0494144	total: 1m 3s	remaining: 23.4s
# 732:	learn: 0.0494050	total: 1m 4s	remaining: 23.3s
# 733:	learn: 0.0493928	total: 1m 4s	remaining: 23.2s
# 734:	learn: 0.0493781	total: 1m 4s	remaining: 23.1s
# 735:	learn: 0.0493732	total: 1m 4s	remaining: 23.1s
# 736:	learn: 0.0493587	total: 1m 4s	remaining: 23s
# 737:	learn: 0.0493514	total: 1m 4s	remaining: 22.9s
# 738:	learn: 0.0493436	total: 1m 4s	remaining: 22.8s
# 739:	learn: 0.0493302	total: 1m 4s	remaining: 22.7s
# 740:	learn: 0.0493196	total: 1m 4s	remaining: 22.6s
# 741:	learn: 0.0493073	total: 1m 4s	remaining: 22.5s
# 742:	learn: 0.0492996	total: 1m 4s	remaining: 22.4s
# 743:	learn: 0.0492854	total: 1m 4s	remaining: 22.3s
# 744:	learn: 0.0492750	total: 1m 5s	remaining: 22.3s
# 745:	learn: 0.0492665	total: 1m 5s	remaining: 22.2s
# 746:	learn: 0.0492605	total: 1m 5s	remaining: 22.1s
# 747:	learn: 0.0492525	total: 1m 5s	remaining: 22s
# 748:	learn: 0.0492395	total: 1m 5s	remaining: 21.9s
# 749:	learn: 0.0492233	total: 1m 5s	remaining: 21.8s
# 750:	learn: 0.0492131	total: 1m 5s	remaining: 21.7s
# 751:	learn: 0.0491998	total: 1m 5s	remaining: 21.6s
# 752:	learn: 0.0491943	total: 1m 5s	remaining: 21.5s
# 753:	learn: 0.0491741	total: 1m 5s	remaining: 21.5s
# 754:	learn: 0.0491578	total: 1m 5s	remaining: 21.4s
# 755:	learn: 0.0491429	total: 1m 5s	remaining: 21.3s
# 756:	learn: 0.0491313	total: 1m 6s	remaining: 21.2s
# 757:	learn: 0.0491278	total: 1m 6s	remaining: 21.1s
# 758:	learn: 0.0491140	total: 1m 6s	remaining: 21s
# 759:	learn: 0.0491017	total: 1m 6s	remaining: 20.9s
# 760:	learn: 0.0490905	total: 1m 6s	remaining: 20.8s
# 761:	learn: 0.0490792	total: 1m 6s	remaining: 20.7s
# 762:	learn: 0.0490745	total: 1m 6s	remaining: 20.7s
# 763:	learn: 0.0490679	total: 1m 6s	remaining: 20.6s
# 764:	learn: 0.0490603	total: 1m 6s	remaining: 20.5s
# 765:	learn: 0.0490507	total: 1m 6s	remaining: 20.4s
# 766:	learn: 0.0490422	total: 1m 6s	remaining: 20.3s
# 767:	learn: 0.0490331	total: 1m 6s	remaining: 20.2s
# 768:	learn: 0.0490243	total: 1m 6s	remaining: 20.1s
# 769:	learn: 0.0490169	total: 1m 7s	remaining: 20s
# 770:	learn: 0.0490016	total: 1m 7s	remaining: 19.9s
# 771:	learn: 0.0489907	total: 1m 7s	remaining: 19.9s
# 772:	learn: 0.0489829	total: 1m 7s	remaining: 19.8s
# 773:	learn: 0.0489713	total: 1m 7s	remaining: 19.7s
# 774:	learn: 0.0489612	total: 1m 7s	remaining: 19.6s
# 775:	learn: 0.0489518	total: 1m 7s	remaining: 19.5s
# 776:	learn: 0.0489369	total: 1m 7s	remaining: 19.4s
# 777:	learn: 0.0489259	total: 1m 7s	remaining: 19.3s
# 778:	learn: 0.0489083	total: 1m 7s	remaining: 19.2s
# 779:	learn: 0.0488960	total: 1m 7s	remaining: 19.1s
# 780:	learn: 0.0488880	total: 1m 7s	remaining: 19.1s
# 781:	learn: 0.0488791	total: 1m 8s	remaining: 19s
# 782:	learn: 0.0488728	total: 1m 8s	remaining: 18.9s
# 783:	learn: 0.0488647	total: 1m 8s	remaining: 18.8s
# 784:	learn: 0.0488560	total: 1m 8s	remaining: 18.7s
# 785:	learn: 0.0488451	total: 1m 8s	remaining: 18.6s
# 786:	learn: 0.0488317	total: 1m 8s	remaining: 18.5s
# 787:	learn: 0.0488238	total: 1m 8s	remaining: 18.4s
# 788:	learn: 0.0488141	total: 1m 8s	remaining: 18.3s
# 789:	learn: 0.0488047	total: 1m 8s	remaining: 18.3s
# 790:	learn: 0.0487945	total: 1m 8s	remaining: 18.2s
# 791:	learn: 0.0487814	total: 1m 8s	remaining: 18.1s
# 792:	learn: 0.0487712	total: 1m 8s	remaining: 18s
# 793:	learn: 0.0487631	total: 1m 9s	remaining: 17.9s
# 794:	learn: 0.0487544	total: 1m 9s	remaining: 17.8s
# 795:	learn: 0.0487430	total: 1m 9s	remaining: 17.7s
# 796:	learn: 0.0487331	total: 1m 9s	remaining: 17.6s
# 797:	learn: 0.0487199	total: 1m 9s	remaining: 17.6s
# 798:	learn: 0.0487163	total: 1m 9s	remaining: 17.5s
# 799:	learn: 0.0487026	total: 1m 9s	remaining: 17.4s
# 800:	learn: 0.0486931	total: 1m 9s	remaining: 17.3s
# 801:	learn: 0.0486831	total: 1m 9s	remaining: 17.2s
# 802:	learn: 0.0486731	total: 1m 9s	remaining: 17.1s
# 803:	learn: 0.0486616	total: 1m 9s	remaining: 17s
# 804:	learn: 0.0486501	total: 1m 9s	remaining: 16.9s
# 805:	learn: 0.0486384	total: 1m 9s	remaining: 16.8s
# 806:	learn: 0.0486229	total: 1m 10s	remaining: 16.8s
# 807:	learn: 0.0486101	total: 1m 10s	remaining: 16.7s
# 808:	learn: 0.0486014	total: 1m 10s	remaining: 16.6s
# 809:	learn: 0.0485878	total: 1m 10s	remaining: 16.5s
# 810:	learn: 0.0485758	total: 1m 10s	remaining: 16.4s
# 811:	learn: 0.0485701	total: 1m 10s	remaining: 16.3s
# 812:	learn: 0.0485643	total: 1m 10s	remaining: 16.2s
# 813:	learn: 0.0485535	total: 1m 10s	remaining: 16.1s
# 814:	learn: 0.0485428	total: 1m 10s	remaining: 16.1s
# 815:	learn: 0.0485263	total: 1m 10s	remaining: 16s
# 816:	learn: 0.0485188	total: 1m 10s	remaining: 15.9s
# 817:	learn: 0.0485107	total: 1m 10s	remaining: 15.8s
# 818:	learn: 0.0485000	total: 1m 11s	remaining: 15.7s
# 819:	learn: 0.0484908	total: 1m 11s	remaining: 15.6s
# 820:	learn: 0.0484762	total: 1m 11s	remaining: 15.5s
# 821:	learn: 0.0484654	total: 1m 11s	remaining: 15.4s
# 822:	learn: 0.0484539	total: 1m 11s	remaining: 15.3s
# 823:	learn: 0.0484465	total: 1m 11s	remaining: 15.3s
# 824:	learn: 0.0484319	total: 1m 11s	remaining: 15.2s
# 825:	learn: 0.0484221	total: 1m 11s	remaining: 15.1s
# 826:	learn: 0.0484088	total: 1m 11s	remaining: 15s
# 827:	learn: 0.0483960	total: 1m 11s	remaining: 14.9s
# 828:	learn: 0.0483858	total: 1m 11s	remaining: 14.8s
# 829:	learn: 0.0483733	total: 1m 11s	remaining: 14.7s
# 830:	learn: 0.0483658	total: 1m 12s	remaining: 14.6s
# 831:	learn: 0.0483535	total: 1m 12s	remaining: 14.6s
# 832:	learn: 0.0483477	total: 1m 12s	remaining: 14.5s
# 833:	learn: 0.0483356	total: 1m 12s	remaining: 14.4s
# 834:	learn: 0.0483271	total: 1m 12s	remaining: 14.3s
# 835:	learn: 0.0483151	total: 1m 12s	remaining: 14.2s
# 836:	learn: 0.0483057	total: 1m 12s	remaining: 14.1s
# 837:	learn: 0.0482967	total: 1m 12s	remaining: 14s
# 838:	learn: 0.0482877	total: 1m 12s	remaining: 13.9s
# 839:	learn: 0.0482670	total: 1m 12s	remaining: 13.9s
# 840:	learn: 0.0482486	total: 1m 12s	remaining: 13.8s
# 841:	learn: 0.0482366	total: 1m 12s	remaining: 13.7s
# 842:	learn: 0.0482220	total: 1m 13s	remaining: 13.6s
# 843:	learn: 0.0482139	total: 1m 13s	remaining: 13.5s
# 844:	learn: 0.0481998	total: 1m 13s	remaining: 13.4s
# 845:	learn: 0.0481931	total: 1m 13s	remaining: 13.3s
# 846:	learn: 0.0481838	total: 1m 13s	remaining: 13.2s
# 847:	learn: 0.0481738	total: 1m 13s	remaining: 13.2s
# 848:	learn: 0.0481650	total: 1m 13s	remaining: 13.1s
# 849:	learn: 0.0481567	total: 1m 13s	remaining: 13s
# 850:	learn: 0.0481400	total: 1m 13s	remaining: 12.9s
# 851:	learn: 0.0481285	total: 1m 13s	remaining: 12.8s
# 852:	learn: 0.0481200	total: 1m 13s	remaining: 12.7s
# 853:	learn: 0.0481086	total: 1m 13s	remaining: 12.6s
# 854:	learn: 0.0481016	total: 1m 14s	remaining: 12.6s
# 855:	learn: 0.0480963	total: 1m 14s	remaining: 12.5s
# 856:	learn: 0.0480850	total: 1m 14s	remaining: 12.4s
# 857:	learn: 0.0480762	total: 1m 14s	remaining: 12.3s
# 858:	learn: 0.0480643	total: 1m 14s	remaining: 12.2s
# 859:	learn: 0.0480556	total: 1m 14s	remaining: 12.1s
# 860:	learn: 0.0480451	total: 1m 14s	remaining: 12s
# 861:	learn: 0.0480346	total: 1m 14s	remaining: 11.9s
# 862:	learn: 0.0480263	total: 1m 14s	remaining: 11.8s
# 863:	learn: 0.0480191	total: 1m 14s	remaining: 11.8s
# 864:	learn: 0.0480096	total: 1m 14s	remaining: 11.7s
# 865:	learn: 0.0479980	total: 1m 14s	remaining: 11.6s
# 866:	learn: 0.0479904	total: 1m 14s	remaining: 11.5s
# 867:	learn: 0.0479807	total: 1m 15s	remaining: 11.4s
# 868:	learn: 0.0479738	total: 1m 15s	remaining: 11.3s
# 869:	learn: 0.0479667	total: 1m 15s	remaining: 11.2s
# 870:	learn: 0.0479557	total: 1m 15s	remaining: 11.2s
# 871:	learn: 0.0479502	total: 1m 15s	remaining: 11.1s
# 872:	learn: 0.0479399	total: 1m 15s	remaining: 11s
# 873:	learn: 0.0479291	total: 1m 15s	remaining: 10.9s
# 874:	learn: 0.0479207	total: 1m 15s	remaining: 10.8s
# 875:	learn: 0.0479106	total: 1m 15s	remaining: 10.7s
# 876:	learn: 0.0478996	total: 1m 15s	remaining: 10.6s
# 877:	learn: 0.0478895	total: 1m 15s	remaining: 10.5s
# 878:	learn: 0.0478809	total: 1m 15s	remaining: 10.5s
# 879:	learn: 0.0478694	total: 1m 16s	remaining: 10.4s
# 880:	learn: 0.0478611	total: 1m 16s	remaining: 10.3s
# 881:	learn: 0.0478473	total: 1m 16s	remaining: 10.2s
# 882:	learn: 0.0478415	total: 1m 16s	remaining: 10.1s
# 883:	learn: 0.0478304	total: 1m 16s	remaining: 10s
# 884:	learn: 0.0478231	total: 1m 16s	remaining: 9.93s
# 885:	learn: 0.0478172	total: 1m 16s	remaining: 9.85s
# 886:	learn: 0.0478012	total: 1m 16s	remaining: 9.76s
# 887:	learn: 0.0477957	total: 1m 16s	remaining: 9.67s
# 888:	learn: 0.0477792	total: 1m 16s	remaining: 9.59s
# 889:	learn: 0.0477689	total: 1m 16s	remaining: 9.5s
# 890:	learn: 0.0477568	total: 1m 16s	remaining: 9.41s
# 891:	learn: 0.0477466	total: 1m 17s	remaining: 9.33s
# 892:	learn: 0.0477317	total: 1m 17s	remaining: 9.24s
# 893:	learn: 0.0477179	total: 1m 17s	remaining: 9.15s
# 894:	learn: 0.0477107	total: 1m 17s	remaining: 9.06s
# 895:	learn: 0.0476996	total: 1m 17s	remaining: 8.98s
# 896:	learn: 0.0476935	total: 1m 17s	remaining: 8.89s
# 897:	learn: 0.0476817	total: 1m 17s	remaining: 8.8s
# 898:	learn: 0.0476741	total: 1m 17s	remaining: 8.72s
# 899:	learn: 0.0476639	total: 1m 17s	remaining: 8.63s
# 900:	learn: 0.0476473	total: 1m 17s	remaining: 8.54s
# 901:	learn: 0.0476365	total: 1m 17s	remaining: 8.46s
# 902:	learn: 0.0476301	total: 1m 17s	remaining: 8.37s
# 903:	learn: 0.0476178	total: 1m 18s	remaining: 8.28s
# 904:	learn: 0.0476093	total: 1m 18s	remaining: 8.2s
# 905:	learn: 0.0475989	total: 1m 18s	remaining: 8.11s
# 906:	learn: 0.0475882	total: 1m 18s	remaining: 8.02s
# 907:	learn: 0.0475746	total: 1m 18s	remaining: 7.94s
# 908:	learn: 0.0475630	total: 1m 18s	remaining: 7.85s
# 909:	learn: 0.0475537	total: 1m 18s	remaining: 7.76s
# 910:	learn: 0.0475440	total: 1m 18s	remaining: 7.67s
# 911:	learn: 0.0475331	total: 1m 18s	remaining: 7.59s
# 912:	learn: 0.0475230	total: 1m 18s	remaining: 7.5s
# 913:	learn: 0.0475170	total: 1m 18s	remaining: 7.42s
# 914:	learn: 0.0475055	total: 1m 18s	remaining: 7.33s
# 915:	learn: 0.0474984	total: 1m 18s	remaining: 7.24s
# 916:	learn: 0.0474924	total: 1m 19s	remaining: 7.16s
# 917:	learn: 0.0474843	total: 1m 19s	remaining: 7.07s
# 918:	learn: 0.0474730	total: 1m 19s	remaining: 6.98s
# 919:	learn: 0.0474671	total: 1m 19s	remaining: 6.89s
# 920:	learn: 0.0474619	total: 1m 19s	remaining: 6.81s
# 921:	learn: 0.0474495	total: 1m 19s	remaining: 6.72s
# 922:	learn: 0.0474422	total: 1m 19s	remaining: 6.63s
# ...
# 691:	learn: 0.0594977	total: 34.3s	remaining: 15.3s
# 692:	learn: 0.0594964	total: 34.3s	remaining: 15.2s
# 693:	learn: 0.0594944	total: 34.4s	remaining: 15.2s
# 694:	learn: 0.0594914	total: 34.4s	remaining: 15.1s
# 695:	learn: 0.0594890	total: 34.5s	remaining: 15.1s
# 696:	learn: 0.0594872	total: 34.5s	remaining: 15s
# 697:	learn: 0.0594847	total: 34.6s	remaining: 15s
# 698:	learn: 0.0594820	total: 34.6s	remaining: 14.9s
# 699:	learn: 0.0594802	total: 34.7s	remaining: 14.9s
# 700:	learn: 0.0594788	total: 34.7s	remaining: 14.8s
# 701:	learn: 0.0594775	total: 34.8s	remaining: 14.8s
# 702:	learn: 0.0594759	total: 34.8s	remaining: 14.7s
# 703:	learn: 0.0594742	total: 34.9s	remaining: 14.7s
# 704:	learn: 0.0594723	total: 34.9s	remaining: 14.6s
# 705:	learn: 0.0594698	total: 35s	remaining: 14.6s
# 706:	learn: 0.0594667	total: 35s	remaining: 14.5s
# 707:	learn: 0.0594635	total: 35.1s	remaining: 14.5s
# 708:	learn: 0.0594616	total: 35.1s	remaining: 14.4s
# 709:	learn: 0.0594594	total: 35.2s	remaining: 14.4s
# 710:	learn: 0.0594579	total: 35.2s	remaining: 14.3s
# 711:	learn: 0.0594554	total: 35.3s	remaining: 14.3s
# 712:	learn: 0.0594539	total: 35.3s	remaining: 14.2s
# 713:	learn: 0.0594525	total: 35.4s	remaining: 14.2s
# 714:	learn: 0.0594504	total: 35.4s	remaining: 14.1s
# 715:	learn: 0.0594489	total: 35.5s	remaining: 14.1s
# 716:	learn: 0.0594468	total: 35.5s	remaining: 14s
# 717:	learn: 0.0594457	total: 35.6s	remaining: 14s
# 718:	learn: 0.0594440	total: 35.6s	remaining: 13.9s
# 719:	learn: 0.0594426	total: 35.7s	remaining: 13.9s
# 720:	learn: 0.0594409	total: 35.7s	remaining: 13.8s
# 721:	learn: 0.0594400	total: 35.8s	remaining: 13.8s
# 722:	learn: 0.0594382	total: 35.8s	remaining: 13.7s
# 723:	learn: 0.0594344	total: 35.9s	remaining: 13.7s
# 724:	learn: 0.0594332	total: 35.9s	remaining: 13.6s
# 725:	learn: 0.0594317	total: 36s	remaining: 13.6s
# 726:	learn: 0.0594280	total: 36s	remaining: 13.5s
# 727:	learn: 0.0594256	total: 36.1s	remaining: 13.5s
# 728:	learn: 0.0594235	total: 36.1s	remaining: 13.4s
# 729:	learn: 0.0594216	total: 36.2s	remaining: 13.4s
# 730:	learn: 0.0594195	total: 36.2s	remaining: 13.3s
# 731:	learn: 0.0594173	total: 36.3s	remaining: 13.3s
# 732:	learn: 0.0594153	total: 36.3s	remaining: 13.2s
# 733:	learn: 0.0594121	total: 36.4s	remaining: 13.2s
# 734:	learn: 0.0594101	total: 36.4s	remaining: 13.1s
# 735:	learn: 0.0594078	total: 36.5s	remaining: 13.1s
# 736:	learn: 0.0594056	total: 36.5s	remaining: 13s
# 737:	learn: 0.0594038	total: 36.6s	remaining: 13s
# 738:	learn: 0.0594013	total: 36.6s	remaining: 12.9s
# 739:	learn: 0.0593990	total: 36.7s	remaining: 12.9s
# 740:	learn: 0.0593969	total: 36.7s	remaining: 12.8s
# 741:	learn: 0.0593956	total: 36.8s	remaining: 12.8s
# 742:	learn: 0.0593926	total: 36.8s	remaining: 12.7s
# 743:	learn: 0.0593914	total: 36.9s	remaining: 12.7s
# 744:	learn: 0.0593892	total: 36.9s	remaining: 12.6s
# 745:	learn: 0.0593876	total: 37s	remaining: 12.6s
# 746:	learn: 0.0593854	total: 37s	remaining: 12.5s
# 747:	learn: 0.0593831	total: 37.1s	remaining: 12.5s
# 748:	learn: 0.0593810	total: 37.1s	remaining: 12.4s
# 749:	learn: 0.0593777	total: 37.2s	remaining: 12.4s
# 750:	learn: 0.0593763	total: 37.2s	remaining: 12.3s
# 751:	learn: 0.0593746	total: 37.2s	remaining: 12.3s
# 752:	learn: 0.0593723	total: 37.3s	remaining: 12.2s
# 753:	learn: 0.0593711	total: 37.4s	remaining: 12.2s
# 754:	learn: 0.0593686	total: 37.4s	remaining: 12.1s
# 755:	learn: 0.0593667	total: 37.4s	remaining: 12.1s
# 756:	learn: 0.0593647	total: 37.5s	remaining: 12s
# 757:	learn: 0.0593626	total: 37.5s	remaining: 12s
# 758:	learn: 0.0593615	total: 37.6s	remaining: 11.9s
# 759:	learn: 0.0593605	total: 37.7s	remaining: 11.9s
# 760:	learn: 0.0593580	total: 37.7s	remaining: 11.8s
# 761:	learn: 0.0593572	total: 37.8s	remaining: 11.8s
# 762:	learn: 0.0593553	total: 37.8s	remaining: 11.7s
# 763:	learn: 0.0593525	total: 37.8s	remaining: 11.7s
# 764:	learn: 0.0593489	total: 37.9s	remaining: 11.6s
# 765:	learn: 0.0593469	total: 37.9s	remaining: 11.6s
# 766:	learn: 0.0593447	total: 38s	remaining: 11.5s
# 767:	learn: 0.0593436	total: 38s	remaining: 11.5s
# 768:	learn: 0.0593407	total: 38.1s	remaining: 11.4s
# 769:	learn: 0.0593381	total: 38.1s	remaining: 11.4s
# 770:	learn: 0.0593366	total: 38.2s	remaining: 11.3s
# 771:	learn: 0.0593349	total: 38.2s	remaining: 11.3s
# 772:	learn: 0.0593332	total: 38.3s	remaining: 11.2s
# 773:	learn: 0.0593308	total: 38.3s	remaining: 11.2s
# 774:	learn: 0.0593295	total: 38.4s	remaining: 11.1s
# 775:	learn: 0.0593279	total: 38.4s	remaining: 11.1s
# 776:	learn: 0.0593259	total: 38.5s	remaining: 11s
# 777:	learn: 0.0593244	total: 38.5s	remaining: 11s
# 778:	learn: 0.0593224	total: 38.6s	remaining: 10.9s
# 779:	learn: 0.0593210	total: 38.6s	remaining: 10.9s
# 780:	learn: 0.0593190	total: 38.7s	remaining: 10.8s
# 781:	learn: 0.0593181	total: 38.7s	remaining: 10.8s
# 782:	learn: 0.0593162	total: 38.8s	remaining: 10.7s
# 783:	learn: 0.0593141	total: 38.8s	remaining: 10.7s
# 784:	learn: 0.0593121	total: 38.9s	remaining: 10.6s
# 785:	learn: 0.0593097	total: 38.9s	remaining: 10.6s
# 786:	learn: 0.0593068	total: 39s	remaining: 10.5s
# 787:	learn: 0.0593034	total: 39s	remaining: 10.5s
# 788:	learn: 0.0593028	total: 39.1s	remaining: 10.4s
# 789:	learn: 0.0593012	total: 39.1s	remaining: 10.4s
# 790:	learn: 0.0592995	total: 39.2s	remaining: 10.3s
# 791:	learn: 0.0592977	total: 39.2s	remaining: 10.3s
# 792:	learn: 0.0592958	total: 39.3s	remaining: 10.3s
# 793:	learn: 0.0592940	total: 39.3s	remaining: 10.2s
# 794:	learn: 0.0592919	total: 39.4s	remaining: 10.2s
# 795:	learn: 0.0592904	total: 39.4s	remaining: 10.1s
# 796:	learn: 0.0592886	total: 39.5s	remaining: 10.1s
# 797:	learn: 0.0592869	total: 39.5s	remaining: 10s
# 798:	learn: 0.0592856	total: 39.6s	remaining: 9.95s
# 799:	learn: 0.0592831	total: 39.6s	remaining: 9.9s
# 800:	learn: 0.0592821	total: 39.7s	remaining: 9.85s
# 801:	learn: 0.0592803	total: 39.7s	remaining: 9.8s
# 802:	learn: 0.0592799	total: 39.8s	remaining: 9.75s
# 803:	learn: 0.0592776	total: 39.8s	remaining: 9.7s
# 804:	learn: 0.0592754	total: 39.9s	remaining: 9.65s
# 805:	learn: 0.0592741	total: 39.9s	remaining: 9.6s
# 806:	learn: 0.0592728	total: 40s	remaining: 9.56s
# 807:	learn: 0.0592707	total: 40s	remaining: 9.51s
# 808:	learn: 0.0592687	total: 40.1s	remaining: 9.46s
# 809:	learn: 0.0592663	total: 40.1s	remaining: 9.41s
# 810:	learn: 0.0592642	total: 40.2s	remaining: 9.36s
# 811:	learn: 0.0592628	total: 40.2s	remaining: 9.31s
# 812:	learn: 0.0592610	total: 40.3s	remaining: 9.26s
# 813:	learn: 0.0592591	total: 40.3s	remaining: 9.21s
# 814:	learn: 0.0592571	total: 40.4s	remaining: 9.16s
# 815:	learn: 0.0592536	total: 40.4s	remaining: 9.11s
# 816:	learn: 0.0592514	total: 40.5s	remaining: 9.06s
# 817:	learn: 0.0592502	total: 40.5s	remaining: 9.01s
# 818:	learn: 0.0592490	total: 40.6s	remaining: 8.96s
# 819:	learn: 0.0592473	total: 40.6s	remaining: 8.91s
# 820:	learn: 0.0592453	total: 40.7s	remaining: 8.87s
# 821:	learn: 0.0592435	total: 40.7s	remaining: 8.82s
# 822:	learn: 0.0592425	total: 40.8s	remaining: 8.77s
# 823:	learn: 0.0592413	total: 40.8s	remaining: 8.72s
# 824:	learn: 0.0592394	total: 40.9s	remaining: 8.67s
# 825:	learn: 0.0592379	total: 40.9s	remaining: 8.62s
# 826:	learn: 0.0592363	total: 41s	remaining: 8.57s
# 827:	learn: 0.0592343	total: 41s	remaining: 8.52s
# 828:	learn: 0.0592325	total: 41.1s	remaining: 8.47s
# 829:	learn: 0.0592309	total: 41.1s	remaining: 8.42s
# 830:	learn: 0.0592298	total: 41.2s	remaining: 8.37s
# 831:	learn: 0.0592278	total: 41.2s	remaining: 8.32s
# 832:	learn: 0.0592264	total: 41.3s	remaining: 8.27s
# 833:	learn: 0.0592244	total: 41.3s	remaining: 8.22s
# 834:	learn: 0.0592226	total: 41.4s	remaining: 8.17s
# 835:	learn: 0.0592204	total: 41.4s	remaining: 8.13s
# 836:	learn: 0.0592188	total: 41.5s	remaining: 8.08s
# 837:	learn: 0.0592172	total: 41.5s	remaining: 8.03s
# 838:	learn: 0.0592162	total: 41.6s	remaining: 7.98s
# 839:	learn: 0.0592147	total: 41.6s	remaining: 7.93s
# 840:	learn: 0.0592124	total: 41.7s	remaining: 7.88s
# 841:	learn: 0.0592105	total: 41.7s	remaining: 7.83s
# 842:	learn: 0.0592080	total: 41.8s	remaining: 7.78s
# 843:	learn: 0.0592060	total: 41.8s	remaining: 7.73s
# 844:	learn: 0.0592042	total: 41.9s	remaining: 7.68s
# 845:	learn: 0.0592025	total: 41.9s	remaining: 7.63s
# 846:	learn: 0.0592013	total: 42s	remaining: 7.58s
# 847:	learn: 0.0592002	total: 42s	remaining: 7.53s
# 848:	learn: 0.0591987	total: 42.1s	remaining: 7.49s
# 849:	learn: 0.0591979	total: 42.1s	remaining: 7.43s
# 850:	learn: 0.0591968	total: 42.2s	remaining: 7.39s
# 851:	learn: 0.0591952	total: 42.2s	remaining: 7.34s
# 852:	learn: 0.0591938	total: 42.3s	remaining: 7.29s
# 853:	learn: 0.0591919	total: 42.3s	remaining: 7.24s
# 854:	learn: 0.0591908	total: 42.4s	remaining: 7.19s
# 855:	learn: 0.0591887	total: 42.4s	remaining: 7.14s
# 856:	learn: 0.0591868	total: 42.5s	remaining: 7.09s
# 857:	learn: 0.0591842	total: 42.5s	remaining: 7.04s
# 858:	learn: 0.0591823	total: 42.6s	remaining: 6.99s
# 859:	learn: 0.0591808	total: 42.6s	remaining: 6.94s
# 860:	learn: 0.0591792	total: 42.7s	remaining: 6.89s
# 861:	learn: 0.0591773	total: 42.7s	remaining: 6.84s
# 862:	learn: 0.0591750	total: 42.8s	remaining: 6.79s
# 863:	learn: 0.0591742	total: 42.8s	remaining: 6.74s
# 864:	learn: 0.0591721	total: 42.9s	remaining: 6.69s
# 865:	learn: 0.0591708	total: 42.9s	remaining: 6.64s
# 866:	learn: 0.0591696	total: 43s	remaining: 6.59s
# 867:	learn: 0.0591687	total: 43s	remaining: 6.54s
# 868:	learn: 0.0591670	total: 43.1s	remaining: 6.49s
# 869:	learn: 0.0591648	total: 43.1s	remaining: 6.44s
# 870:	learn: 0.0591634	total: 43.2s	remaining: 6.39s
# 871:	learn: 0.0591620	total: 43.2s	remaining: 6.34s
# 872:	learn: 0.0591605	total: 43.3s	remaining: 6.29s
# 873:	learn: 0.0591582	total: 43.3s	remaining: 6.24s
# 874:	learn: 0.0591552	total: 43.4s	remaining: 6.19s
# 875:	learn: 0.0591526	total: 43.4s	remaining: 6.14s
# 876:	learn: 0.0591502	total: 43.5s	remaining: 6.09s
# 877:	learn: 0.0591490	total: 43.5s	remaining: 6.04s
# 878:	learn: 0.0591479	total: 43.6s	remaining: 6s
# 879:	learn: 0.0591471	total: 43.6s	remaining: 5.95s
# 880:	learn: 0.0591461	total: 43.7s	remaining: 5.9s
# 881:	learn: 0.0591439	total: 43.7s	remaining: 5.85s
# 882:	learn: 0.0591417	total: 43.8s	remaining: 5.8s
# 883:	learn: 0.0591396	total: 43.8s	remaining: 5.75s
# 884:	learn: 0.0591370	total: 43.9s	remaining: 5.7s
# 885:	learn: 0.0591354	total: 43.9s	remaining: 5.65s
# 886:	learn: 0.0591339	total: 44s	remaining: 5.6s
# 887:	learn: 0.0591315	total: 44s	remaining: 5.55s
# 888:	learn: 0.0591300	total: 44.1s	remaining: 5.5s
# 889:	learn: 0.0591285	total: 44.1s	remaining: 5.45s
# 890:	learn: 0.0591271	total: 44.2s	remaining: 5.4s
# 891:	learn: 0.0591239	total: 44.2s	remaining: 5.35s
# 892:	learn: 0.0591229	total: 44.3s	remaining: 5.3s
# 893:	learn: 0.0591213	total: 44.3s	remaining: 5.25s
# 894:	learn: 0.0591196	total: 44.4s	remaining: 5.2s
# 895:	learn: 0.0591177	total: 44.4s	remaining: 5.15s
# 896:	learn: 0.0591160	total: 44.4s	remaining: 5.1s
# 897:	learn: 0.0591140	total: 44.5s	remaining: 5.05s
# 898:	learn: 0.0591127	total: 44.5s	remaining: 5s
# 899:	learn: 0.0591111	total: 44.6s	remaining: 4.95s
# 900:	learn: 0.0591096	total: 44.6s	remaining: 4.91s
# 901:	learn: 0.0591081	total: 44.7s	remaining: 4.86s
# 902:	learn: 0.0591073	total: 44.7s	remaining: 4.81s
# 903:	learn: 0.0591047	total: 44.8s	remaining: 4.76s
# 904:	learn: 0.0591030	total: 44.8s	remaining: 4.71s
# 905:	learn: 0.0591008	total: 44.9s	remaining: 4.66s
# 906:	learn: 0.0590988	total: 44.9s	remaining: 4.61s
# 907:	learn: 0.0590970	total: 45s	remaining: 4.56s
# 908:	learn: 0.0590958	total: 45s	remaining: 4.51s
# 909:	learn: 0.0590939	total: 45.1s	remaining: 4.46s
# 910:	learn: 0.0590923	total: 45.1s	remaining: 4.41s
# 911:	learn: 0.0590903	total: 45.2s	remaining: 4.36s
# 912:	learn: 0.0590881	total: 45.2s	remaining: 4.31s
# 913:	learn: 0.0590861	total: 45.3s	remaining: 4.26s
# 914:	learn: 0.0590849	total: 45.3s	remaining: 4.21s
# 915:	learn: 0.0590837	total: 45.4s	remaining: 4.16s
# 916:	learn: 0.0590814	total: 45.4s	remaining: 4.11s
# 917:	learn: 0.0590802	total: 45.5s	remaining: 4.06s
# 918:	learn: 0.0590788	total: 45.5s	remaining: 4.01s
# 919:	learn: 0.0590777	total: 45.6s	remaining: 3.96s
# 920:	learn: 0.0590764	total: 45.6s	remaining: 3.91s
# 921:	learn: 0.0590752	total: 45.7s	remaining: 3.86s
# 922:	learn: 0.0590738	total: 45.7s	remaining: 3.81s
# 923:	learn: 0.0590720	total: 45.8s	remaining: 3.76s
# 924:	learn: 0.0590707	total: 45.8s	remaining: 3.71s
# 925:	learn: 0.0590686	total: 45.9s	remaining: 3.67s
# 926:	learn: 0.0590670	total: 45.9s	remaining: 3.62s
# 927:	learn: 0.0590653	total: 46s	remaining: 3.57s
# 928:	learn: 0.0590635	total: 46s	remaining: 3.52s
# 929:	learn: 0.0590614	total: 46.1s	remaining: 3.47s
# 930:	learn: 0.0590595	total: 46.1s	remaining: 3.42s
# 931:	learn: 0.0590569	total: 46.2s	remaining: 3.37s
# 932:	learn: 0.0590554	total: 46.2s	remaining: 3.32s
# 933:	learn: 0.0590545	total: 46.3s	remaining: 3.27s
# 934:	learn: 0.0590532	total: 46.3s	remaining: 3.22s
# 935:	learn: 0.0590519	total: 46.4s	remaining: 3.17s
# 936:	learn: 0.0590509	total: 46.4s	remaining: 3.12s
# 937:	learn: 0.0590494	total: 46.5s	remaining: 3.07s
# 938:	learn: 0.0590480	total: 46.5s	remaining: 3.02s
# 939:	learn: 0.0590460	total: 46.6s	remaining: 2.97s
# 940:	learn: 0.0590441	total: 46.6s	remaining: 2.92s
# 941:	learn: 0.0590420	total: 46.7s	remaining: 2.87s
# 942:	learn: 0.0590402	total: 46.7s	remaining: 2.82s
# 943:	learn: 0.0590383	total: 46.8s	remaining: 2.77s
# 944:	learn: 0.0590361	total: 46.8s	remaining: 2.72s
# 945:	learn: 0.0590348	total: 46.9s	remaining: 2.67s
# 946:	learn: 0.0590332	total: 46.9s	remaining: 2.63s
# 947:	learn: 0.0590310	total: 47s	remaining: 2.58s
# 948:	learn: 0.0590300	total: 47s	remaining: 2.52s
# 949:	learn: 0.0590290	total: 47s	remaining: 2.48s
# 950:	learn: 0.0590259	total: 47.1s	remaining: 2.43s
# 951:	learn: 0.0590236	total: 47.2s	remaining: 2.38s
# 952:	learn: 0.0590219	total: 47.2s	remaining: 2.33s
# 953:	learn: 0.0590200	total: 47.3s	remaining: 2.28s
# 954:	learn: 0.0590174	total: 47.3s	remaining: 2.23s
# 955:	learn: 0.0590152	total: 47.3s	remaining: 2.18s
# 956:	learn: 0.0590124	total: 47.4s	remaining: 2.13s
# 957:	learn: 0.0590112	total: 47.4s	remaining: 2.08s
# 958:	learn: 0.0590084	total: 47.5s	remaining: 2.03s
# 959:	learn: 0.0590060	total: 47.5s	remaining: 1.98s
# 960:	learn: 0.0590044	total: 47.6s	remaining: 1.93s
# 961:	learn: 0.0590016	total: 47.6s	remaining: 1.88s
# 962:	learn: 0.0589999	total: 47.7s	remaining: 1.83s
# 963:	learn: 0.0589986	total: 47.7s	remaining: 1.78s
# 964:	learn: 0.0589969	total: 47.8s	remaining: 1.73s
# 965:	learn: 0.0589960	total: 47.8s	remaining: 1.68s
# 966:	learn: 0.0589945	total: 47.9s	remaining: 1.63s
# 967:	learn: 0.0589932	total: 47.9s	remaining: 1.58s
# 968:	learn: 0.0589915	total: 48s	remaining: 1.53s
# 969:	learn: 0.0589902	total: 48s	remaining: 1.49s
# 970:	learn: 0.0589883	total: 48.1s	remaining: 1.44s
# 971:	learn: 0.0589864	total: 48.1s	remaining: 1.39s
# 972:	learn: 0.0589843	total: 48.2s	remaining: 1.34s
# 973:	learn: 0.0589831	total: 48.2s	remaining: 1.29s
# 974:	learn: 0.0589809	total: 48.3s	remaining: 1.24s
# 975:	learn: 0.0589792	total: 48.3s	remaining: 1.19s
# 976:	learn: 0.0589782	total: 48.4s	remaining: 1.14s
# 977:	learn: 0.0589756	total: 48.4s	remaining: 1.09s
# 978:	learn: 0.0589740	total: 48.5s	remaining: 1.04s
# 979:	learn: 0.0589725	total: 48.5s	remaining: 990ms
# 980:	learn: 0.0589711	total: 48.6s	remaining: 941ms
# 981:	learn: 0.0589691	total: 48.6s	remaining: 891ms
# 982:	learn: 0.0589680	total: 48.7s	remaining: 842ms
# 983:	learn: 0.0589669	total: 48.7s	remaining: 792ms
# 984:	learn: 0.0589637	total: 48.8s	remaining: 743ms
# 985:	learn: 0.0589616	total: 48.8s	remaining: 693ms
# 986:	learn: 0.0589594	total: 48.9s	remaining: 644ms
# 987:	learn: 0.0589581	total: 48.9s	remaining: 594ms
# 988:	learn: 0.0589564	total: 49s	remaining: 545ms
# 989:	learn: 0.0589542	total: 49s	remaining: 495ms
# 990:	learn: 0.0589525	total: 49.1s	remaining: 446ms
# 991:	learn: 0.0589504	total: 49.1s	remaining: 396ms
# 992:	learn: 0.0589479	total: 49.2s	remaining: 347ms
# 993:	learn: 0.0589459	total: 49.2s	remaining: 297ms
# 994:	learn: 0.0589439	total: 49.3s	remaining: 248ms
# 995:	learn: 0.0589429	total: 49.3s	remaining: 198ms
# 996:	learn: 0.0589422	total: 49.4s	remaining: 149ms
# 997:	learn: 0.0589406	total: 49.4s	remaining: 99ms
# 998:	learn: 0.0589385	total: 49.5s	remaining: 49.5ms
# 999:	learn: 0.0589370	total: 49.5s	remaining: 0us

# %% [markdown]
# Xgboost

# %%
dtrain = xgb.DMatrix(x_train_std,label = y_train)
dtest = xgb.DMatrix(x_test_std,label = y_test)
dtrain_17 = xgb.DMatrix(x_17_train_std,label = y_17_train)
dtest_17 = xgb.DMatrix(x_17_test_std,label = y_17_test)

# %%
param1 = {'max_depth':4, 'eta':0.1, 'subsample':0.8, 'colsample_bytree':0.8, 'alpha':0.01, 'objective':'reg:linear', 'early_stopping_rounds':30}

# specify validations set to watch performance
watchlist = [(dtest, 'eval'), (dtrain, 'train')]
watchlist_17 = [(dtest_17, 'eval'), (dtrain_17, 'train')]
num_round = 300
bst1 = xgb.train(param1, dtrain, num_round, watchlist)
bst1_17 = xgb.train(param1, dtrain_17, num_round, watchlist_17)
# Out:
# [0]	eval-rmse:0.447774	train-rmse:0.447975
# [1]	eval-rmse:0.403827	train-rmse:0.404031
# [2]	eval-rmse:0.364407	train-rmse:0.364615
# [3]	eval-rmse:0.32901	train-rmse:0.329219
# [4]	eval-rmse:0.297238	train-rmse:0.297453
# [5]	eval-rmse:0.268782	train-rmse:0.269002
# [6]	eval-rmse:0.243303	train-rmse:0.243525
# [7]	eval-rmse:0.220523	train-rmse:0.220746
# [8]	eval-rmse:0.200181	train-rmse:0.200404
# [9]	eval-rmse:0.182057	train-rmse:0.182284
# [10]	eval-rmse:0.165901	train-rmse:0.166132
# [11]	eval-rmse:0.151571	train-rmse:0.151798
# [12]	eval-rmse:0.13887	train-rmse:0.139098
# [13]	eval-rmse:0.127675	train-rmse:0.1279
# [14]	eval-rmse:0.117812	train-rmse:0.118032
# [15]	eval-rmse:0.109197	train-rmse:0.109407
# [16]	eval-rmse:0.10168	train-rmse:0.101873
# [17]	eval-rmse:0.095131	train-rmse:0.095319
# [18]	eval-rmse:0.089483	train-rmse:0.089663
# [19]	eval-rmse:0.084636	train-rmse:0.084805
# [20]	eval-rmse:0.080496	train-rmse:0.080653
# [21]	eval-rmse:0.076963	train-rmse:0.077112
# [22]	eval-rmse:0.073984	train-rmse:0.074119
# [23]	eval-rmse:0.071487	train-rmse:0.071615
# [24]	eval-rmse:0.069397	train-rmse:0.069515
# [25]	eval-rmse:0.067654	train-rmse:0.067754
# [26]	eval-rmse:0.06621	train-rmse:0.066296
# [27]	eval-rmse:0.065021	train-rmse:0.065097
# [28]	eval-rmse:0.064042	train-rmse:0.064099
# [29]	eval-rmse:0.063231	train-rmse:0.063274
# [30]	eval-rmse:0.062569	train-rmse:0.062601
# [31]	eval-rmse:0.062028	train-rmse:0.062049
# [32]	eval-rmse:0.061583	train-rmse:0.061591
# [33]	eval-rmse:0.061221	train-rmse:0.061211
# [34]	eval-rmse:0.060932	train-rmse:0.060906
# [35]	eval-rmse:0.060699	train-rmse:0.060656
# [36]	eval-rmse:0.060496	train-rmse:0.060442
# [37]	eval-rmse:0.060333	train-rmse:0.060268
# [38]	eval-rmse:0.060204	train-rmse:0.060131
# [39]	eval-rmse:0.060088	train-rmse:0.060003
# [40]	eval-rmse:0.059999	train-rmse:0.059903
# [41]	eval-rmse:0.059928	train-rmse:0.059822
# [42]	eval-rmse:0.05987	train-rmse:0.059754
# [43]	eval-rmse:0.059823	train-rmse:0.059697
# [44]	eval-rmse:0.059782	train-rmse:0.059645
# [45]	eval-rmse:0.059753	train-rmse:0.059604
# [46]	eval-rmse:0.05973	train-rmse:0.059567
# [47]	eval-rmse:0.059711	train-rmse:0.059533
# [48]	eval-rmse:0.05969	train-rmse:0.059502
# [49]	eval-rmse:0.05967	train-rmse:0.059471
# [50]	eval-rmse:0.059653	train-rmse:0.05944
# [51]	eval-rmse:0.059646	train-rmse:0.05942
# [52]	eval-rmse:0.059639	train-rmse:0.0594
# [53]	eval-rmse:0.059621	train-rmse:0.05938
# [54]	eval-rmse:0.059617	train-rmse:0.059364
# [55]	eval-rmse:0.059612	train-rmse:0.059352
# [56]	eval-rmse:0.059608	train-rmse:0.059341
# [57]	eval-rmse:0.059603	train-rmse:0.059322
# [58]	eval-rmse:0.059602	train-rmse:0.05931
# [59]	eval-rmse:0.059596	train-rmse:0.059292
# [60]	eval-rmse:0.05959	train-rmse:0.059277
# [61]	eval-rmse:0.059589	train-rmse:0.059269
# [62]	eval-rmse:0.059578	train-rmse:0.05925
# [63]	eval-rmse:0.059579	train-rmse:0.059241
# [64]	eval-rmse:0.059575	train-rmse:0.05923
# [65]	eval-rmse:0.059572	train-rmse:0.059217
# [66]	eval-rmse:0.059572	train-rmse:0.059207
# [67]	eval-rmse:0.059568	train-rmse:0.059197
# [68]	eval-rmse:0.059566	train-rmse:0.059188
# [69]	eval-rmse:0.059563	train-rmse:0.059179
# [70]	eval-rmse:0.059565	train-rmse:0.059171
# [71]	eval-rmse:0.059561	train-rmse:0.05916
# [72]	eval-rmse:0.059557	train-rmse:0.059148
# [73]	eval-rmse:0.059553	train-rmse:0.059134
# [74]	eval-rmse:0.059547	train-rmse:0.059121
# [75]	eval-rmse:0.059548	train-rmse:0.059108
# [76]	eval-rmse:0.059546	train-rmse:0.059096
# [77]	eval-rmse:0.059542	train-rmse:0.059082
# [78]	eval-rmse:0.059547	train-rmse:0.059075
# [79]	eval-rmse:0.059545	train-rmse:0.059064
# [80]	eval-rmse:0.059532	train-rmse:0.059048
# [81]	eval-rmse:0.059528	train-rmse:0.059033
# [82]	eval-rmse:0.059517	train-rmse:0.059013
# [83]	eval-rmse:0.059519	train-rmse:0.058998
# [84]	eval-rmse:0.059517	train-rmse:0.058988
# [85]	eval-rmse:0.059511	train-rmse:0.058974
# [86]	eval-rmse:0.059511	train-rmse:0.058957
# [87]	eval-rmse:0.059504	train-rmse:0.058944
# [88]	eval-rmse:0.059502	train-rmse:0.058936
# [89]	eval-rmse:0.059501	train-rmse:0.058929
# [90]	eval-rmse:0.059498	train-rmse:0.058919
# [91]	eval-rmse:0.059494	train-rmse:0.058909
# [92]	eval-rmse:0.05949	train-rmse:0.058901
# [93]	eval-rmse:0.059486	train-rmse:0.058886
# [94]	eval-rmse:0.059486	train-rmse:0.05888
# [95]	eval-rmse:0.059483	train-rmse:0.058869
# [96]	eval-rmse:0.05948	train-rmse:0.058861
# [97]	eval-rmse:0.059481	train-rmse:0.058855
# [98]	eval-rmse:0.059484	train-rmse:0.058844
# [99]	eval-rmse:0.059482	train-rmse:0.058831
# [100]	eval-rmse:0.059472	train-rmse:0.058813
# [101]	eval-rmse:0.059473	train-rmse:0.058798
# [102]	eval-rmse:0.059473	train-rmse:0.058791
# [103]	eval-rmse:0.059466	train-rmse:0.05878
# [104]	eval-rmse:0.05947	train-rmse:0.058771
# [105]	eval-rmse:0.059472	train-rmse:0.058762
# [106]	eval-rmse:0.059471	train-rmse:0.058755
# [107]	eval-rmse:0.059467	train-rmse:0.058742
# [108]	eval-rmse:0.059473	train-rmse:0.058738
# [109]	eval-rmse:0.059469	train-rmse:0.058726
# [110]	eval-rmse:0.059469	train-rmse:0.058719
# [111]	eval-rmse:0.059473	train-rmse:0.058709
# [112]	eval-rmse:0.059473	train-rmse:0.058704
# [113]	eval-rmse:0.059472	train-rmse:0.058695
# [114]	eval-rmse:0.059466	train-rmse:0.058678
# [115]	eval-rmse:0.059465	train-rmse:0.058665
# [116]	eval-rmse:0.059462	train-rmse:0.058656
# [117]	eval-rmse:0.05946	train-rmse:0.058645
# [118]	eval-rmse:0.059457	train-rmse:0.058634
# [119]	eval-rmse:0.059453	train-rmse:0.058622
# [120]	eval-rmse:0.059451	train-rmse:0.058616
# [121]	eval-rmse:0.059447	train-rmse:0.058607
# [122]	eval-rmse:0.059441	train-rmse:0.058596
# [123]	eval-rmse:0.05944	train-rmse:0.058584
# [124]	eval-rmse:0.059431	train-rmse:0.058571
# [125]	eval-rmse:0.059431	train-rmse:0.058563
# [126]	eval-rmse:0.059434	train-rmse:0.058555
# [127]	eval-rmse:0.059436	train-rmse:0.058547
# [128]	eval-rmse:0.059432	train-rmse:0.058537
# [129]	eval-rmse:0.059431	train-rmse:0.05853
# [130]	eval-rmse:0.059435	train-rmse:0.058521
# [131]	eval-rmse:0.05944	train-rmse:0.058513
# [132]	eval-rmse:0.059436	train-rmse:0.058499
# [133]	eval-rmse:0.059434	train-rmse:0.058492
# [134]	eval-rmse:0.059432	train-rmse:0.058483
# [135]	eval-rmse:0.059435	train-rmse:0.058477
# [136]	eval-rmse:0.059437	train-rmse:0.058471
# [137]	eval-rmse:0.059435	train-rmse:0.058464
# [138]	eval-rmse:0.059433	train-rmse:0.058455
# [139]	eval-rmse:0.05943	train-rmse:0.058448
# [140]	eval-rmse:0.059431	train-rmse:0.058437
# [141]	eval-rmse:0.059431	train-rmse:0.058427
# [142]	eval-rmse:0.059432	train-rmse:0.058417
# [143]	eval-rmse:0.059428	train-rmse:0.058409
# [144]	eval-rmse:0.059428	train-rmse:0.058395
# [145]	eval-rmse:0.059426	train-rmse:0.058386
# [146]	eval-rmse:0.059419	train-rmse:0.058375
# [147]	eval-rmse:0.059413	train-rmse:0.058362
# [148]	eval-rmse:0.059413	train-rmse:0.058353
# [149]	eval-rmse:0.059413	train-rmse:0.058344
# [150]	eval-rmse:0.059413	train-rmse:0.058335
# [151]	eval-rmse:0.059409	train-rmse:0.058324
# [152]	eval-rmse:0.059409	train-rmse:0.058317
# [153]	eval-rmse:0.059411	train-rmse:0.058306
# [154]	eval-rmse:0.059404	train-rmse:0.058299
# [155]	eval-rmse:0.059404	train-rmse:0.058291
# [156]	eval-rmse:0.059401	train-rmse:0.058284
# [157]	eval-rmse:0.059399	train-rmse:0.058274
# [158]	eval-rmse:0.059397	train-rmse:0.058267
# [159]	eval-rmse:0.059391	train-rmse:0.058258
# [160]	eval-rmse:0.059393	train-rmse:0.058249
# [161]	eval-rmse:0.059395	train-rmse:0.058241
# [162]	eval-rmse:0.059392	train-rmse:0.058232
# [163]	eval-rmse:0.059393	train-rmse:0.058224
# [164]	eval-rmse:0.059392	train-rmse:0.058216
# [165]	eval-rmse:0.059388	train-rmse:0.058206
# [166]	eval-rmse:0.059387	train-rmse:0.058196
# [167]	eval-rmse:0.059388	train-rmse:0.058187
# [168]	eval-rmse:0.059392	train-rmse:0.058178
# [169]	eval-rmse:0.059394	train-rmse:0.05817
# [170]	eval-rmse:0.059397	train-rmse:0.058164
# [171]	eval-rmse:0.059394	train-rmse:0.058155
# [172]	eval-rmse:0.059395	train-rmse:0.05815
# [173]	eval-rmse:0.059395	train-rmse:0.058146
# [174]	eval-rmse:0.059389	train-rmse:0.058131
# [175]	eval-rmse:0.059385	train-rmse:0.058123
# [176]	eval-rmse:0.05938	train-rmse:0.058114
# [177]	eval-rmse:0.059376	train-rmse:0.058104
# [178]	eval-rmse:0.059371	train-rmse:0.058098
# [179]	eval-rmse:0.059372	train-rmse:0.05809
# [180]	eval-rmse:0.059375	train-rmse:0.058087
# [181]	eval-rmse:0.059375	train-rmse:0.05808
# [182]	eval-rmse:0.059371	train-rmse:0.05807
# [183]	eval-rmse:0.059364	train-rmse:0.058058
# [184]	eval-rmse:0.059363	train-rmse:0.058048
# [185]	eval-rmse:0.059362	train-rmse:0.058041
# [186]	eval-rmse:0.059362	train-rmse:0.058033
# [187]	eval-rmse:0.05936	train-rmse:0.058023
# [188]	eval-rmse:0.059359	train-rmse:0.058017
# [189]	eval-rmse:0.05936	train-rmse:0.058008
# [190]	eval-rmse:0.059357	train-rmse:0.058
# [191]	eval-rmse:0.059358	train-rmse:0.057993
# [192]	eval-rmse:0.059359	train-rmse:0.057984
# [193]	eval-rmse:0.059356	train-rmse:0.057974
# [194]	eval-rmse:0.059357	train-rmse:0.057966
# [195]	eval-rmse:0.059352	train-rmse:0.05796
# [196]	eval-rmse:0.059348	train-rmse:0.057948
# [197]	eval-rmse:0.059347	train-rmse:0.05794
# [198]	eval-rmse:0.059348	train-rmse:0.057934
# [199]	eval-rmse:0.059348	train-rmse:0.057926
# [200]	eval-rmse:0.059348	train-rmse:0.057919
# [201]	eval-rmse:0.059348	train-rmse:0.057912
# [202]	eval-rmse:0.059346	train-rmse:0.057903
# [203]	eval-rmse:0.059347	train-rmse:0.057898
# [204]	eval-rmse:0.059348	train-rmse:0.057889
# [205]	eval-rmse:0.059351	train-rmse:0.057882
# [206]	eval-rmse:0.05935	train-rmse:0.057873
# [207]	eval-rmse:0.059346	train-rmse:0.057862
# [208]	eval-rmse:0.059344	train-rmse:0.057849
# [209]	eval-rmse:0.059345	train-rmse:0.05784
# [210]	eval-rmse:0.059343	train-rmse:0.057831
# [211]	eval-rmse:0.059347	train-rmse:0.057826
# [212]	eval-rmse:0.059346	train-rmse:0.057819
# [213]	eval-rmse:0.059345	train-rmse:0.057814
# [214]	eval-rmse:0.059351	train-rmse:0.057805
# [215]	eval-rmse:0.059351	train-rmse:0.057798
# [216]	eval-rmse:0.05935	train-rmse:0.05779
# [217]	eval-rmse:0.05935	train-rmse:0.057782
# [218]	eval-rmse:0.059347	train-rmse:0.057773
# [219]	eval-rmse:0.059348	train-rmse:0.057766
# [220]	eval-rmse:0.059346	train-rmse:0.05776
# [221]	eval-rmse:0.059348	train-rmse:0.057752
# [222]	eval-rmse:0.059348	train-rmse:0.057748
# [223]	eval-rmse:0.059345	train-rmse:0.057741
# [224]	eval-rmse:0.059345	train-rmse:0.057738
# [225]	eval-rmse:0.059346	train-rmse:0.057729
# [226]	eval-rmse:0.059348	train-rmse:0.057715
# [227]	eval-rmse:0.05935	train-rmse:0.057707
# [228]	eval-rmse:0.059349	train-rmse:0.057697
# [229]	eval-rmse:0.059349	train-rmse:0.05769
# [230]	eval-rmse:0.05935	train-rmse:0.057684
# [231]	eval-rmse:0.059348	train-rmse:0.057675
# [232]	eval-rmse:0.059348	train-rmse:0.057665
# [233]	eval-rmse:0.05935	train-rmse:0.057658
# [234]	eval-rmse:0.059351	train-rmse:0.057656
# [235]	eval-rmse:0.059351	train-rmse:0.05765
# [236]	eval-rmse:0.059348	train-rmse:0.057643
# [237]	eval-rmse:0.059349	train-rmse:0.057635
# [238]	eval-rmse:0.059348	train-rmse:0.057625
# [239]	eval-rmse:0.05935	train-rmse:0.057616
# [240]	eval-rmse:0.05935	train-rmse:0.057607
# [241]	eval-rmse:0.059348	train-rmse:0.057602
# [242]	eval-rmse:0.05935	train-rmse:0.057596
# [243]	eval-rmse:0.059349	train-rmse:0.057589
# [244]	eval-rmse:0.059348	train-rmse:0.057584
# [245]	eval-rmse:0.059348	train-rmse:0.057578
# [246]	eval-rmse:0.059352	train-rmse:0.05757
# [247]	eval-rmse:0.05935	train-rmse:0.057561
# [248]	eval-rmse:0.059348	train-rmse:0.057553
# [249]	eval-rmse:0.05935	train-rmse:0.057545
# [250]	eval-rmse:0.059351	train-rmse:0.057537
# [251]	eval-rmse:0.059353	train-rmse:0.057533
# [252]	eval-rmse:0.059352	train-rmse:0.057526
# [253]	eval-rmse:0.059349	train-rmse:0.057519
# [254]	eval-rmse:0.059351	train-rmse:0.05751
# [255]	eval-rmse:0.059353	train-rmse:0.057507
# [256]	eval-rmse:0.059351	train-rmse:0.057497
# [257]	eval-rmse:0.05935	train-rmse:0.057488
# [258]	eval-rmse:0.059353	train-rmse:0.057483
# [259]	eval-rmse:0.059355	train-rmse:0.057475
# [260]	eval-rmse:0.059359	train-rmse:0.057468
# [261]	eval-rmse:0.059357	train-rmse:0.057461
# [262]	eval-rmse:0.059356	train-rmse:0.057455
# [263]	eval-rmse:0.059357	train-rmse:0.057443
# [264]	eval-rmse:0.059356	train-rmse:0.057435
# [265]	eval-rmse:0.059356	train-rmse:0.057424
# [266]	eval-rmse:0.059356	train-rmse:0.057418
# [267]	eval-rmse:0.059355	train-rmse:0.057416
# [268]	eval-rmse:0.05936	train-rmse:0.057404
# [269]	eval-rmse:0.059359	train-rmse:0.057397
# [270]	eval-rmse:0.059361	train-rmse:0.05739
# [271]	eval-rmse:0.059363	train-rmse:0.057387
# [272]	eval-rmse:0.059364	train-rmse:0.057379
# [273]	eval-rmse:0.059363	train-rmse:0.05737
# [274]	eval-rmse:0.059363	train-rmse:0.057364
# [275]	eval-rmse:0.059365	train-rmse:0.057356
# [276]	eval-rmse:0.059365	train-rmse:0.057347
# [277]	eval-rmse:0.059366	train-rmse:0.057342
# [278]	eval-rmse:0.059368	train-rmse:0.057337
# [279]	eval-rmse:0.059366	train-rmse:0.057325
# [280]	eval-rmse:0.059367	train-rmse:0.057318
# [281]	eval-rmse:0.059368	train-rmse:0.057307
# [282]	eval-rmse:0.059369	train-rmse:0.0573
# [283]	eval-rmse:0.059367	train-rmse:0.057292
# [284]	eval-rmse:0.059364	train-rmse:0.057287
# [285]	eval-rmse:0.059364	train-rmse:0.057283
# [286]	eval-rmse:0.059366	train-rmse:0.057275
# [287]	eval-rmse:0.059367	train-rmse:0.057269
# [288]	eval-rmse:0.059367	train-rmse:0.057261
# [289]	eval-rmse:0.059369	train-rmse:0.057256
# [290]	eval-rmse:0.059369	train-rmse:0.057249
# [291]	eval-rmse:0.059372	train-rmse:0.057242
# [292]	eval-rmse:0.059371	train-rmse:0.057233
# [293]	eval-rmse:0.059371	train-rmse:0.057229
# [294]	eval-rmse:0.05937	train-rmse:0.057219
# [295]	eval-rmse:0.059367	train-rmse:0.057209
# [296]	eval-rmse:0.059365	train-rmse:0.0572
# [297]	eval-rmse:0.05936	train-rmse:0.057192
# [298]	eval-rmse:0.059355	train-rmse:0.057183
# [299]	eval-rmse:0.059352	train-rmse:0.057179
# [0]	eval-rmse:0.446592	train-rmse:0.44655
# [1]	eval-rmse:0.402844	train-rmse:0.4028
# [2]	eval-rmse:0.363572	train-rmse:0.363522
# [3]	eval-rmse:0.328308	train-rmse:0.328256
# [4]	eval-rmse:0.296711	train-rmse:0.296651
# [5]	eval-rmse:0.268417	train-rmse:0.268344
# [6]	eval-rmse:0.243054	train-rmse:0.242977
# [7]	eval-rmse:0.220403	train-rmse:0.220314
# [8]	eval-rmse:0.200199	train-rmse:0.20009
# [9]	eval-rmse:0.182186	train-rmse:0.182067
# [10]	eval-rmse:0.166141	train-rmse:0.16601
# [11]	eval-rmse:0.151922	train-rmse:0.151776
# [12]	eval-rmse:0.13934	train-rmse:0.139184
# [13]	eval-rmse:0.128232	train-rmse:0.128059
# [14]	eval-rmse:0.118463	train-rmse:0.118275
# [15]	eval-rmse:0.109929	train-rmse:0.10972
# [16]	eval-rmse:0.102491	train-rmse:0.102255
# [17]	eval-rmse:0.09606	train-rmse:0.095798
# [18]	eval-rmse:0.090492	train-rmse:0.090212
# [19]	eval-rmse:0.085706	train-rmse:0.085403
# [20]	eval-rmse:0.081635	train-rmse:0.081311
# [21]	eval-rmse:0.078175	train-rmse:0.077835
# [22]	eval-rmse:0.075264	train-rmse:0.074902
# [23]	eval-rmse:0.072822	train-rmse:0.072438
# [24]	eval-rmse:0.070779	train-rmse:0.070377
# [25]	eval-rmse:0.069086	train-rmse:0.068663
# [26]	eval-rmse:0.067671	train-rmse:0.067236
# [27]	eval-rmse:0.066505	train-rmse:0.066054
# [28]	eval-rmse:0.065548	train-rmse:0.065081
# [29]	eval-rmse:0.064747	train-rmse:0.06427
# [30]	eval-rmse:0.064095	train-rmse:0.063601
# [31]	eval-rmse:0.06356	train-rmse:0.063054
# [32]	eval-rmse:0.063124	train-rmse:0.062606
# [33]	eval-rmse:0.062775	train-rmse:0.062242
# [34]	eval-rmse:0.062482	train-rmse:0.061933
# [35]	eval-rmse:0.062239	train-rmse:0.061686
# [36]	eval-rmse:0.062048	train-rmse:0.06148
# [37]	eval-rmse:0.061889	train-rmse:0.061309
# [38]	eval-rmse:0.06176	train-rmse:0.061171
# [39]	eval-rmse:0.061649	train-rmse:0.061048
# [40]	eval-rmse:0.061558	train-rmse:0.060949
# [41]	eval-rmse:0.061486	train-rmse:0.060866
# [42]	eval-rmse:0.061424	train-rmse:0.060796
# [43]	eval-rmse:0.061371	train-rmse:0.060732
# [44]	eval-rmse:0.061328	train-rmse:0.060682
# [45]	eval-rmse:0.061296	train-rmse:0.060639
# [46]	eval-rmse:0.061269	train-rmse:0.060602
# [47]	eval-rmse:0.06126	train-rmse:0.060567
# [48]	eval-rmse:0.061244	train-rmse:0.060532
# [49]	eval-rmse:0.061234	train-rmse:0.060504
# [50]	eval-rmse:0.061219	train-rmse:0.060478
# [51]	eval-rmse:0.06121	train-rmse:0.060454
# [52]	eval-rmse:0.061198	train-rmse:0.060436
# [53]	eval-rmse:0.061185	train-rmse:0.060418
# [54]	eval-rmse:0.061175	train-rmse:0.0604
# [55]	eval-rmse:0.061174	train-rmse:0.060383
# [56]	eval-rmse:0.061168	train-rmse:0.06037
# [57]	eval-rmse:0.061165	train-rmse:0.060355
# [58]	eval-rmse:0.061169	train-rmse:0.06034
# [59]	eval-rmse:0.061167	train-rmse:0.060323
# [60]	eval-rmse:0.061164	train-rmse:0.06031
# [61]	eval-rmse:0.061162	train-rmse:0.060299
# [62]	eval-rmse:0.06116	train-rmse:0.060284
# [63]	eval-rmse:0.061155	train-rmse:0.060272
# [64]	eval-rmse:0.061152	train-rmse:0.060256
# [65]	eval-rmse:0.061149	train-rmse:0.060244
# [66]	eval-rmse:0.06115	train-rmse:0.060234
# [67]	eval-rmse:0.061148	train-rmse:0.060226
# [68]	eval-rmse:0.061148	train-rmse:0.060216
# [69]	eval-rmse:0.061157	train-rmse:0.060198
# [70]	eval-rmse:0.061156	train-rmse:0.060186
# [71]	eval-rmse:0.061147	train-rmse:0.060168
# [72]	eval-rmse:0.061145	train-rmse:0.060155
# [73]	eval-rmse:0.061148	train-rmse:0.060145
# [74]	eval-rmse:0.061144	train-rmse:0.060133
# [75]	eval-rmse:0.061143	train-rmse:0.060129
# [76]	eval-rmse:0.061145	train-rmse:0.060121
# [77]	eval-rmse:0.061141	train-rmse:0.060111
# [78]	eval-rmse:0.061139	train-rmse:0.060097
# [79]	eval-rmse:0.061133	train-rmse:0.060088
# [80]	eval-rmse:0.061124	train-rmse:0.060073
# [81]	eval-rmse:0.061122	train-rmse:0.060068
# [82]	eval-rmse:0.061124	train-rmse:0.060062
# [83]	eval-rmse:0.061122	train-rmse:0.060053
# [84]	eval-rmse:0.061128	train-rmse:0.060039
# [85]	eval-rmse:0.061125	train-rmse:0.060024
# [86]	eval-rmse:0.061121	train-rmse:0.060011
# [87]	eval-rmse:0.061121	train-rmse:0.060002
# [88]	eval-rmse:0.06112	train-rmse:0.059991
# [89]	eval-rmse:0.061124	train-rmse:0.059982
# [90]	eval-rmse:0.061118	train-rmse:0.05997
# [91]	eval-rmse:0.061116	train-rmse:0.059962
# [92]	eval-rmse:0.061113	train-rmse:0.059955
# [93]	eval-rmse:0.061109	train-rmse:0.059938
# [94]	eval-rmse:0.061113	train-rmse:0.059926
# [95]	eval-rmse:0.061115	train-rmse:0.059914
# [96]	eval-rmse:0.061119	train-rmse:0.059906
# [97]	eval-rmse:0.061113	train-rmse:0.059893
# [98]	eval-rmse:0.06111	train-rmse:0.059884
# [99]	eval-rmse:0.061112	train-rmse:0.059878
# [100]	eval-rmse:0.061105	train-rmse:0.059864
# [101]	eval-rmse:0.061114	train-rmse:0.059856
# [102]	eval-rmse:0.061114	train-rmse:0.05984
# [103]	eval-rmse:0.061113	train-rmse:0.059828
# [104]	eval-rmse:0.061117	train-rmse:0.05982
# [105]	eval-rmse:0.061113	train-rmse:0.059815
# [106]	eval-rmse:0.061115	train-rmse:0.059804
# [107]	eval-rmse:0.061116	train-rmse:0.059788
# [108]	eval-rmse:0.061111	train-rmse:0.059775
# [109]	eval-rmse:0.061107	train-rmse:0.059764
# [110]	eval-rmse:0.061105	train-rmse:0.059756
# [111]	eval-rmse:0.061099	train-rmse:0.059743
# [112]	eval-rmse:0.0611	train-rmse:0.059733
# [113]	eval-rmse:0.061095	train-rmse:0.059722
# [114]	eval-rmse:0.061099	train-rmse:0.059711
# [115]	eval-rmse:0.061092	train-rmse:0.059701
# [116]	eval-rmse:0.061094	train-rmse:0.059692
# [117]	eval-rmse:0.061094	train-rmse:0.059683
# [118]	eval-rmse:0.061093	train-rmse:0.059671
# [119]	eval-rmse:0.061092	train-rmse:0.059656
# [120]	eval-rmse:0.0611	train-rmse:0.059644
# [121]	eval-rmse:0.061101	train-rmse:0.059639
# [122]	eval-rmse:0.0611	train-rmse:0.059633
# [123]	eval-rmse:0.061106	train-rmse:0.059623
# [124]	eval-rmse:0.061107	train-rmse:0.059615
# [125]	eval-rmse:0.06111	train-rmse:0.059606
# [126]	eval-rmse:0.061108	train-rmse:0.059597
# [127]	eval-rmse:0.061104	train-rmse:0.059592
# [128]	eval-rmse:0.061102	train-rmse:0.059582
# [129]	eval-rmse:0.061103	train-rmse:0.059572
# [130]	eval-rmse:0.061101	train-rmse:0.059562
# [131]	eval-rmse:0.061102	train-rmse:0.059554
# [132]	eval-rmse:0.061095	train-rmse:0.059547
# [133]	eval-rmse:0.061094	train-rmse:0.059536
# [134]	eval-rmse:0.061092	train-rmse:0.059529
# [135]	eval-rmse:0.061089	train-rmse:0.059517
# [136]	eval-rmse:0.06109	train-rmse:0.059508
# [137]	eval-rmse:0.061092	train-rmse:0.059499
# [138]	eval-rmse:0.061097	train-rmse:0.05949
# [139]	eval-rmse:0.061093	train-rmse:0.05948
# [140]	eval-rmse:0.061091	train-rmse:0.059471
# [141]	eval-rmse:0.061084	train-rmse:0.059458
# [142]	eval-rmse:0.06108	train-rmse:0.059442
# [143]	eval-rmse:0.061077	train-rmse:0.059437
# [144]	eval-rmse:0.061077	train-rmse:0.059429
# [145]	eval-rmse:0.061075	train-rmse:0.059419
# [146]	eval-rmse:0.061073	train-rmse:0.059409
# [147]	eval-rmse:0.061073	train-rmse:0.059403
# [148]	eval-rmse:0.061075	train-rmse:0.059396
# [149]	eval-rmse:0.061077	train-rmse:0.059387
# [150]	eval-rmse:0.061075	train-rmse:0.059373
# [151]	eval-rmse:0.061074	train-rmse:0.059361
# [152]	eval-rmse:0.061073	train-rmse:0.059349
# [153]	eval-rmse:0.061072	train-rmse:0.059345
# [154]	eval-rmse:0.061072	train-rmse:0.059341
# [155]	eval-rmse:0.061072	train-rmse:0.059332
# [156]	eval-rmse:0.061071	train-rmse:0.059325
# [157]	eval-rmse:0.061075	train-rmse:0.059316
# [158]	eval-rmse:0.06108	train-rmse:0.059312
# [159]	eval-rmse:0.06108	train-rmse:0.059302
# [160]	eval-rmse:0.061075	train-rmse:0.059291
# [161]	eval-rmse:0.061075	train-rmse:0.05928
# [162]	eval-rmse:0.061075	train-rmse:0.05927
# [163]	eval-rmse:0.061073	train-rmse:0.059258
# [164]	eval-rmse:0.06108	train-rmse:0.059249
# [165]	eval-rmse:0.06108	train-rmse:0.059244
# [166]	eval-rmse:0.06108	train-rmse:0.05923
# [167]	eval-rmse:0.061078	train-rmse:0.059225
# [168]	eval-rmse:0.061081	train-rmse:0.059215
# [169]	eval-rmse:0.061078	train-rmse:0.059204
# [170]	eval-rmse:0.061079	train-rmse:0.059195
# [171]	eval-rmse:0.061076	train-rmse:0.059186
# [172]	eval-rmse:0.061078	train-rmse:0.059178
# [173]	eval-rmse:0.061074	train-rmse:0.059167
# [174]	eval-rmse:0.061075	train-rmse:0.059154
# [175]	eval-rmse:0.06107	train-rmse:0.059148
# [176]	eval-rmse:0.061067	train-rmse:0.059139
# [177]	eval-rmse:0.061068	train-rmse:0.059128
# [178]	eval-rmse:0.061071	train-rmse:0.059122
# [179]	eval-rmse:0.06107	train-rmse:0.059116
# [180]	eval-rmse:0.061071	train-rmse:0.059109
# [181]	eval-rmse:0.061074	train-rmse:0.059098
# [182]	eval-rmse:0.061076	train-rmse:0.059084
# [183]	eval-rmse:0.061076	train-rmse:0.059073
# [184]	eval-rmse:0.061077	train-rmse:0.059064
# [185]	eval-rmse:0.061077	train-rmse:0.059054
# [186]	eval-rmse:0.061078	train-rmse:0.059048
# [187]	eval-rmse:0.061083	train-rmse:0.059037
# [188]	eval-rmse:0.061081	train-rmse:0.059029
# [189]	eval-rmse:0.06108	train-rmse:0.059023
# [190]	eval-rmse:0.061079	train-rmse:0.059011
# [191]	eval-rmse:0.061076	train-rmse:0.059001
# [192]	eval-rmse:0.061075	train-rmse:0.058995
# [193]	eval-rmse:0.061077	train-rmse:0.058988
# [194]	eval-rmse:0.061076	train-rmse:0.058983
# [195]	eval-rmse:0.061077	train-rmse:0.058976
# [196]	eval-rmse:0.061076	train-rmse:0.058968
# [197]	eval-rmse:0.061077	train-rmse:0.058962
# [198]	eval-rmse:0.061075	train-rmse:0.058952
# [199]	eval-rmse:0.061079	train-rmse:0.058946
# [200]	eval-rmse:0.061077	train-rmse:0.058937
# [201]	eval-rmse:0.061077	train-rmse:0.058928
# [202]	eval-rmse:0.061073	train-rmse:0.058917
# [203]	eval-rmse:0.061074	train-rmse:0.058913
# [204]	eval-rmse:0.061075	train-rmse:0.058904
# [205]	eval-rmse:0.061072	train-rmse:0.058894
# [206]	eval-rmse:0.06107	train-rmse:0.058887
# [207]	eval-rmse:0.061067	train-rmse:0.05888
# [208]	eval-rmse:0.061069	train-rmse:0.05887
# [209]	eval-rmse:0.061064	train-rmse:0.058859
# [210]	eval-rmse:0.061064	train-rmse:0.05885
# [211]	eval-rmse:0.061062	train-rmse:0.058841
# [212]	eval-rmse:0.061062	train-rmse:0.058832
# [213]	eval-rmse:0.061064	train-rmse:0.058825
# [214]	eval-rmse:0.061062	train-rmse:0.058819
# [215]	eval-rmse:0.061062	train-rmse:0.058811
# [216]	eval-rmse:0.061063	train-rmse:0.058802
# [217]	eval-rmse:0.061066	train-rmse:0.058794
# [218]	eval-rmse:0.061064	train-rmse:0.058788
# [219]	eval-rmse:0.061058	train-rmse:0.058778
# [220]	eval-rmse:0.061061	train-rmse:0.058769
# [221]	eval-rmse:0.061066	train-rmse:0.058761
# [222]	eval-rmse:0.061068	train-rmse:0.058755
# [223]	eval-rmse:0.06107	train-rmse:0.058748
# [224]	eval-rmse:0.061072	train-rmse:0.058741
# [225]	eval-rmse:0.061074	train-rmse:0.058734
# [226]	eval-rmse:0.061078	train-rmse:0.058726
# [227]	eval-rmse:0.061085	train-rmse:0.058719
# [228]	eval-rmse:0.061083	train-rmse:0.058709
# [229]	eval-rmse:0.061083	train-rmse:0.0587
# [230]	eval-rmse:0.061085	train-rmse:0.058692
# [231]	eval-rmse:0.061083	train-rmse:0.058683
# [232]	eval-rmse:0.061081	train-rmse:0.058677
# [233]	eval-rmse:0.06108	train-rmse:0.058669
# [234]	eval-rmse:0.061085	train-rmse:0.058658
# [235]	eval-rmse:0.061085	train-rmse:0.058651
# [236]	eval-rmse:0.061082	train-rmse:0.05864
# [237]	eval-rmse:0.061081	train-rmse:0.058631
# [238]	eval-rmse:0.061079	train-rmse:0.058623
# [239]	eval-rmse:0.061078	train-rmse:0.058622
# [240]	eval-rmse:0.061079	train-rmse:0.058616
# [241]	eval-rmse:0.061077	train-rmse:0.058607
# [242]	eval-rmse:0.061075	train-rmse:0.058598
# [243]	eval-rmse:0.061075	train-rmse:0.058591
# [244]	eval-rmse:0.061074	train-rmse:0.058583
# [245]	eval-rmse:0.061081	train-rmse:0.058578
# [246]	eval-rmse:0.061086	train-rmse:0.058569
# [247]	eval-rmse:0.061088	train-rmse:0.058559
# [248]	eval-rmse:0.061085	train-rmse:0.058549
# [249]	eval-rmse:0.061081	train-rmse:0.058538
# [250]	eval-rmse:0.061077	train-rmse:0.058528
# [251]	eval-rmse:0.061076	train-rmse:0.058517
# [252]	eval-rmse:0.061074	train-rmse:0.058509
# [253]	eval-rmse:0.061071	train-rmse:0.058502
# [254]	eval-rmse:0.061073	train-rmse:0.058493
# [255]	eval-rmse:0.061071	train-rmse:0.058483
# [256]	eval-rmse:0.061076	train-rmse:0.058473
# [257]	eval-rmse:0.061079	train-rmse:0.058463
# [258]	eval-rmse:0.061078	train-rmse:0.058456
# [259]	eval-rmse:0.061081	train-rmse:0.058451
# [260]	eval-rmse:0.061082	train-rmse:0.058447
# [261]	eval-rmse:0.061081	train-rmse:0.058439
# [262]	eval-rmse:0.061081	train-rmse:0.058435
# [263]	eval-rmse:0.061082	train-rmse:0.058427
# [264]	eval-rmse:0.061078	train-rmse:0.058422
# [265]	eval-rmse:0.061079	train-rmse:0.058417
# [266]	eval-rmse:0.061078	train-rmse:0.05841
# [267]	eval-rmse:0.061085	train-rmse:0.058401
# [268]	eval-rmse:0.06109	train-rmse:0.058393
# [269]	eval-rmse:0.061093	train-rmse:0.058385
# [270]	eval-rmse:0.061092	train-rmse:0.058376
# [271]	eval-rmse:0.061093	train-rmse:0.058369
# [272]	eval-rmse:0.061093	train-rmse:0.058365
# [273]	eval-rmse:0.061092	train-rmse:0.058358
# [274]	eval-rmse:0.061091	train-rmse:0.058348
# [275]	eval-rmse:0.06109	train-rmse:0.058345
# [276]	eval-rmse:0.061085	train-rmse:0.058335
# [277]	eval-rmse:0.061084	train-rmse:0.058326
# [278]	eval-rmse:0.061088	train-rmse:0.058316
# [279]	eval-rmse:0.061092	train-rmse:0.058306
# [280]	eval-rmse:0.061092	train-rmse:0.058299
# [281]	eval-rmse:0.06109	train-rmse:0.058294
# [282]	eval-rmse:0.061094	train-rmse:0.058289
# [283]	eval-rmse:0.061088	train-rmse:0.058285
# [284]	eval-rmse:0.061089	train-rmse:0.058279
# [285]	eval-rmse:0.061087	train-rmse:0.058271
# [286]	eval-rmse:0.061091	train-rmse:0.058263
# [287]	eval-rmse:0.06109	train-rmse:0.058257
# [288]	eval-rmse:0.061089	train-rmse:0.058248
# [289]	eval-rmse:0.061091	train-rmse:0.058245
# [290]	eval-rmse:0.061089	train-rmse:0.058237
# [291]	eval-rmse:0.061093	train-rmse:0.058232
# [292]	eval-rmse:0.061092	train-rmse:0.058226
# [293]	eval-rmse:0.061093	train-rmse:0.058222
# [294]	eval-rmse:0.061093	train-rmse:0.058213
# [295]	eval-rmse:0.061092	train-rmse:0.058208
# [296]	eval-rmse:0.061094	train-rmse:0.058204
# [297]	eval-rmse:0.061094	train-rmse:0.058195
# [298]	eval-rmse:0.0611	train-rmse:0.058191
# [299]	eval-rmse:0.061097	train-rmse:0.058183

# %%
param2 = {'max_depth':5, 'eta':0.2, 'subsample':0.8, 'colsample_bytree':0.8, 'alpha':0.01, 'objective':'reg:linear', 'early_stopping_rounds':30}

# specify validations set to watch performance
watchlist = [(dtest, 'eval'), (dtrain, 'train')]
watchlist_17 = [(dtest_17, 'eval'), (dtrain_17, 'train')]
num_round = 300
bst2 = xgb.train(param2, dtrain, num_round, watchlist)
bst2_17 = xgb.train(param2, dtrain_17, num_round, watchlist_17)
# Out:
# [0]	eval-rmse:0.398979	train-rmse:0.399182
# [1]	eval-rmse:0.321167	train-rmse:0.321384
# [2]	eval-rmse:0.25949	train-rmse:0.259707
# [3]	eval-rmse:0.210705	train-rmse:0.210903
# [4]	eval-rmse:0.172322	train-rmse:0.172514
# [5]	eval-rmse:0.142452	train-rmse:0.142637
# [6]	eval-rmse:0.119479	train-rmse:0.119639
# [7]	eval-rmse:0.102088	train-rmse:0.102211
# [8]	eval-rmse:0.089183	train-rmse:0.08927
# [9]	eval-rmse:0.079862	train-rmse:0.079901
# [10]	eval-rmse:0.073224	train-rmse:0.073212
# [11]	eval-rmse:0.068621	train-rmse:0.068567
# [12]	eval-rmse:0.065509	train-rmse:0.06541
# [13]	eval-rmse:0.063457	train-rmse:0.063299
# [14]	eval-rmse:0.062095	train-rmse:0.061889
# [15]	eval-rmse:0.061218	train-rmse:0.060962
# [16]	eval-rmse:0.060638	train-rmse:0.060341
# [17]	eval-rmse:0.06026	train-rmse:0.059922
# [18]	eval-rmse:0.059995	train-rmse:0.059634
# [19]	eval-rmse:0.059826	train-rmse:0.059422
# [20]	eval-rmse:0.059737	train-rmse:0.059298
# [21]	eval-rmse:0.059654	train-rmse:0.05918
# [22]	eval-rmse:0.05961	train-rmse:0.059109
# [23]	eval-rmse:0.059588	train-rmse:0.059037
# [24]	eval-rmse:0.059563	train-rmse:0.058977
# [25]	eval-rmse:0.059547	train-rmse:0.058925
# [26]	eval-rmse:0.059543	train-rmse:0.058888
# [27]	eval-rmse:0.059524	train-rmse:0.058854
# [28]	eval-rmse:0.059533	train-rmse:0.058809
# [29]	eval-rmse:0.059517	train-rmse:0.058762
# [30]	eval-rmse:0.0595	train-rmse:0.058722
# [31]	eval-rmse:0.059498	train-rmse:0.058692
# [32]	eval-rmse:0.059497	train-rmse:0.058663
# [33]	eval-rmse:0.059494	train-rmse:0.058619
# [34]	eval-rmse:0.059497	train-rmse:0.058584
# [35]	eval-rmse:0.059518	train-rmse:0.058553
# [36]	eval-rmse:0.05952	train-rmse:0.058506
# [37]	eval-rmse:0.059518	train-rmse:0.058468
# [38]	eval-rmse:0.059519	train-rmse:0.058453
# [39]	eval-rmse:0.059515	train-rmse:0.058412
# [40]	eval-rmse:0.059513	train-rmse:0.058384
# [41]	eval-rmse:0.059511	train-rmse:0.05835
# [42]	eval-rmse:0.059505	train-rmse:0.058318
# [43]	eval-rmse:0.059506	train-rmse:0.05828
# [44]	eval-rmse:0.059494	train-rmse:0.058248
# [45]	eval-rmse:0.059494	train-rmse:0.058216
# [46]	eval-rmse:0.059488	train-rmse:0.058189
# [47]	eval-rmse:0.059491	train-rmse:0.058155
# [48]	eval-rmse:0.059503	train-rmse:0.058121
# [49]	eval-rmse:0.059502	train-rmse:0.058108
# [50]	eval-rmse:0.059504	train-rmse:0.058081
# [51]	eval-rmse:0.059506	train-rmse:0.058037
# [52]	eval-rmse:0.059504	train-rmse:0.058005
# [53]	eval-rmse:0.05949	train-rmse:0.057969
# [54]	eval-rmse:0.059484	train-rmse:0.057946
# [55]	eval-rmse:0.05949	train-rmse:0.057919
# [56]	eval-rmse:0.059483	train-rmse:0.057875
# [57]	eval-rmse:0.059492	train-rmse:0.057853
# [58]	eval-rmse:0.059497	train-rmse:0.057829
# [59]	eval-rmse:0.059491	train-rmse:0.057792
# [60]	eval-rmse:0.059487	train-rmse:0.057764
# [61]	eval-rmse:0.05949	train-rmse:0.057737
# [62]	eval-rmse:0.059479	train-rmse:0.057706
# [63]	eval-rmse:0.059476	train-rmse:0.057677
# [64]	eval-rmse:0.059472	train-rmse:0.057647
# [65]	eval-rmse:0.059482	train-rmse:0.057618
# [66]	eval-rmse:0.059486	train-rmse:0.057588
# [67]	eval-rmse:0.059479	train-rmse:0.057568
# [68]	eval-rmse:0.059483	train-rmse:0.057537
# [69]	eval-rmse:0.059481	train-rmse:0.057513
# [70]	eval-rmse:0.059488	train-rmse:0.057478
# [71]	eval-rmse:0.059491	train-rmse:0.057458
# [72]	eval-rmse:0.059489	train-rmse:0.057444
# [73]	eval-rmse:0.059484	train-rmse:0.057413
# [74]	eval-rmse:0.059486	train-rmse:0.057389
# [75]	eval-rmse:0.059481	train-rmse:0.057352
# [76]	eval-rmse:0.059481	train-rmse:0.057332
# [77]	eval-rmse:0.059485	train-rmse:0.0573
# [78]	eval-rmse:0.059481	train-rmse:0.057275
# [79]	eval-rmse:0.059471	train-rmse:0.057242
# [80]	eval-rmse:0.059463	train-rmse:0.057218
# [81]	eval-rmse:0.059465	train-rmse:0.057197
# [82]	eval-rmse:0.059469	train-rmse:0.057182
# [83]	eval-rmse:0.059467	train-rmse:0.057143
# [84]	eval-rmse:0.059471	train-rmse:0.05712
# [85]	eval-rmse:0.059469	train-rmse:0.057091
# [86]	eval-rmse:0.059479	train-rmse:0.057075
# [87]	eval-rmse:0.05948	train-rmse:0.057056
# [88]	eval-rmse:0.059482	train-rmse:0.057017
# [89]	eval-rmse:0.059481	train-rmse:0.057003
# [90]	eval-rmse:0.059486	train-rmse:0.056977
# [91]	eval-rmse:0.059487	train-rmse:0.05695
# [92]	eval-rmse:0.059485	train-rmse:0.056927
# [93]	eval-rmse:0.059478	train-rmse:0.056896
# [94]	eval-rmse:0.059473	train-rmse:0.056873
# [95]	eval-rmse:0.059464	train-rmse:0.056836
# [96]	eval-rmse:0.05946	train-rmse:0.056821
# [97]	eval-rmse:0.059458	train-rmse:0.056792
# [98]	eval-rmse:0.059464	train-rmse:0.056769
# [99]	eval-rmse:0.059469	train-rmse:0.056749
# [100]	eval-rmse:0.059459	train-rmse:0.056713
# [101]	eval-rmse:0.059464	train-rmse:0.056683
# [102]	eval-rmse:0.059468	train-rmse:0.056667
# [103]	eval-rmse:0.059459	train-rmse:0.056649
# [104]	eval-rmse:0.059456	train-rmse:0.056622
# [105]	eval-rmse:0.059467	train-rmse:0.056579
# [106]	eval-rmse:0.059471	train-rmse:0.056554
# [107]	eval-rmse:0.059465	train-rmse:0.056522
# [108]	eval-rmse:0.059467	train-rmse:0.056513
# [109]	eval-rmse:0.059473	train-rmse:0.056489
# [110]	eval-rmse:0.059479	train-rmse:0.056461
# [111]	eval-rmse:0.059483	train-rmse:0.056438
# [112]	eval-rmse:0.05949	train-rmse:0.056411
# [113]	eval-rmse:0.059491	train-rmse:0.056385
# [114]	eval-rmse:0.059483	train-rmse:0.056356
# [115]	eval-rmse:0.059473	train-rmse:0.056316
# [116]	eval-rmse:0.059471	train-rmse:0.056279
# [117]	eval-rmse:0.059476	train-rmse:0.056265
# [118]	eval-rmse:0.059473	train-rmse:0.056256
# [119]	eval-rmse:0.059482	train-rmse:0.056223
# [120]	eval-rmse:0.059484	train-rmse:0.056196
# [121]	eval-rmse:0.059491	train-rmse:0.056165
# [122]	eval-rmse:0.059497	train-rmse:0.056133
# [123]	eval-rmse:0.059499	train-rmse:0.05611
# [124]	eval-rmse:0.059502	train-rmse:0.056079
# [125]	eval-rmse:0.059503	train-rmse:0.056059
# [126]	eval-rmse:0.059503	train-rmse:0.05603
# [127]	eval-rmse:0.059512	train-rmse:0.056006
# [128]	eval-rmse:0.059523	train-rmse:0.055977
# [129]	eval-rmse:0.059505	train-rmse:0.055939
# [130]	eval-rmse:0.059514	train-rmse:0.055907
# [131]	eval-rmse:0.059537	train-rmse:0.055884
# [132]	eval-rmse:0.059535	train-rmse:0.055854
# [133]	eval-rmse:0.059544	train-rmse:0.055831
# [134]	eval-rmse:0.059548	train-rmse:0.055811
# [135]	eval-rmse:0.059548	train-rmse:0.0558
# [136]	eval-rmse:0.059554	train-rmse:0.055776
# [137]	eval-rmse:0.059561	train-rmse:0.055762
# [138]	eval-rmse:0.059562	train-rmse:0.055749
# [139]	eval-rmse:0.05957	train-rmse:0.055734
# [140]	eval-rmse:0.05957	train-rmse:0.055712
# [141]	eval-rmse:0.059563	train-rmse:0.055688
# [142]	eval-rmse:0.059565	train-rmse:0.055666
# [143]	eval-rmse:0.059569	train-rmse:0.055643
# [144]	eval-rmse:0.059573	train-rmse:0.055625
# [145]	eval-rmse:0.059576	train-rmse:0.055596
# [146]	eval-rmse:0.059582	train-rmse:0.055583
# [147]	eval-rmse:0.059593	train-rmse:0.055557
# [148]	eval-rmse:0.059595	train-rmse:0.055539
# [149]	eval-rmse:0.059601	train-rmse:0.055521
# [150]	eval-rmse:0.059604	train-rmse:0.05549
# [151]	eval-rmse:0.059607	train-rmse:0.055478
# [152]	eval-rmse:0.059605	train-rmse:0.055454
# [153]	eval-rmse:0.05961	train-rmse:0.05543
# [154]	eval-rmse:0.059605	train-rmse:0.055401
# [155]	eval-rmse:0.059609	train-rmse:0.055384
# [156]	eval-rmse:0.059614	train-rmse:0.05537
# [157]	eval-rmse:0.05961	train-rmse:0.05535
# [158]	eval-rmse:0.059613	train-rmse:0.055333
# [159]	eval-rmse:0.059611	train-rmse:0.055308
# [160]	eval-rmse:0.059607	train-rmse:0.055291
# [161]	eval-rmse:0.059613	train-rmse:0.055278
# [162]	eval-rmse:0.059618	train-rmse:0.055252
# [163]	eval-rmse:0.059614	train-rmse:0.055226
# [164]	eval-rmse:0.059628	train-rmse:0.055197
# [165]	eval-rmse:0.059624	train-rmse:0.055177
# [166]	eval-rmse:0.059623	train-rmse:0.055165
# [167]	eval-rmse:0.059634	train-rmse:0.05514
# [168]	eval-rmse:0.059629	train-rmse:0.055112
# [169]	eval-rmse:0.059632	train-rmse:0.055097
# [170]	eval-rmse:0.059631	train-rmse:0.055075
# [171]	eval-rmse:0.059633	train-rmse:0.055054
# [172]	eval-rmse:0.059628	train-rmse:0.055034
# [173]	eval-rmse:0.059629	train-rmse:0.055014
# [174]	eval-rmse:0.059628	train-rmse:0.054997
# [175]	eval-rmse:0.059621	train-rmse:0.054982
# [176]	eval-rmse:0.059623	train-rmse:0.054958
# [177]	eval-rmse:0.059632	train-rmse:0.054937
# [178]	eval-rmse:0.059629	train-rmse:0.054906
# [179]	eval-rmse:0.059622	train-rmse:0.054883
# [180]	eval-rmse:0.059617	train-rmse:0.054864
# [181]	eval-rmse:0.059616	train-rmse:0.054844
# [182]	eval-rmse:0.059616	train-rmse:0.054825
# [183]	eval-rmse:0.059617	train-rmse:0.054807
# [184]	eval-rmse:0.059614	train-rmse:0.05479
# [185]	eval-rmse:0.059617	train-rmse:0.054772
# [186]	eval-rmse:0.059618	train-rmse:0.054753
# [187]	eval-rmse:0.059629	train-rmse:0.054731
# [188]	eval-rmse:0.059626	train-rmse:0.054701
# [189]	eval-rmse:0.059627	train-rmse:0.054685
# [190]	eval-rmse:0.059632	train-rmse:0.05467
# [191]	eval-rmse:0.059628	train-rmse:0.05465
# [192]	eval-rmse:0.059635	train-rmse:0.054633
# [193]	eval-rmse:0.05964	train-rmse:0.054609
# [194]	eval-rmse:0.059636	train-rmse:0.054588
# [195]	eval-rmse:0.059634	train-rmse:0.054569
# [196]	eval-rmse:0.05964	train-rmse:0.054548
# [197]	eval-rmse:0.05964	train-rmse:0.05453
# [198]	eval-rmse:0.059631	train-rmse:0.054507
# [199]	eval-rmse:0.05963	train-rmse:0.054496
# [200]	eval-rmse:0.05963	train-rmse:0.054477
# [201]	eval-rmse:0.059628	train-rmse:0.054462
# [202]	eval-rmse:0.059625	train-rmse:0.054445
# [203]	eval-rmse:0.059621	train-rmse:0.054428
# [204]	eval-rmse:0.059621	train-rmse:0.054405
# [205]	eval-rmse:0.059626	train-rmse:0.05439
# [206]	eval-rmse:0.059627	train-rmse:0.05437
# [207]	eval-rmse:0.059633	train-rmse:0.054351
# [208]	eval-rmse:0.059639	train-rmse:0.054326
# [209]	eval-rmse:0.059644	train-rmse:0.054304
# [210]	eval-rmse:0.059654	train-rmse:0.054283
# [211]	eval-rmse:0.059654	train-rmse:0.054274
# [212]	eval-rmse:0.059652	train-rmse:0.054258
# [213]	eval-rmse:0.059651	train-rmse:0.054237
# [214]	eval-rmse:0.059659	train-rmse:0.054222
# [215]	eval-rmse:0.059675	train-rmse:0.054192
# [216]	eval-rmse:0.059669	train-rmse:0.054171
# [217]	eval-rmse:0.05967	train-rmse:0.054148
# [218]	eval-rmse:0.059676	train-rmse:0.054129
# [219]	eval-rmse:0.059684	train-rmse:0.054107
# [220]	eval-rmse:0.059693	train-rmse:0.054087
# [221]	eval-rmse:0.059688	train-rmse:0.054061
# [222]	eval-rmse:0.059688	train-rmse:0.054038
# [223]	eval-rmse:0.059694	train-rmse:0.054024
# [224]	eval-rmse:0.059699	train-rmse:0.054003
# [225]	eval-rmse:0.059702	train-rmse:0.053987
# [226]	eval-rmse:0.059702	train-rmse:0.053965
# [227]	eval-rmse:0.059709	train-rmse:0.053951
# [228]	eval-rmse:0.059713	train-rmse:0.053937
# [229]	eval-rmse:0.059715	train-rmse:0.053925
# [230]	eval-rmse:0.059722	train-rmse:0.053907
# [231]	eval-rmse:0.059725	train-rmse:0.053883
# [232]	eval-rmse:0.059734	train-rmse:0.053858
# [233]	eval-rmse:0.059735	train-rmse:0.053847
# [234]	eval-rmse:0.059735	train-rmse:0.053827
# [235]	eval-rmse:0.059735	train-rmse:0.053819
# [236]	eval-rmse:0.05974	train-rmse:0.053806
# [237]	eval-rmse:0.059742	train-rmse:0.053788
# [238]	eval-rmse:0.05974	train-rmse:0.053773
# [239]	eval-rmse:0.059752	train-rmse:0.053751
# [240]	eval-rmse:0.059759	train-rmse:0.053728
# [241]	eval-rmse:0.059754	train-rmse:0.053713
# [242]	eval-rmse:0.059759	train-rmse:0.053691
# [243]	eval-rmse:0.059757	train-rmse:0.053679
# [244]	eval-rmse:0.059769	train-rmse:0.053659
# [245]	eval-rmse:0.059768	train-rmse:0.053644
# [246]	eval-rmse:0.05977	train-rmse:0.053636
# [247]	eval-rmse:0.059772	train-rmse:0.053611
# [248]	eval-rmse:0.059764	train-rmse:0.05359
# [249]	eval-rmse:0.059769	train-rmse:0.053572
# [250]	eval-rmse:0.059761	train-rmse:0.053551
# [251]	eval-rmse:0.059767	train-rmse:0.053542
# [252]	eval-rmse:0.059777	train-rmse:0.05352
# [253]	eval-rmse:0.059777	train-rmse:0.053502
# [254]	eval-rmse:0.059776	train-rmse:0.053478
# [255]	eval-rmse:0.059783	train-rmse:0.053453
# [256]	eval-rmse:0.059774	train-rmse:0.053434
# [257]	eval-rmse:0.059771	train-rmse:0.053411
# [258]	eval-rmse:0.059768	train-rmse:0.053391
# [259]	eval-rmse:0.059777	train-rmse:0.053375
# [260]	eval-rmse:0.059787	train-rmse:0.053355
# [261]	eval-rmse:0.059791	train-rmse:0.053327
# [262]	eval-rmse:0.059799	train-rmse:0.053306
# [263]	eval-rmse:0.059793	train-rmse:0.053284
# [264]	eval-rmse:0.059793	train-rmse:0.053255
# [265]	eval-rmse:0.059797	train-rmse:0.053232
# [266]	eval-rmse:0.059789	train-rmse:0.053221
# [267]	eval-rmse:0.059793	train-rmse:0.053199
# [268]	eval-rmse:0.059794	train-rmse:0.05318
# [269]	eval-rmse:0.059793	train-rmse:0.05316
# [270]	eval-rmse:0.059794	train-rmse:0.053141
# [271]	eval-rmse:0.059803	train-rmse:0.053123
# [272]	eval-rmse:0.059798	train-rmse:0.05311
# [273]	eval-rmse:0.059804	train-rmse:0.053084
# [274]	eval-rmse:0.059808	train-rmse:0.05307
# [275]	eval-rmse:0.05981	train-rmse:0.053057
# [276]	eval-rmse:0.059806	train-rmse:0.053024
# [277]	eval-rmse:0.05981	train-rmse:0.053016
# [278]	eval-rmse:0.059804	train-rmse:0.052996
# [279]	eval-rmse:0.059809	train-rmse:0.052983
# [280]	eval-rmse:0.059811	train-rmse:0.052965
# [281]	eval-rmse:0.059816	train-rmse:0.052946
# [282]	eval-rmse:0.059829	train-rmse:0.052927
# [283]	eval-rmse:0.059834	train-rmse:0.052904
# [284]	eval-rmse:0.059838	train-rmse:0.052892
# [285]	eval-rmse:0.059834	train-rmse:0.052876
# [286]	eval-rmse:0.059833	train-rmse:0.052854
# [287]	eval-rmse:0.059845	train-rmse:0.052835
# [288]	eval-rmse:0.059845	train-rmse:0.052819
# [289]	eval-rmse:0.059852	train-rmse:0.052806
# [290]	eval-rmse:0.05985	train-rmse:0.052786
# [291]	eval-rmse:0.059859	train-rmse:0.052763
# [292]	eval-rmse:0.059863	train-rmse:0.052739
# [293]	eval-rmse:0.059865	train-rmse:0.052725
# [294]	eval-rmse:0.059864	train-rmse:0.052701
# [295]	eval-rmse:0.059862	train-rmse:0.052682
# [296]	eval-rmse:0.059872	train-rmse:0.052664
# [297]	eval-rmse:0.05987	train-rmse:0.052643
# [298]	eval-rmse:0.059883	train-rmse:0.052619
# [299]	eval-rmse:0.059886	train-rmse:0.052595
# [0]	eval-rmse:0.397998	train-rmse:0.397957
# [1]	eval-rmse:0.320577	train-rmse:0.32052
# [2]	eval-rmse:0.259149	train-rmse:0.259076
# [3]	eval-rmse:0.210573	train-rmse:0.210485
# [4]	eval-rmse:0.172496	train-rmse:0.17236
# [5]	eval-rmse:0.142883	train-rmse:0.142709
# [6]	eval-rmse:0.120093	train-rmse:0.119877
# [7]	eval-rmse:0.102919	train-rmse:0.102629
# [8]	eval-rmse:0.090212	train-rmse:0.08987
# [9]	eval-rmse:0.081044	train-rmse:0.080634
# [10]	eval-rmse:0.074547	train-rmse:0.074075
# [11]	eval-rmse:0.070076	train-rmse:0.069549
# [12]	eval-rmse:0.06707	train-rmse:0.066476
# [13]	eval-rmse:0.065029	train-rmse:0.06438
# [14]	eval-rmse:0.063677	train-rmse:0.06299
# [15]	eval-rmse:0.062818	train-rmse:0.062075
# [16]	eval-rmse:0.062235	train-rmse:0.061467
# [17]	eval-rmse:0.061881	train-rmse:0.061051
# [18]	eval-rmse:0.061635	train-rmse:0.060768
# [19]	eval-rmse:0.061481	train-rmse:0.060556
# [20]	eval-rmse:0.061388	train-rmse:0.060401
# [21]	eval-rmse:0.061324	train-rmse:0.060279
# [22]	eval-rmse:0.061268	train-rmse:0.060193
# [23]	eval-rmse:0.06124	train-rmse:0.060123
# [24]	eval-rmse:0.06123	train-rmse:0.060054
# [25]	eval-rmse:0.061211	train-rmse:0.060009
# [26]	eval-rmse:0.061199	train-rmse:0.059941
# [27]	eval-rmse:0.061191	train-rmse:0.059922
# [28]	eval-rmse:0.061187	train-rmse:0.059879
# [29]	eval-rmse:0.061184	train-rmse:0.059834
# [30]	eval-rmse:0.06118	train-rmse:0.059799
# [31]	eval-rmse:0.061173	train-rmse:0.059765
# [32]	eval-rmse:0.061179	train-rmse:0.059725
# [33]	eval-rmse:0.061182	train-rmse:0.059693
# [34]	eval-rmse:0.061173	train-rmse:0.059657
# [35]	eval-rmse:0.061169	train-rmse:0.059612
# [36]	eval-rmse:0.061162	train-rmse:0.059573
# [37]	eval-rmse:0.061162	train-rmse:0.059542
# [38]	eval-rmse:0.061159	train-rmse:0.059524
# [39]	eval-rmse:0.061148	train-rmse:0.059474
# [40]	eval-rmse:0.061154	train-rmse:0.059443
# [41]	eval-rmse:0.061154	train-rmse:0.05941
# [42]	eval-rmse:0.061143	train-rmse:0.059374
# [43]	eval-rmse:0.061149	train-rmse:0.059337
# [44]	eval-rmse:0.061151	train-rmse:0.059299
# [45]	eval-rmse:0.061162	train-rmse:0.059251
# [46]	eval-rmse:0.061166	train-rmse:0.059213
# [47]	eval-rmse:0.061166	train-rmse:0.059172
# [48]	eval-rmse:0.061175	train-rmse:0.059126
# [49]	eval-rmse:0.061181	train-rmse:0.059102
# [50]	eval-rmse:0.061175	train-rmse:0.059084
# [51]	eval-rmse:0.061179	train-rmse:0.059055
# [52]	eval-rmse:0.06118	train-rmse:0.05903
# [53]	eval-rmse:0.061176	train-rmse:0.058993
# [54]	eval-rmse:0.061178	train-rmse:0.058955
# [55]	eval-rmse:0.061178	train-rmse:0.058913
# [56]	eval-rmse:0.061185	train-rmse:0.058888
# [57]	eval-rmse:0.061193	train-rmse:0.05885
# [58]	eval-rmse:0.061199	train-rmse:0.058819
# [59]	eval-rmse:0.061201	train-rmse:0.058784
# [60]	eval-rmse:0.061194	train-rmse:0.058753
# [61]	eval-rmse:0.061197	train-rmse:0.058726
# [62]	eval-rmse:0.0612	train-rmse:0.058709
# [63]	eval-rmse:0.061197	train-rmse:0.058676
# [64]	eval-rmse:0.061193	train-rmse:0.05863
# [65]	eval-rmse:0.061199	train-rmse:0.05861
# [66]	eval-rmse:0.061208	train-rmse:0.058581
# [67]	eval-rmse:0.061219	train-rmse:0.05856
# [68]	eval-rmse:0.061233	train-rmse:0.058535
# [69]	eval-rmse:0.06123	train-rmse:0.058519
# [70]	eval-rmse:0.061224	train-rmse:0.058488
# [71]	eval-rmse:0.061219	train-rmse:0.05845
# [72]	eval-rmse:0.061218	train-rmse:0.058417
# [73]	eval-rmse:0.061235	train-rmse:0.058394
# [74]	eval-rmse:0.061229	train-rmse:0.058369
# [75]	eval-rmse:0.061248	train-rmse:0.058331
# [76]	eval-rmse:0.061243	train-rmse:0.058312
# [77]	eval-rmse:0.061249	train-rmse:0.058282
# [78]	eval-rmse:0.061248	train-rmse:0.058249
# [79]	eval-rmse:0.061242	train-rmse:0.05823
# [80]	eval-rmse:0.061239	train-rmse:0.058194
# [81]	eval-rmse:0.061238	train-rmse:0.058178
# [82]	eval-rmse:0.061242	train-rmse:0.058155
# [83]	eval-rmse:0.061241	train-rmse:0.058135
# [84]	eval-rmse:0.061254	train-rmse:0.058114
# [85]	eval-rmse:0.061248	train-rmse:0.05808
# [86]	eval-rmse:0.061241	train-rmse:0.058035
# [87]	eval-rmse:0.061238	train-rmse:0.05802
# [88]	eval-rmse:0.061235	train-rmse:0.057972
# [89]	eval-rmse:0.061243	train-rmse:0.057938
# [90]	eval-rmse:0.061251	train-rmse:0.05791
# [91]	eval-rmse:0.061252	train-rmse:0.057888
# [92]	eval-rmse:0.061256	train-rmse:0.057854
# [93]	eval-rmse:0.06127	train-rmse:0.057817
# [94]	eval-rmse:0.061269	train-rmse:0.057785
# [95]	eval-rmse:0.061266	train-rmse:0.057757
# [96]	eval-rmse:0.061268	train-rmse:0.057735
# [97]	eval-rmse:0.061273	train-rmse:0.057702
# [98]	eval-rmse:0.061265	train-rmse:0.057673
# [99]	eval-rmse:0.061253	train-rmse:0.057646
# [100]	eval-rmse:0.061258	train-rmse:0.057615
# [101]	eval-rmse:0.06126	train-rmse:0.05759
# [102]	eval-rmse:0.061263	train-rmse:0.057551
# [103]	eval-rmse:0.061256	train-rmse:0.057518
# [104]	eval-rmse:0.061255	train-rmse:0.057486
# [105]	eval-rmse:0.061259	train-rmse:0.057461
# [106]	eval-rmse:0.061255	train-rmse:0.057429
# [107]	eval-rmse:0.061249	train-rmse:0.057406
# [108]	eval-rmse:0.061255	train-rmse:0.057393
# [109]	eval-rmse:0.061253	train-rmse:0.057371
# [110]	eval-rmse:0.061258	train-rmse:0.057351
# [111]	eval-rmse:0.061242	train-rmse:0.05732
# [112]	eval-rmse:0.061255	train-rmse:0.057296
# [113]	eval-rmse:0.061257	train-rmse:0.057281
# [114]	eval-rmse:0.061269	train-rmse:0.057257
# [115]	eval-rmse:0.061266	train-rmse:0.057227
# [116]	eval-rmse:0.061258	train-rmse:0.057204
# [117]	eval-rmse:0.061261	train-rmse:0.057179
# [118]	eval-rmse:0.061259	train-rmse:0.057142
# [119]	eval-rmse:0.061262	train-rmse:0.057113
# [120]	eval-rmse:0.061263	train-rmse:0.057099
# [121]	eval-rmse:0.061266	train-rmse:0.057076
# [122]	eval-rmse:0.061273	train-rmse:0.057053
# [123]	eval-rmse:0.061293	train-rmse:0.057028
# [124]	eval-rmse:0.061289	train-rmse:0.056995
# [125]	eval-rmse:0.061298	train-rmse:0.056962
# [126]	eval-rmse:0.061297	train-rmse:0.056949
# [127]	eval-rmse:0.061303	train-rmse:0.056921
# [128]	eval-rmse:0.061301	train-rmse:0.056889
# [129]	eval-rmse:0.061303	train-rmse:0.056858
# [130]	eval-rmse:0.061312	train-rmse:0.05682
# [131]	eval-rmse:0.061308	train-rmse:0.056805
# [132]	eval-rmse:0.061313	train-rmse:0.056781
# [133]	eval-rmse:0.061318	train-rmse:0.056751
# [134]	eval-rmse:0.061316	train-rmse:0.056728
# [135]	eval-rmse:0.061311	train-rmse:0.056704
# [136]	eval-rmse:0.061314	train-rmse:0.056682
# [137]	eval-rmse:0.061314	train-rmse:0.056672
# [138]	eval-rmse:0.061321	train-rmse:0.056648
# [139]	eval-rmse:0.061319	train-rmse:0.056629
# [140]	eval-rmse:0.061325	train-rmse:0.056604
# [141]	eval-rmse:0.061334	train-rmse:0.056572
# [142]	eval-rmse:0.061327	train-rmse:0.056552
# [143]	eval-rmse:0.061338	train-rmse:0.056529
# [144]	eval-rmse:0.061334	train-rmse:0.056512
# [145]	eval-rmse:0.061324	train-rmse:0.056486
# [146]	eval-rmse:0.061324	train-rmse:0.056462
# [147]	eval-rmse:0.061326	train-rmse:0.056433
# [148]	eval-rmse:0.061325	train-rmse:0.056419
# [149]	eval-rmse:0.061331	train-rmse:0.056386
# [150]	eval-rmse:0.061329	train-rmse:0.056356
# [151]	eval-rmse:0.06133	train-rmse:0.05632
# [152]	eval-rmse:0.061317	train-rmse:0.056291
# [153]	eval-rmse:0.061316	train-rmse:0.056264
# [154]	eval-rmse:0.061322	train-rmse:0.056251
# [155]	eval-rmse:0.061321	train-rmse:0.056236
# [156]	eval-rmse:0.061319	train-rmse:0.056212
# [157]	eval-rmse:0.061321	train-rmse:0.056189
# [158]	eval-rmse:0.061322	train-rmse:0.05618
# [159]	eval-rmse:0.061331	train-rmse:0.056156
# [160]	eval-rmse:0.061322	train-rmse:0.056124
# [161]	eval-rmse:0.061321	train-rmse:0.05609
# [162]	eval-rmse:0.061327	train-rmse:0.056067
# [163]	eval-rmse:0.061344	train-rmse:0.056034
# [164]	eval-rmse:0.061351	train-rmse:0.056014
# [165]	eval-rmse:0.061358	train-rmse:0.056
# [166]	eval-rmse:0.061365	train-rmse:0.055976
# [167]	eval-rmse:0.06137	train-rmse:0.055947
# [168]	eval-rmse:0.061379	train-rmse:0.055931
# [169]	eval-rmse:0.061384	train-rmse:0.0559
# [170]	eval-rmse:0.061385	train-rmse:0.055875
# [171]	eval-rmse:0.06139	train-rmse:0.055855
# [172]	eval-rmse:0.061395	train-rmse:0.05583
# [173]	eval-rmse:0.061397	train-rmse:0.055798
# [174]	eval-rmse:0.061398	train-rmse:0.055772
# [175]	eval-rmse:0.061395	train-rmse:0.055762
# [176]	eval-rmse:0.061399	train-rmse:0.05574
# [177]	eval-rmse:0.061386	train-rmse:0.055722
# [178]	eval-rmse:0.061379	train-rmse:0.055705
# [179]	eval-rmse:0.061389	train-rmse:0.055684
# [180]	eval-rmse:0.0614	train-rmse:0.055662
# [181]	eval-rmse:0.061403	train-rmse:0.055637
# [182]	eval-rmse:0.0614	train-rmse:0.055619
# [183]	eval-rmse:0.061401	train-rmse:0.055592
# [184]	eval-rmse:0.061404	train-rmse:0.055579
# [185]	eval-rmse:0.061414	train-rmse:0.055553
# [186]	eval-rmse:0.061415	train-rmse:0.055532
# [187]	eval-rmse:0.061412	train-rmse:0.055505
# [188]	eval-rmse:0.061415	train-rmse:0.055484
# [189]	eval-rmse:0.061417	train-rmse:0.055468
# [190]	eval-rmse:0.061428	train-rmse:0.05544
# [191]	eval-rmse:0.061434	train-rmse:0.055404
# [192]	eval-rmse:0.061436	train-rmse:0.055395
# [193]	eval-rmse:0.061435	train-rmse:0.055378
# [194]	eval-rmse:0.061426	train-rmse:0.055357
# [195]	eval-rmse:0.061437	train-rmse:0.055331
# [196]	eval-rmse:0.061444	train-rmse:0.055311
# [197]	eval-rmse:0.061445	train-rmse:0.0553
# [198]	eval-rmse:0.061454	train-rmse:0.055283
# [199]	eval-rmse:0.061451	train-rmse:0.055273
# [200]	eval-rmse:0.061442	train-rmse:0.055255
# [201]	eval-rmse:0.061441	train-rmse:0.055227
# [202]	eval-rmse:0.061446	train-rmse:0.055195
# [203]	eval-rmse:0.061451	train-rmse:0.055185
# [204]	eval-rmse:0.061449	train-rmse:0.055154
# [205]	eval-rmse:0.061455	train-rmse:0.055135
# [206]	eval-rmse:0.061464	train-rmse:0.055105
# [207]	eval-rmse:0.061463	train-rmse:0.055084
# [208]	eval-rmse:0.061464	train-rmse:0.05506
# [209]	eval-rmse:0.061468	train-rmse:0.055051
# [210]	eval-rmse:0.061472	train-rmse:0.055034
# [211]	eval-rmse:0.061479	train-rmse:0.055011
# [212]	eval-rmse:0.06148	train-rmse:0.054995
# [213]	eval-rmse:0.061479	train-rmse:0.054983
# [214]	eval-rmse:0.061487	train-rmse:0.054967
# [215]	eval-rmse:0.061493	train-rmse:0.054944
# [216]	eval-rmse:0.061496	train-rmse:0.054924
# [217]	eval-rmse:0.061505	train-rmse:0.054905
# [218]	eval-rmse:0.061502	train-rmse:0.054884
# [219]	eval-rmse:0.061508	train-rmse:0.054855
# [220]	eval-rmse:0.061509	train-rmse:0.054832
# [221]	eval-rmse:0.061516	train-rmse:0.054806
# [222]	eval-rmse:0.061524	train-rmse:0.054788
# [223]	eval-rmse:0.06152	train-rmse:0.054776
# [224]	eval-rmse:0.061525	train-rmse:0.054759
# [225]	eval-rmse:0.061529	train-rmse:0.05474
# [226]	eval-rmse:0.061541	train-rmse:0.054714
# [227]	eval-rmse:0.061554	train-rmse:0.054695
# [228]	eval-rmse:0.061567	train-rmse:0.05467
# [229]	eval-rmse:0.061579	train-rmse:0.054656
# [230]	eval-rmse:0.061584	train-rmse:0.054633
# [231]	eval-rmse:0.061585	train-rmse:0.054611
# [232]	eval-rmse:0.061595	train-rmse:0.054589
# [233]	eval-rmse:0.061601	train-rmse:0.054577
# [234]	eval-rmse:0.061609	train-rmse:0.054562
# [235]	eval-rmse:0.061624	train-rmse:0.054538
# [236]	eval-rmse:0.061629	train-rmse:0.054517
# [237]	eval-rmse:0.061629	train-rmse:0.054492
# [238]	eval-rmse:0.061621	train-rmse:0.054472
# [239]	eval-rmse:0.061628	train-rmse:0.054461
# [240]	eval-rmse:0.061635	train-rmse:0.054444
# [241]	eval-rmse:0.061628	train-rmse:0.05442
# [242]	eval-rmse:0.061635	train-rmse:0.054396
# [243]	eval-rmse:0.06164	train-rmse:0.054386
# [244]	eval-rmse:0.06165	train-rmse:0.054377
# [245]	eval-rmse:0.061667	train-rmse:0.054358
# [246]	eval-rmse:0.061669	train-rmse:0.054329
# [247]	eval-rmse:0.061673	train-rmse:0.054322
# [248]	eval-rmse:0.061672	train-rmse:0.054294
# [249]	eval-rmse:0.06167	train-rmse:0.054269
# [250]	eval-rmse:0.061681	train-rmse:0.054257
# [251]	eval-rmse:0.061681	train-rmse:0.054238
# [252]	eval-rmse:0.061683	train-rmse:0.054217
# [253]	eval-rmse:0.061681	train-rmse:0.054192
# [254]	eval-rmse:0.061684	train-rmse:0.054164
# [255]	eval-rmse:0.061688	train-rmse:0.054141
# [256]	eval-rmse:0.061686	train-rmse:0.054121
# [257]	eval-rmse:0.061688	train-rmse:0.054105
# [258]	eval-rmse:0.061691	train-rmse:0.054092
# [259]	eval-rmse:0.061691	train-rmse:0.054073
# [260]	eval-rmse:0.061695	train-rmse:0.05406
# [261]	eval-rmse:0.0617	train-rmse:0.054034
# [262]	eval-rmse:0.061701	train-rmse:0.054004
# [263]	eval-rmse:0.061707	train-rmse:0.053979
# [264]	eval-rmse:0.061705	train-rmse:0.053955
# [265]	eval-rmse:0.061697	train-rmse:0.053924
# [266]	eval-rmse:0.061704	train-rmse:0.053909
# [267]	eval-rmse:0.061702	train-rmse:0.05389
# [268]	eval-rmse:0.061706	train-rmse:0.053869
# [269]	eval-rmse:0.06171	train-rmse:0.053853
# [270]	eval-rmse:0.061709	train-rmse:0.053831
# [271]	eval-rmse:0.061708	train-rmse:0.053807
# [272]	eval-rmse:0.061706	train-rmse:0.053797
# [273]	eval-rmse:0.06171	train-rmse:0.053776
# [274]	eval-rmse:0.06171	train-rmse:0.053746
# [275]	eval-rmse:0.061711	train-rmse:0.053739
# [276]	eval-rmse:0.061707	train-rmse:0.053712
# [277]	eval-rmse:0.061706	train-rmse:0.053686
# [278]	eval-rmse:0.061698	train-rmse:0.053665
# [279]	eval-rmse:0.061706	train-rmse:0.053642
# [280]	eval-rmse:0.061713	train-rmse:0.05363
# [281]	eval-rmse:0.061719	train-rmse:0.053605
# [282]	eval-rmse:0.061727	train-rmse:0.053586
# [283]	eval-rmse:0.061724	train-rmse:0.053574
# [284]	eval-rmse:0.061721	train-rmse:0.053556
# [285]	eval-rmse:0.061724	train-rmse:0.053541
# [286]	eval-rmse:0.061727	train-rmse:0.053521
# [287]	eval-rmse:0.061735	train-rmse:0.053494
# [288]	eval-rmse:0.061734	train-rmse:0.053471
# [289]	eval-rmse:0.06174	train-rmse:0.053461
# [290]	eval-rmse:0.061739	train-rmse:0.053438
# [291]	eval-rmse:0.061744	train-rmse:0.053432
# [292]	eval-rmse:0.06174	train-rmse:0.053413
# [293]	eval-rmse:0.061742	train-rmse:0.053387
# [294]	eval-rmse:0.061752	train-rmse:0.053368
# [295]	eval-rmse:0.061749	train-rmse:0.053346
# [296]	eval-rmse:0.06175	train-rmse:0.053315
# [297]	eval-rmse:0.06175	train-rmse:0.0533
# [298]	eval-rmse:0.06175	train-rmse:0.05328
# [299]	eval-rmse:0.061748	train-rmse:0.053271

# %% [markdown]
# Random Forest

# %%
rf1 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf1.fit(x_train_std,y_train)
rf2 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf2.fit(x_train_std,y_train)
rf3 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf3.fit(x_train_std,y_train)

rf1_17 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf1_17.fit(x_17_train_std,y_17_train)
rf2_17 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf2_17.fit(x_17_train_std,y_17_train)
rf3_17 = RandomForestRegressor(bootstrap=True,criterion='mse', max_depth=None,max_features='auto',max_leaf_nodes=None,min_samples_leaf=35,min_samples_split=50,n_estimators=50,min_weight_fraction_leaf=0.0)
rf3_17.fit(x_17_train_std,y_17_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=35, min_samples_split=50,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred_1 = cb.predict(x_test)
y_pred_2 = bst1.predict(xgb.DMatrix(x_test_std))
y_pred_3 = bst2.predict(xgb.DMatrix(x_test_std))
y_pred_4 = rf1.predict(x_test)
y_pred_5 = rf2.predict(x_test)
y_pred_6 = rf3.predict(x_test)

y_17_pred_1 = cb_17.predict(x_17_test)
y_17_pred_2 = bst1_17.predict(xgb.DMatrix(x_17_test_std))
y_17_pred_3 = bst2_17.predict(xgb.DMatrix(x_17_test_std))
y_17_pred_4 = rf1_17.predict(x_17_test)
y_17_pred_5 = rf2_17.predict(x_17_test)
y_17_pred_6 = rf3_17.predict(x_17_test)

# %% [markdown]
# Stacked Model

# %%
y_pred = np.vstack((y_pred_1,y_pred_2,y_pred_3,y_pred_4,y_pred_6))
y_pred = pd.DataFrame(y_pred.transpose(),columns=list('ABCDE'))

y_pred_17 = np.vstack((y_17_pred_1,y_17_pred_2,y_17_pred_3,y_17_pred_4,y_17_pred_6))
y_pred_17 = pd.DataFrame(y_pred_17.transpose(),columns=list('ABCDE'))

# %%
stacked_model = LinearRegression()
stacked_model.fit(y_pred, y_test)
stacked_model.score(y_pred, y_test)
# Out:
# 0.0007447783861866952

# %%
stacked_model_17 = LinearRegression()
stacked_model_17.fit(y_pred_17, y_17_test)
stacked_model_17.score(y_pred_17, y_17_test)
# Out:
# 0.0017336183547040918

# %% [markdown]
# # Make Prediction

# %%
properties_16_clustering['month'] = 10
properties_16_clustering['year'] = 2016
properties_17_clustering['month'] = 10
properties_17_clustering['year'] = 2017

# %%
properties_16_clustering = pd.get_dummies(properties_16_clustering, columns = cat_col)
properties_17_clustering = pd.get_dummies(properties_17_clustering, columns = cat_col)

# %%
properties_16_clustering.drop('airconditioningtypeid_12.0', axis=1, inplace=True)
properties_16_clustering['buildingqualitytypeid_1.0'] += properties_16_clustering['buildingqualitytypeid_2.0'] +properties_16_clustering['buildingqualitytypeid_3.0']
properties_16_clustering.drop('buildingqualitytypeid_2.0', axis=1, inplace=True)
properties_16_clustering.drop('buildingqualitytypeid_3.0', axis=1, inplace=True)

# %%
properties_16_clustering['buildingqualitytypeid_4.0'] += properties_16_clustering['buildingqualitytypeid_5.0'] +properties_16_clustering['buildingqualitytypeid_6.0']
properties_16_clustering.drop('buildingqualitytypeid_5.0', axis=1, inplace=True)
properties_16_clustering.drop('buildingqualitytypeid_6.0', axis=1, inplace=True)
properties_16_clustering['buildingqualitytypeid_8.0'] += properties_16_clustering['buildingqualitytypeid_9.0'] 
properties_16_clustering.drop('buildingqualitytypeid_9.0', axis=1, inplace=True)
properties_16_clustering['buildingqualitytypeid_10.0'] += properties_16_clustering['buildingqualitytypeid_11.0'] 
properties_16_clustering.drop('buildingqualitytypeid_11.0', axis=1, inplace=True)
properties_16_clustering['heatingorsystemtypeid_24.0'] += properties_16_clustering['heatingorsystemtypeid_19.0'] +properties_16_clustering['heatingorsystemtypeid_21.0']
properties_16_clustering.drop('heatingorsystemtypeid_19.0', axis=1, inplace=True)
properties_16_clustering.drop('heatingorsystemtypeid_21.0', axis=1, inplace=True)
properties_16_clustering.drop('propertylandusetypeid_-1.0', axis=1, inplace=True)
properties_16_clustering.drop('propertylandusetypeid_47.0', axis=1, inplace=True)
properties_16_clustering.drop('propertylandusetypeid_270.0', axis=1, inplace=True)
properties_16_clustering.drop('regionidcounty_-1.0', axis=1, inplace=True)
properties_16_clustering.drop('regionidzip_an', axis=1, inplace=True)

# %%
properties_17_clustering.drop('airconditioningtypeid_3.0', axis=1, inplace=True)
properties_17_clustering.drop('airconditioningtypeid_12.0', axis=1, inplace=True)
properties_17_clustering['heatingorsystemtypeid_24.0'] += properties_17_clustering['heatingorsystemtypeid_12.0'] +properties_17_clustering['heatingorsystemtypeid_14.0']++properties_17_clustering['heatingorsystemtypeid_19.0']++properties_17_clustering['heatingorsystemtypeid_21.0']
properties_17_clustering.drop('heatingorsystemtypeid_12.0', axis=1, inplace=True)
properties_17_clustering.drop('heatingorsystemtypeid_14.0', axis=1, inplace=True)
properties_17_clustering.drop('heatingorsystemtypeid_19.0', axis=1, inplace=True)
properties_17_clustering.drop('heatingorsystemtypeid_21.0', axis=1, inplace=True)
properties_17_clustering.drop('propertylandusetypeid_47.0', axis=1, inplace=True)
properties_17_clustering.drop('propertylandusetypeid_270.0', axis=1, inplace=True)
properties_17_clustering.drop('propertylandusetypeid_279.0', axis=1, inplace=True)

# %%
# properties_16_clustering.to_csv('properties_16_clustering.csv', index=True)
# properties_17_clustering.to_csv('properties_17_clustering.csv', index=True)

# %%
# properties_16_clustering = pd.read_csv('C:/Users/70785/properties_16_clustering.csv', header = 0)
# properties_17_clustering = pd.read_csv('C:/Users/70785/properties_17_clustering.csv', header = 0)

# %%
properties_16_lasso = properties_16_clustering[np.hstack([positive_index ,negative_index])]
properties_17_lasso = properties_17_clustering[np.hstack([positive_index_17 ,negative_index_17])]

# %%
# initialize a scaler object
scaler = StandardScaler()
# transform set
properties_16_clustering_std = scaler.fit_transform(properties_16_clustering)

# initialize a scaler object
scaler = StandardScaler()
# transform set
properties_17_clustering_std = scaler.fit_transform(properties_17_clustering)

# %%
y_pred_1 = cb.predict(properties_16_clustering)
y_pred_2 = bst1.predict(xgb.DMatrix(properties_16_clustering_std))
y_pred_3 = bst2.predict(xgb.DMatrix(properties_16_clustering_std))
y_pred_4 = rf1.predict(properties_16_clustering)
y_pred_5 = rf2.predict(properties_16_clustering)
y_pred_6 = rf3.predict(properties_16_clustering)

y_17_pred_1 = cb_17.predict(properties_17_clustering)
y_17_pred_2 = bst1_17.predict(xgb.DMatrix(properties_17_clustering_std))
y_17_pred_3 = bst2_17.predict(xgb.DMatrix(properties_17_clustering_std))
y_17_pred_4 = rf1_17.predict(properties_17_clustering)
y_17_pred_5 = rf2_17.predict(properties_17_clustering)
y_17_pred_6 = rf3_17.predict(properties_17_clustering)

# %%
y_pred = np.vstack((y_pred_1,y_pred_2,y_pred_3,y_pred_4,y_pred_6))
y_pred = pd.DataFrame(y_pred.transpose(),columns=list('ABCDE'))

y_pred_17 = np.vstack((y_17_pred_1,y_17_pred_2,y_17_pred_3,y_17_pred_4,y_17_pred_6))
y_pred_17 = pd.DataFrame(y_pred_17.transpose(),columns=list('ABCDE'))

# y_pred = np.vstack((y_pred_1,y_pred_2,y_pred_3,y_pred_4,y_pred_5,y_pred_6,y_pred_10,y_pred_11,y_pred_12,y_pred_13,y_pred_14))
# y_pred = pd.DataFrame(y_pred.transpose(),columns=list('ABCDEFGHIJK'))

# y_pred_17 = np.vstack((y_17_pred_1,y_17_pred_2,y_17_pred_3,y_17_pred_4,y_17_pred_5,y_17_pred_6,y_17_pred_10,y_17_pred_11,y_17_pred_12,y_17_pred_13,y_17_pred_14))
# y_pred_17 = pd.DataFrame(y_pred_17.transpose(),columns=list('ABCDEFGHIJK'))

# %%
y_new = stacked_model.predict(y_pred)
y_17_new = stacked_model_17.predict(y_pred_17)

# %%
dataframe = pd.DataFrame({'ParcelId':properties_16_clustering['parcelid'],'201610':y_new,'201611':y_new,'201612':y_new,'201710':y_17_new,'201711':y_17_new,'201712':y_17_new})
dataframe.to_csv("test.csv",index=False)
